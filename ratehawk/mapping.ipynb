# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz, process
import re
import phonetics
from geopy.distance import geodesic
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

class SimpleHotelMatcher:
    def __init__(self):
        """
        Inicjalizacja prostego matchera z własnym drzewem decyzyjnym
        """
        self.reference_hotels = None
        self.api_hotels = None
        self.country_mappings = self._create_country_mappings()
        
    def _create_country_mappings(self) -> Dict[str, str]:
        """
        Tworzenie mapowania krajów na kody ISO - kompletna lista
        """
        country_map = {
            # Rate Hawk API codes
            'TH': 'Thailand',
            'AE': 'United Arab Emirates', 
            'SC': 'Seychelles',
            
            # Lista referencyjna - wszystkie kraje
            'Turcja': 'Turkey',
            'Hiszpania': 'Spain', 
            'UAE': 'United Arab Emirates',
            'Czarnogóra': 'Montenegro',
            'Włochy': 'Italy',
            'Malezja': 'Malaysia',
            'Malediwy': 'Maldives',
            'Grecja': 'Greece',
            'Seszele': 'Seychelles',
            'Maroko': 'Morocco',
            'Egipt': 'Egypt',
            'Mauritius': 'Mauritius',
            'Wielka Brytania': 'United Kingdom',
            'Portugalia': 'Portugal',
            'Tajlandia': 'Thailand',
            'Szwajcaria': 'Switzerland',
            'Australia': 'Australia',
            'Indonezja': 'Indonesia',
            'Aruba': 'Aruba',
            'Grenlandia': 'Greenland',
            'Wietnam': 'Vietnam',
            'Francja': 'France',
            'USA': 'United States',
            'Singapur': 'Singapore',
            'Islandia': 'Iceland',
            'Qatar': 'Qatar',
            'RPA': 'South Africa',
            'Dominikana': 'Dominican Republic',
            'Explora': 'Chile',  # Explora cruise line
            
            # Alternative spellings
            'Turkey': 'Turkey',
            'Spain': 'Spain',
            'Montenegro': 'Montenegro',
            'Italy': 'Italy',
            'Malaysia': 'Malaysia',
            'Maldives': 'Maldives',
            'Greece': 'Greece',
            'Seychelles': 'Seychelles',
            'Morocco': 'Morocco',
            'Egypt': 'Egypt',
            'United Kingdom': 'United Kingdom',
            'Portugal': 'Portugal',
            'Thailand': 'Thailand',
            'Switzerland': 'Switzerland',
            'Australia': 'Australia',
            'Indonesia': 'Indonesia',
            'Vietnam': 'Vietnam',
            'France': 'France',
            'United States': 'United States',
            'Singapore': 'Singapore',
            'Iceland': 'Iceland',
            'Qatar': 'Qatar',
            'South Africa': 'South Africa',
            'Dominican Republic': 'Dominican Republic',
            'Chile': 'Chile'
        }
        return country_map
    
    def load_reference_hotels(self, csv_path: str) -> pd.DataFrame:
        """
        Ładowanie i przetwarzanie listy referencyjnej hoteli
        """
        print("\n" + "="*50)
        print("📂 KROK 1A: ŁADOWANIE LISTY REFERENCYJNEJ")
        print("="*50)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Załadowano plik: {csv_path}")
            print(f"📊 Znaleziono {len(df)} hoteli w pliku")
        except Exception as e:
            print(f"❌ Błąd podczas ładowania pliku: {e}")
            return None
        
        print("\n🧹 Czyszczenie i normalizacja danych...")
        
        # Czyszczenie i normalizacja danych referencyjnych
        df['clean_location'] = df['Lokalizacja'].str.strip()
        df['clean_hotel'] = df['Hotel'].str.strip()
        
        # Ekstrakcja kraju i miasta z lokalizacji
        print("🌍 Ekstrakcja krajów i miast...")
        df[['country', 'city']] = df['clean_location'].str.split(',', n=1, expand=True)
        df['country'] = df['country'].fillna('').str.strip()
        df['city'] = df['city'].fillna('').str.strip()
        
        # Dodanie kodów ISO
        print("🏳️ Mapowanie kodów krajów...")
        df['country_iso'] = df['country'].map(self.country_mappings)
        df['country_iso'] = df['country_iso'].fillna(df['country'])
        
        # Pokazanie statystyk krajów
        country_stats = df['country_iso'].value_counts()
        print(f"📈 Top 5 krajów:")
        for country, count in country_stats.head().items():
            print(f"   {country}: {count} hoteli")
        
        # Normalizacja nazw hoteli
        print("✂️ Normalizacja nazw hoteli...")
        df['normalized_name'] = df['clean_hotel'].apply(self._normalize_hotel_name)
        
        # Tworzenie unikalnego ID
        df['reference_id'] = df.index.astype(str).str.zfill(3)
        
        self.reference_hotels = df
        print(f"✅ Przetworzono {len(df)} hoteli referencyjnych")
        
        # Pokazanie przykładów normalizacji
        print(f"\n📋 Przykłady normalizacji nazw:")
        for i in range(min(3, len(df))):
            original = df.iloc[i]['clean_hotel']
            normalized = df.iloc[i]['normalized_name']
            print(f"   '{original}' → '{normalized}'")
        
        return df
    
    def load_api_hotels(self, csv_path: str) -> pd.DataFrame:
        """
        Ładowanie i przetwarzanie hoteli z Rate Hawk API
        """
        print("\n" + "="*50)
        print("📡 KROK 1B: ŁADOWANIE DANYCH Z RATE HAWK API")
        print("="*50)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Załadowano plik: {csv_path}")
            print(f"📊 Znaleziono {len(df)} hoteli z API")
        except Exception as e:
            print(f"❌ Błąd podczas ładowania pliku: {e}")
            return None
        
        print("\n🧹 Czyszczenie danych API...")
        
        # Podstawowe czyszczenie danych
        df['clean_name'] = df['name'].fillna('').str.strip()
        df['clean_city'] = df['city'].fillna('').str.strip()
        df['clean_country'] = df['country'].fillna('').str.strip()
        df['clean_address'] = df['address'].fillna('').str.strip()
        
        # Statystyki krajów w API
        country_stats = df['clean_country'].value_counts()
        print(f"🌍 Top 5 krajów w API:")
        for country, count in country_stats.head().items():
            print(f"   {country}: {count} hoteli")
        
        # Normalizacja nazw
        print("✂️ Normalizacja nazw hoteli API...")
        df['normalized_name'] = df['clean_name'].apply(self._normalize_hotel_name)
        
        # Mapowanie krajów na pełne nazwy
        print("🏳️ Mapowanie kodów krajów API...")
        df['country_full'] = df['clean_country'].map(self.country_mappings)
        df['country_full'] = df['country_full'].fillna(df['clean_country'])
        
        # Czyszczenie współrzędnych
        print("🗺️ Walidacja współrzędnych geograficznych...")
        df['lat'] = pd.to_numeric(df['latitude'], errors='coerce')
        df['lng'] = pd.to_numeric(df['longitude'], errors='coerce')
        
        coords_valid = df[['lat', 'lng']].notna().all(axis=1).sum()
        print(f"📍 Hoteli z prawidłowymi współrzędnymi: {coords_valid}/{len(df)} ({coords_valid/len(df)*100:.1f}%)")
        
        # Normalizacja chain names
        df['clean_chain'] = df['hotel_chain'].fillna('No chain').str.strip()
        chain_stats = df['clean_chain'].value_counts()
        print(f"🏨 Top 3 sieci hotelowe w API:")
        for chain, count in chain_stats.head(3).items():
            if chain != 'No chain':
                print(f"   {chain}: {count} hoteli")
        
        self.api_hotels = df
        print(f"✅ Przetworzono {len(df)} hoteli z API")
        
        return df
    
    def _normalize_hotel_name(self, name: str) -> str:
        """
        Normalizacja nazwy hotelu dla lepszego matchingu
        """
        if pd.isna(name) or not name:
            return ""
        
        # Konwersja na lowercase
        name = str(name).lower().strip()
        
        # Usunięcie znaków specjalnych ale zachowanie spacji
        name = re.sub(r'[^\w\s]', ' ', name)
        
        # Usunięcie typowych słów hotelowych
        stop_words = [
            'hotel', 'resort', 'spa', 'suites', 'inn', 'lodge', 
            'motel', 'palace', 'club', 'grand', 'royal'
        ]
        
        words = name.split()
        words = [word for word in words if word not in stop_words and len(word) > 1]
        
        # Usunięcie duplikatów zachowując kolejność
        seen = set()
        unique_words = []
        for word in words:
            if word not in seen:
                unique_words.append(word)
                seen.add(word)
        
        return ' '.join(unique_words)
    
    def exact_match(self) -> List[Dict]:
        """
        Exact matching - szukanie identycznych nazw i lokalizacji
        Z COUNTRY PRE-FILTERING dla optymalizacji
        """
        print("\n" + "="*50)
        print("🎯 KROK 2: EXACT MATCHING")
        print("="*50)
        print("Szukanie identycznych nazw i lokalizacji...")
        print("🔧 OPTYMALIZACJA: Pre-filtering po krajach")
        
        exact_matches = []
        total_comparisons = 0
        skipped_by_country = 0
        
        print(f"Sprawdzanie {len(self.reference_hotels)} hoteli referencyjnych vs {len(self.api_hotels)} z API\n")
        
        for ref_idx, ref_hotel in self.reference_hotels.iterrows():
            ref_name = ref_hotel['normalized_name']
            ref_country = ref_hotel['country_iso']
            ref_city = ref_hotel['city']
            
            print(f"Sprawdzanie [{ref_idx+1:2d}/{len(self.reference_hotels)}]: {ref_hotel['clean_hotel'][:50]}...")
            print(f"   🌍 Kraj: {ref_country}")
            
            # PRE-FILTERING: Tylko hotele z tego samego kraju lub podobnego
            candidates = []
            for _, api_hotel in self.api_hotels.iterrows():
                api_country = api_hotel['country_full']
                country_similarity = self._country_similarity(ref_country, api_country)
                
                # Filtruj tylko hotele z podobnym krajem (>0.7 similarity)
                if country_similarity > 0.7:
                    candidates.append((api_hotel, country_similarity))
                else:
                    skipped_by_country += 1
            
            print(f"   📍 Kandydatów po filtrze krajów: {len(candidates)}/{len(self.api_hotels)} ({len(candidates)/len(self.api_hotels)*100:.1f}%)")
            
            matches_for_hotel = 0
            
            # Sprawdzanie tylko kandydatów z podobnych krajów
            for api_hotel, country_sim in candidates:
                total_comparisons += 1
                
                api_name = api_hotel['normalized_name']
                api_city = api_hotel['clean_city']
                
                # Exact name match
                if ref_name and api_name and ref_name == api_name:
                    exact_matches.append({
                        'reference_id': ref_hotel['reference_id'],
                        'reference_name': ref_hotel['clean_hotel'],
                        'api_id': api_hotel['id'],
                        'api_name': api_hotel['clean_name'],
                        'match_type': 'exact_name',
                        'confidence': 1.0,
                        'decision_path': 'Identical normalized names'
                    })
                    matches_for_hotel += 1
                    print(f"   ✅ EXACT MATCH: {api_hotel['clean_name'][:40]}...")
                    continue
                
                # Near exact with location
                name_similarity = fuzz.ratio(ref_name, api_name) / 100.0
                if name_similarity > 0.95:
                    city_match = self._city_similarity(ref_city, api_city)
                    
                    if country_sim > 0.8 or city_match > 0.8:
                        exact_matches.append({
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel['id'],
                            'api_name': api_hotel['clean_name'],
                            'match_type': 'near_exact',
                            'confidence': min(name_similarity + 0.05, 1.0),
                            'decision_path': f'High name similarity ({name_similarity:.2f}) + location match'
                        })
                        matches_for_hotel += 1
                        print(f"   ✅ NEAR EXACT: {api_hotel['clean_name'][:40]}... (sim: {name_similarity:.2f})")
            
            if matches_for_hotel == 0:
                print(f"   ❌ Brak exact matches")
            print()
        
        print(f"🎯 EXACT MATCHING ZAKOŃCZONY!")
        print(f"✅ Znaleziono {len(exact_matches)} exact matches")
        print(f"📊 Coverage exact: {len(exact_matches)}/{len(self.reference_hotels)} ({len(exact_matches)/len(self.reference_hotels)*100:.1f}%)")
        print(f"⚡ Optymalizacja:")
        print(f"   📊 Porównań wykonanych: {total_comparisons:,}")
        print(f"   🚫 Pominięto przez filtr krajów: {skipped_by_country:,}")
        print(f"   🔥 Reduction: {(skipped_by_country/(total_comparisons+skipped_by_country))*100:.1f}%")
        
        return exact_matches
    
    def custom_decision_tree(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        """
        WŁASNE DRZEWO DECYZYJNE - logika oparta na fuzzy matching
        
        Decision Tree Logic:
        1. Sprawdź high similarity (>80%) + same country → MATCH
        2. Sprawdź chain similarity + medium similarity (>60%) → MATCH  
        3. Sprawdź word order similarity + same city → MATCH
        4. Sprawdź phonetic + high partial ratio → MATCH
        5. Else → NO MATCH
        """
        
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return None
        
        # Obliczenie wszystkich features
        features = self._calculate_features(ref_hotel, api_hotel)
        
        # DECISION TREE LOGIC
        
        # NODE 1: High Similarity + Same Country
        if features['fuzz_ratio'] > 0.80 and features['same_country'] > 0.8:
            return {
                'reference_id': ref_hotel['reference_id'],
                'reference_name': ref_hotel['clean_hotel'],
                'api_id': api_hotel['id'],
                'api_name': api_hotel['clean_name'],
                'match_type': 'decision_tree',
                'confidence': min(0.85 + features['fuzz_ratio'] * 0.1, 0.95),
                'decision_path': f"HIGH_SIMILARITY + SAME_COUNTRY (ratio: {features['fuzz_ratio']:.2f})"
            }
        
        # NODE 2: Chain Similarity + Medium Name Similarity  
        if features['chain_similarity'] > 0.8 and features['fuzz_ratio'] > 0.60:
            return {
                'reference_id': ref_hotel['reference_id'],
                'reference_name': ref_hotel['clean_hotel'],
                'api_id': api_hotel['id'],
                'api_name': api_hotel['clean_name'],
                'match_type': 'decision_tree',
                'confidence': 0.75 + features['fuzz_ratio'] * 0.1,
                'decision_path': f"CHAIN_MATCH + MEDIUM_SIMILARITY (chain: {features['chain_similarity']:.2f})"
            }
        
        # NODE 3: Word Order + Same City (Marriott Warsaw vs Warsaw Marriott)
        if features['word_order_sim'] > 0.80 and features['same_city'] > 0.7:
            return {
                'reference_id': ref_hotel['reference_id'],
                'reference_name': ref_hotel['clean_hotel'],
                'api_id': api_hotel['id'],
                'api_name': api_hotel['clean_name'],
                'match_type': 'decision_tree',
                'confidence': 0.70 + features['word_order_sim'] * 0.15,
                'decision_path': f"WORD_ORDER + SAME_CITY (word_order: {features['word_order_sim']:.2f})"
            }
        
        # NODE 4: Phonetic Similarity + High Partial Ratio
        if features['soundex_match'] == 1.0 and features['fuzz_partial'] > 0.85:
            return {
                'reference_id': ref_hotel['reference_id'],
                'reference_name': ref_hotel['clean_hotel'],
                'api_id': api_hotel['id'],
                'api_name': api_hotel['clean_name'],
                'match_type': 'decision_tree',
                'confidence': 0.65 + features['fuzz_partial'] * 0.1,
                'decision_path': f"PHONETIC + HIGH_PARTIAL (soundex + partial: {features['fuzz_partial']:.2f})"
            }
        
        # NODE 5: Token Sort High + Medium Overall Similarity
        if features['fuzz_token_sort'] > 0.85 and features['fuzz_ratio'] > 0.50:
            return {
                'reference_id': ref_hotel['reference_id'],
                'reference_name': ref_hotel['clean_hotel'],
                'api_id': api_hotel['id'],
                'api_name': api_hotel['clean_name'],
                'match_type': 'decision_tree',
                'confidence': 0.60 + features['fuzz_token_sort'] * 0.1,
                'decision_path': f"TOKEN_SORT + MEDIUM_SIM (token_sort: {features['fuzz_token_sort']:.2f})"
            }
        
        # NO MATCH
        return None
    
    def _calculate_features(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        """
        Obliczenie wszystkich features dla decision tree
        """
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        features = {}
        
        # String similarities
        if ref_name and api_name:
            features['fuzz_ratio'] = fuzz.ratio(ref_name, api_name) / 100.0
            features['fuzz_partial'] = fuzz.partial_ratio(ref_name, api_name) / 100.0
            features['fuzz_token_sort'] = fuzz.token_sort_ratio(ref_name, api_name) / 100.0
            features['fuzz_token_set'] = fuzz.token_set_ratio(ref_name, api_name) / 100.0
        else:
            features.update({
                'fuzz_ratio': 0, 'fuzz_partial': 0, 
                'fuzz_token_sort': 0, 'fuzz_token_set': 0
            })
        
        # Geographic similarity
        ref_country = ref_hotel.get('country_iso', '')
        api_country = api_hotel.get('country_full', '')
        features['same_country'] = self._country_similarity(ref_country, api_country)
        
        ref_city = ref_hotel.get('city', '')
        api_city = api_hotel.get('clean_city', '')
        features['same_city'] = self._city_similarity(ref_city, api_city)
        
        # Word order similarity
        features['word_order_sim'] = self._word_order_similarity(ref_name, api_name)
        
        # Phonetic similarity
        features['soundex_match'] = self._phonetic_similarity(ref_name, api_name)
        
        # Chain similarity
        features['chain_similarity'] = self._chain_similarity(ref_hotel, api_hotel)
        
        return features
    
    def _country_similarity(self, country1: str, country2: str) -> float:
        """
        Sprawdzenie podobieństwa krajów
        """
        if not country1 or not country2:
            return 0.0
        
        country1 = str(country1).lower().strip()
        country2 = str(country2).lower().strip()
        
        if country1 == country2:
            return 1.0
        
        # Sprawdzenie czy jeden zawiera drugi
        if country1 in country2 or country2 in country1:
            return 0.9
        
        # Fuzzy similarity dla krajów
        return fuzz.ratio(country1, country2) / 100.0
    
    def _city_similarity(self, city1: str, city2: str) -> float:
        """
        Sprawdzenie podobieństwa miast
        """
        if not city1 or not city2:
            return 0.0
        
        city1 = str(city1).lower().strip()
        city2 = str(city2).lower().strip()
        
        if city1 == city2:
            return 1.0
        
        return fuzz.ratio(city1, city2) / 100.0
    
    def _word_order_similarity(self, name1: str, name2: str) -> float:
        """
        Sprawdzenie czy to te same słowa w innej kolejności
        """
        if not name1 or not name2:
            return 0.0
        
        words1 = set(name1.lower().split())
        words2 = set(name2.lower().split())
        
        if not words1 or not words2:
            return 0.0
        
        intersection = len(words1 & words2)
        union = len(words1 | words2)
        
        return intersection / union if union > 0 else 0.0
    
    def _phonetic_similarity(self, name1: str, name2: str) -> float:
        """
        Sprawdzenie podobieństwa fonetycznego
        """
        if not name1 or not name2:
            return 0.0
        
        try:
            soundex1 = phonetics.soundex(name1.replace(' ', ''))
            soundex2 = phonetics.soundex(name2.replace(' ', ''))
            return 1.0 if soundex1 == soundex2 else 0.0
        except:
            return 0.0
    
    def _chain_similarity(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> float:
        """
        Sprawdzenie podobieństwa sieci hotelowych - rozszerzona lista
        """
        ref_name = ref_hotel.get('clean_hotel', '')
        api_chain = api_hotel.get('clean_chain', '')
        
        # Rozszerzona lista znanych sieci hotelowych z twojej listy
        chains = [
            # Luxury chains
            'four seasons', 'one only', 'waldorf astoria', 'mandarin oriental',
            'ritz carlton', 'ritz-carlton', 'st regis', 'shangri-la',
            
            # Premium chains  
            'marriott', 'hilton', 'hyatt', 'intercontinental', 'sheraton',
            'westin', 'doubletree', 'regent', 'fairmont', 'raffles',
            
            # Boutique/Regional
            'atlantis', 'ikos', 'movenpick', 'mövenpick', 'banyan tree',
            'six senses', 'rosewood', 'belmond', 'dusit thani',
            'angsana', 'chedi', 'lefay', 'forte village',
            
            # Resort brands
            'bahia del duque', 'grecotel', 'domes', 'sani', 'daios',
            'puente romano', 'marbella club', 'gloria', 'maxx royal',
            
            # Cruise/Special
            'quark expeditions', 'explora'
        ]
        
        ref_lower = ref_name.lower()
        api_lower = api_chain.lower()
        
        # Exact chain match
        for chain in chains:
            if chain in ref_lower and chain in api_lower:
                return 1.0
        
        # Fuzzy chain similarity
        if api_chain != 'No chain' and len(api_chain) > 3:
            chain_sim = fuzz.ratio(api_chain.lower(), ref_name.lower()) / 100.0
            if chain_sim > 0.6:  # Threshold dla chain similarity
                return chain_sim
        
        return 0.0
    
    def fuzzy_decision_matching(self) -> List[Dict]:
        """
        Fuzzy matching używając custom decision tree
        """
        print("\n" + "="*50)
        print("🧠 KROK 3: FUZZY DECISION TREE MATCHING")
        print("="*50)
        print("Używanie własnego drzewa decyzyjnego z fuzzy features...")
        
        fuzzy_matches = []
        total_hotels = len(self.reference_hotels)
        
        print(f"Sprawdzanie {total_hotels} hoteli referencyjnych")
        print("Decision Tree Logic:")
        print("  NODE 1: High Similarity (>80%) + Same Country")
        print("  NODE 2: Chain Match + Medium Similarity (>60%)")  
        print("  NODE 3: Word Order Match + Same City")
        print("  NODE 4: Phonetic Match + High Partial")
        print("  NODE 5: Token Sort + Medium Overall\n")
        
        for ref_idx, ref_hotel in self.reference_hotels.iterrows():
            print(f"Analizowanie [{ref_idx+1:2d}/{total_hotels}]: {ref_hotel['clean_hotel'][:50]}...")
            
            best_match = None
            best_confidence = 0
            candidates_checked = 0
            decision_paths = []
            
            for _, api_hotel in self.api_hotels.iterrows():
                candidates_checked += 1
                
                # Sprawdzenie przez decision tree
                match_result = self.custom_decision_tree(ref_hotel, api_hotel)
                
                if match_result and match_result['confidence'] > best_confidence:
                    best_confidence = match_result['confidence']
                    best_match = match_result
                    decision_paths.append(f"   Candidate: {api_hotel['clean_name'][:30]}... → {match_result['decision_path']}")
                
                # Progress co 500 kandydatów
                if candidates_checked % 500 == 0:
                    print(f"   Sprawdzono {candidates_checked}/{len(self.api_hotels)} kandydatów...")
            
            if best_match and best_confidence >= 0.6:  # Minimum threshold
                fuzzy_matches.append(best_match)
                print(f"   ✅ MATCH FOUND: {best_match['api_name'][:40]}...")
                print(f"   📊 Confidence: {best_confidence:.3f}")
                print(f"   🎯 Decision: {best_match['decision_path']}")
                
                # Pokaż najlepsze alternatywy
                if len(decision_paths) > 1:
                    print(f"   📋 Top alternatives:")
                    for path in decision_paths[-3:]:  # Last 3 best
                        print(path)
            else:
                print(f"   ❌ Brak matches (best confidence: {best_confidence:.3f})")
            
            print()
        
        print(f"🧠 FUZZY DECISION MATCHING ZAKOŃCZONY!")
        print(f"✅ Znaleziono {len(fuzzy_matches)} fuzzy matches")
        print(f"📊 Coverage fuzzy: {len(fuzzy_matches)}/{total_hotels} ({len(fuzzy_matches)/total_hotels*100:.1f}%)")
        
        return fuzzy_matches
    
    def run_complete_matching(self, reference_csv: str, api_csv: str) -> Dict:
        """
        Kompletny pipeline matchingu bez ML
        """
        print("🚀" + "="*58 + "🚀")
        print("🚀 HOTEL MAPPING ENGINE - SIMPLE DECISION TREE VERSION 🚀")
        print("🚀" + "="*58 + "🚀")
        print("Mapowanie hoteli premium do Rate Hawk API")
        print("Algorytm: Exact Match + Custom Decision Tree + Fuzzy Features")
        
        # Krok 1: Ładowanie danych
        self.load_reference_hotels(reference_csv)
        if self.reference_hotels is None:
            return {'error': 'Failed to load reference hotels'}
            
        self.load_api_hotels(api_csv)
        if self.api_hotels is None:
            return {'error': 'Failed to load API hotels'}
        
        # Krok 2: Exact matching
        exact_matches = self.exact_match()
        
        # Krok 3: Fuzzy decision tree matching
        fuzzy_matches = self.fuzzy_decision_matching()
        
        # Krok 4: Kombinowanie wyników (unikanie duplikatów)
        print("\n" + "="*50)
        print("🔗 KROK 4: KOMBINOWANIE WYNIKÓW")
        print("="*50)
        
        all_matches = exact_matches.copy()
        
        # Dodaj fuzzy matches które nie są już w exact matches
        exact_ref_ids = {match['reference_id'] for match in exact_matches}
        new_fuzzy_matches = 0
        
        for fuzzy_match in fuzzy_matches:
            if fuzzy_match['reference_id'] not in exact_ref_ids:
                all_matches.append(fuzzy_match)
                new_fuzzy_matches += 1
        
        print(f"📊 Exact matches: {len(exact_matches)}")
        print(f"📊 Nowe fuzzy matches: {new_fuzzy_matches}")
        print(f"📊 Duplikaty pominięte: {len(fuzzy_matches) - new_fuzzy_matches}")
        print(f"📊 Łączne matches: {len(all_matches)}")
        
        # Krok 5: Generowanie raportów
        print("\n" + "="*50)
        print("📈 KROK 5: GENEROWANIE RAPORTÓW")
        print("="*50)
        
        coverage = len(all_matches) / len(self.reference_hotels) * 100
        
        results = {
            'total_reference_hotels': len(self.reference_hotels),
            'total_api_hotels': len(self.api_hotels),
            'exact_matches': len(exact_matches),
            'fuzzy_matches': new_fuzzy_matches,
            'total_matches': len(all_matches),
            'coverage_percentage': coverage,
            'matches': all_matches
        }
        
        print(f"🎯 FINAL RESULTS:")
        print(f"   📚 Hoteli referencyjnych: {results['total_reference_hotels']}")
        print(f"   📡 Hoteli z API: {results['total_api_hotels']:,}")
        print(f"   ✅ Exact matches: {results['exact_matches']}")
        print(f"   🧠 Fuzzy matches: {results['fuzzy_matches']}")
        print(f"   🎯 Total matches: {results['total_matches']}")
        print(f"   📊 Coverage: {coverage:.1f}%")
        
        # Confidence distribution
        if all_matches:
            confidences = [match['confidence'] for match in all_matches]
            high_conf = sum(1 for c in confidences if c >= 0.9)
            med_conf = sum(1 for c in confidences if 0.7 <= c < 0.9)
            low_conf = sum(1 for c in confidences if c < 0.7)
            
            print(f"\n📊 CONFIDENCE DISTRIBUTION:")
            print(f"   🟢 High confidence (≥0.9): {high_conf}")
            print(f"   🟡 Medium confidence (0.7-0.9): {med_conf}")
            print(f"   🔴 Low confidence (<0.7): {low_conf}")
        
        return results
    
    def save_results(self, results: Dict, output_prefix: str = "hotel_mapping"):
        """
        Zapisywanie wyników do plików CSV
        """
        print("\nZapisywanie wyników...")
        
        # Plik 1: Lista referencyjna z kodami ISO
        reference_with_iso = self.reference_hotels[[
            'Lokalizacja', 'Hotel', 'country', 'city', 'country_iso', 'reference_id'
        ]].copy()
        
        reference_file = f"{output_prefix}_reference_with_iso.csv"
        reference_with_iso.to_csv(reference_file, index=False)
        print(f"Zapisano: {reference_file}")
        
        # Plik 2: Wszystkie matches
        if results['matches']:
            matches_df = pd.DataFrame(results['matches'])
            matches_file = f"{output_prefix}_matches.csv"
            matches_df.to_csv(matches_file, index=False)
            print(f"Zapisano: {matches_file}")
        
        # Plik 3: Podsumowanie
        summary = {
            'metric': [
                'Total Reference Hotels',
                'Total API Hotels', 
                'Exact Matches',
                'Fuzzy Decision Matches',
                'Total Matches',
                'Coverage Percentage'
            ],
            'value': [
                results['total_reference_hotels'],
                results['total_api_hotels'],
                results['exact_matches'],
                results['fuzzy_matches'],
                results['total_matches'],
                f"{results['coverage_percentage']:.1f}%"
            ]
        }
        
        summary_df = pd.DataFrame(summary)
        summary_file = f"{output_prefix}_summary.csv"
        summary_df.to_csv(summary_file, index=False)
        print(f"Zapisano: {summary_file}")
        
        print(f"\nCoverage: {results['coverage_percentage']:.1f}% ({results['total_matches']}/{results['total_reference_hotels']})")


# Użycie
if __name__ == "__main__":
    # Inicjalizacja matcher
    matcher = SimpleHotelMatcher()
    
    # Uruchomienie complete matching
    results = matcher.run_complete_matching(
        reference_csv="lista_referencyjna.csv",
        api_csv="01_api_rate_hawk.csv"
    )
    
    # Zapisanie wyników
    matcher.save_results(results)
    
    print("\n" + "=" * 60)
    print("SIMPLE DECISION TREE MATCHING ZAKOŃCZONY!")
    print("=" * 60)


#     ==================================================
# 📈 KROK 5: GENEROWANIE RAPORTÓW
# ==================================================
# 🎯 FINAL RESULTS:
#    📚 Hoteli referencyjnych: 99
#    📡 Hoteli z API: 95,463
#    ✅ Exact matches: 11
#    🧠 Fuzzy matches: 37
#    🎯 Total matches: 48
#    📊 Coverage: 48.5%

# 📊 CONFIDENCE DISTRIBUTION:
#    🟢 High confidence (≥0.9): 20
#    🟡 Medium confidence (0.7-0.9): 27
#    🔴 Low confidence (<0.7): 1

# Zapisywanie wyników...
# Zapisano: hotel_mapping_reference_with_iso.csv
# Zapisano: hotel_mapping_matches.csv
# Zapisano: hotel_mapping_summary.csv

# Coverage: 48.5% (48/99)
# Out:
# 🚀==========================================================🚀
# 🚀 HOTEL MAPPING ENGINE - SIMPLE DECISION TREE VERSION 🚀
# 🚀==========================================================🚀
# Mapowanie hoteli premium do Rate Hawk API
# Algorytm: Exact Match + Custom Decision Tree + Fuzzy Features
#
# ==================================================
# 📂 KROK 1A: ŁADOWANIE LISTY REFERENCYJNEJ
# ==================================================
# ✅ Załadowano plik: lista_referencyjna.csv
# 📊 Znaleziono 99 hoteli w pliku
#
# 🧹 Czyszczenie i normalizacja danych...
# 🌍 Ekstrakcja krajów i miast...
# 🏳️ Mapowanie kodów krajów...
# 📈 Top 5 krajów:
#    Greece: 13 hoteli
#    Maldives: 12 hoteli
#    United Arab Emirates: 11 hoteli
#    Spain: 8 hoteli
#    Thailand: 7 hoteli
# ✂️ Normalizacja nazw hoteli...
# ✅ Przetworzono 99 hoteli referencyjnych
#
# 📋 Przykłady normalizacji nazw:
#    'Regnum Carya Golf & Spa Resort, Turcja' → 'regnum carya golf turcja'
#    'SH Valencia Palace, Walencja' → 'sh valencia walencja'
#    'Atlantis The Royal' → 'atlantis the'
#
# ==================================================
# 📡 KROK 1B: ŁADOWANIE DANYCH Z RATE HAWK API
# ==================================================
# ✅ Załadowano plik: 01_api_rate_hawk.csv
# 📊 Znaleziono 95463 hoteli z API
#
# 🧹 Czyszczenie danych API...
# 🌍 Top 5 krajów w API:
#    AE: 12942 hoteli
#    GR: 8592 hoteli
#    TH: 8063 hoteli
#    US: 7858 hoteli
#    ES: 6906 hoteli
# ✂️ Normalizacja nazw hoteli API...
# 🏳️ Mapowanie kodów krajów API...
# 🗺️ Walidacja współrzędnych geograficznych...
# 📍 Hoteli z prawidłowymi współrzędnymi: 95463/95463 (100.0%)
# 🏨 Top 3 sieci hotelowe w API:
#    ZenRooms: 162 hoteli
#    Choice Hotels: 144 hoteli
# ✅ Przetworzono 95463 hoteli z API
#
# ==================================================
# 🎯 KROK 2: EXACT MATCHING
# ==================================================
# Szukanie identycznych nazw i lokalizacji...
# 🔧 OPTYMALIZACJA: Pre-filtering po krajach
# Sprawdzanie 99 hoteli referencyjnych vs 95463 z API
#
# Sprawdzanie [ 1/99]: Regnum Carya Golf & Spa Resort, Turcja...
#    🌍 Kraj: Turkey
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [ 2/99]: SH Valencia Palace, Walencja...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [ 3/99]: Atlantis The Royal...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ✅ EXACT MATCH: Atlantis The Royal Hotel...
#
# Sprawdzanie [ 4/99]: Ikos Porto Petro, Majorka...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [ 5/99]: One & Only Royal Mirage...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ✅ EXACT MATCH: One&Only Royal Mirage Hotel...
#
# Sprawdzanie [ 6/99]: Atlantis The Palm...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ✅ EXACT MATCH: Atlantis, The Palm...
#
# Sprawdzanie [ 7/99]: One & Only Portovovi, Czarnogóra...
#    🌍 Kraj: Montenegro
#    📍 Kandydatów po filtrze krajów: 10380/95463 (10.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [ 8/99]: Bahia Del Duque...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [ 9/99]: Lefay Resort & SPA Dolomiti...
#    🌍 Kraj: Italy
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [10/99]: Ikos Andalusia...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [11/99]: Four Seasons Langkawi...
#    🌍 Kraj: Malaysia
#    📍 Kandydatów po filtrze krajów: 545/95463 (0.6%)
#    ❌ Brak exact matches
#
# Sprawdzanie [12/99]: Movenpick Resort Kuredhivaru Maldives...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [13/99]: Sani Club Hotel, Chalkidiki...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [14/99]: Marbella Club...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [15/99]: The Ritz-Carlton Yacht Collection...
#    🌍 Kraj: The Ritz-Carlton Yacht Collection
#    📍 Kandydatów po filtrze krajów: 6012/95463 (6.3%)
#    ❌ Brak exact matches
#
# Sprawdzanie [16/99]: Waldorf Astoria Seychelles...
#    🌍 Kraj: Seychelles
#    📍 Kandydatów po filtrze krajów: 8045/95463 (8.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [17/99]: Finolhu, Malediwy...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [18/99]: Gloria Serenity Resort...
#    🌍 Kraj: Turkey
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [19/99]: Dukley Hotel & Resort, Czarnogóra...
#    🌍 Kraj: Montenegro
#    📍 Kandydatów po filtrze krajów: 10380/95463 (10.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [20/99]: Grecotel Corfu Imperial...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [21/99]: JW Marriott Mauritius Resort...
#    🌍 Kraj: Mauritius
#    📍 Kandydatów po filtrze krajów: 17692/95463 (18.5%)
#    ❌ Brak exact matches
#
# Sprawdzanie [22/99]: Four Seasons Resort Seychelles at Desroches Island...
#    🌍 Kraj: Seychelles
#    📍 Kandydatów po filtrze krajów: 8045/95463 (8.4%)
#    ✅ EXACT MATCH: Four Seasons Resort Seychelles at Desroc...
#
# Sprawdzanie [23/99]: The St. Regis La Bahia Blanca Resort, Maroko...
#    🌍 Kraj: Morocco
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [24/99]: One & Only Aesthesis, Ateny...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [25/99]: Forte Village, Sardynia...
#    🌍 Kraj: Italy
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [26/99]: Four Seasons Sharm El Sheikh, Egipt...
#    🌍 Kraj: Egypt
#    📍 Kandydatów po filtrze krajów: 6156/95463 (6.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [27/99]: One & Only Reethi Rah...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [28/99]: Vakkaru...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [29/99]: Six Senses Zil Pasyon...
#    🌍 Kraj: Seychelles
#    📍 Kandydatów po filtrze krajów: 8045/95463 (8.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [30/99]: Fairmont St Andrews, Szkocja...
#    🌍 Kraj: United Kingdom
#    📍 Kandydatów po filtrze krajów: 11446/95463 (12.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [31/99]: The Lodge Hotel, Porto...
#    🌍 Kraj: Portugal
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [32/99]: Banyan Tree Krabi...
#    🌍 Kraj: Thailand
#    📍 Kandydatów po filtrze krajów: 8063/95463 (8.4%)
#    ✅ EXACT MATCH: Banyan Tree Krabi...
#
# Sprawdzanie [33/99]: Mandarin Oriental Jumeira Dubai...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ✅ EXACT MATCH: Hotel mandarin oriental jumeira, dubai...
#
# Sprawdzanie [34/99]: Angsana Corfu Resort...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ✅ EXACT MATCH: Angsana Corfu Resort & Spa...
#
# Sprawdzanie [35/99]: JOALI Being...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [36/99]: Patina Maldives, Fari Islands...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [37/99]: Four Seasons Marakesh, Maroko...
#    🌍 Kraj: Morocco
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [38/99]: Dusit Thani, Pattaya...
#    🌍 Kraj: Thailand
#    📍 Kandydatów po filtrze krajów: 8063/95463 (8.4%)
#    ✅ EXACT MATCH: Dusit Thani Pattaya...
#
# Sprawdzanie [39/99]: Chedi Andermatt, Szwajcaria...
#    🌍 Kraj: Switzerland
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [40/99]: Shangri-La Sydney...
#    🌍 Kraj: Australia
#    📍 Kandydatów po filtrze krajów: 14794/95463 (15.5%)
#    ✅ EXACT MATCH: Shangri-La Sydney...
#
# Sprawdzanie [41/99]: The Stanley, Ateny...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [42/99]: Daios Cove, Kreta...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [43/99]: Romanos, Costa Navarino...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [44/99]: Four Seasons Jimbaran Bay, Bali...
#    🌍 Kraj: Indonesia
#    📍 Kandydatów po filtrze krajów: 12732/95463 (13.3%)
#    ❌ Brak exact matches
#
# Sprawdzanie [45/99]: Hilton Aruba Caribbean Resort & Casino, Aruba...
#    🌍 Kraj: Aruba
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [46/99]: Mandarin Oriental, Costa Navarino...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ✅ EXACT MATCH: Mandarin Oriental, Costa Navarino...
#
# Sprawdzanie [47/99]: Quark Expeditions...
#    🌍 Kraj: Greenland
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [48/99]: JOALI Maldives...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [49/99]: Belmond Reid's Palace, Portugalia...
#    🌍 Kraj: Portugal
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [50/99]: Velaa Private Island...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [51/99]: The Abi d'Oru Hotel & Spa, Sardynia...
#    🌍 Kraj: Italy
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [52/99]: Burj Al Arab...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ❌ Brak exact matches
#
# Sprawdzanie [53/99]: One & Only The Palm...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ❌ Brak exact matches
#
# Sprawdzanie [54/99]: Rosewood Phuket...
#    🌍 Kraj: Thailand
#    📍 Kandydatów po filtrze krajów: 8063/95463 (8.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [55/99]: Wyndham Grand Athens, Ateny...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [56/99]: Ikos Oceania, Chalkidiki...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [57/99]: Saii Phi Phi Island Village Resort, Tajlandia...
#    🌍 Kraj: Thailand
#    📍 Kandydatów po filtrze krajów: 8063/95463 (8.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [58/99]: Raffles Prasiln...
#    🌍 Kraj: Seychelles
#    📍 Kandydatów po filtrze krajów: 8045/95463 (8.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [59/99]: Waldorf Astoria Maldives Ithaafushi...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [60/99]: Regent Phu Quoc Hotel, Wietnam...
#    🌍 Kraj: Vietnam
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [61/99]: The Ritz-Carlton, Jumeirah...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ❌ Brak exact matches
#
# Sprawdzanie [62/99]: METT Marbella Hotel, Hiszpania...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [63/99]: Niyama Private Island...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [64/99]: Hotel Du Palais Biarritz - The Unbound Collection ...
#    🌍 Kraj: France
#    📍 Kandydatów po filtrze krajów: 2938/95463 (3.1%)
#    ❌ Brak exact matches
#
# Sprawdzanie [65/99]: Four Seasons Resort Orlando at Walt Disney World R...
#    🌍 Kraj: United States
#    📍 Kandydatów po filtrze krajów: 12526/95463 (13.1%)
#    ❌ Brak exact matches
#
# Sprawdzanie [66/99]: Mandarin Oriental, Singapur...
#    🌍 Kraj: Singapore
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [67/99]: The Datai, Malezja...
#    🌍 Kraj: Malaysia
#    📍 Kandydatów po filtrze krajów: 545/95463 (0.6%)
#    ❌ Brak exact matches
#
# Sprawdzanie [68/99]: The Betsy Hotel, Miami...
#    🌍 Kraj: United States
#    📍 Kandydatów po filtrze krajów: 12526/95463 (13.1%)
#    ❌ Brak exact matches
#
# Sprawdzanie [69/99]: Ikos Dassia, Korfu...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [70/99]: Puente Romano, Hiszpania...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [71/99]: Domes Zeen, a Luxury Collection Resort, Kreta...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [72/99]: Emerald Resort, Malediwy...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [73/99]: Badrutt's Palace, Szwajcaria...
#    🌍 Kraj: Switzerland
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [74/99]: Four Seasons Resort at Jumeirah Beach...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ❌ Brak exact matches
#
# Sprawdzanie [75/99]: DoubleTree by Hilton Resort & Spa Marjan Island, U...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ❌ Brak exact matches
#
# Sprawdzanie [76/99]: Alpin & Vital Hotel La Perla, Ortisei, Włochy...
#    🌍 Kraj: Italy
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [77/99]: The Retreat at Blue Lagoon Iceland...
#    🌍 Kraj: Iceland
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [78/99]: Jaal Riad Resort, Maroko...
#    🌍 Kraj: Morocco
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [79/99]: The Raffles Doha...
#    🌍 Kraj: Qatar
#    📍 Kandydatów po filtrze krajów: 498/95463 (0.5%)
#    ❌ Brak exact matches
#
# Sprawdzanie [80/99]: Jumeirah at Saadiyat Island Resort, UAE...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ❌ Brak exact matches
#
# Sprawdzanie [81/99]: The Chedi El Gouna, Egipt...
#    🌍 Kraj: Egypt
#    📍 Kandydatów po filtrze krajów: 6156/95463 (6.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [82/99]: El Fuerte Marbella, Hiszpania...
#    🌍 Kraj: Spain
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [83/99]: Fancourt Hotel...
#    🌍 Kraj: South Africa
#    📍 Kandydatów po filtrze krajów: 2938/95463 (3.1%)
#    ❌ Brak exact matches
#
# Sprawdzanie [84/99]: Waldorf Astoria The Palm...
#    🌍 Kraj: United Arab Emirates
#    📍 Kandydatów po filtrze krajów: 25468/95463 (26.7%)
#    ❌ Brak exact matches
#
# Sprawdzanie [85/99]: The Laguna, A Luxury Collection Resort & Spa...
#    🌍 Kraj: Indonesia
#    📍 Kandydatów po filtrze krajów: 12732/95463 (13.3%)
#    ❌ Brak exact matches
#
# Sprawdzanie [86/99]: Six Senses Yao Noi...
#    🌍 Kraj: Thailand
#    📍 Kandydatów po filtrze krajów: 8063/95463 (8.4%)
#    ✅ EXACT MATCH: Six Senses Yao Noi...
#
# Sprawdzanie [87/99]: Le Fitz Roy, Val Thorens...
#    🌍 Kraj: France
#    📍 Kandydatów po filtrze krajów: 2938/95463 (3.1%)
#    ❌ Brak exact matches
#
# Sprawdzanie [88/99]: Sugar Beach Mauritius...
#    🌍 Kraj: Mauritius
#    📍 Kandydatów po filtrze krajów: 17692/95463 (18.5%)
#    ❌ Brak exact matches
#
# Sprawdzanie [89/99]: Lefay Resort Lago Di Garda, Włochy...
#    🌍 Kraj: Italy
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [90/99]: Elivi Skiathos...
#    🌍 Kraj: Greece
#    📍 Kandydatów po filtrze krajów: 8592/95463 (9.0%)
#    ❌ Brak exact matches
#
# Sprawdzanie [91/99]: One & Only Le Saint Geran...
#    🌍 Kraj: Mauritius
#    📍 Kandydatów po filtrze krajów: 17692/95463 (18.5%)
#    ❌ Brak exact matches
#
# Sprawdzanie [92/99]: The St Regis Bali Resort Nusa Dua...
#    🌍 Kraj: Indonesia
#    📍 Kandydatów po filtrze krajów: 12732/95463 (13.3%)
#    ❌ Brak exact matches
#
# Sprawdzanie [93/99]: Explora II...
#    🌍 Kraj: Chile
#    📍 Kandydatów po filtrze krajów: 392/95463 (0.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [94/99]: Lily Beach Resort & Spa, Malediwy...
#    🌍 Kraj: Maldives
#    📍 Kandydatów po filtrze krajów: 7451/95463 (7.8%)
#    ❌ Brak exact matches
#
# Sprawdzanie [95/99]: Tortuga Bay Puntacana Resort & Club, Dominikana...
#    🌍 Kraj: Dominican Republic
#    📍 Kandydatów po filtrze krajów: 5826/95463 (6.1%)
#    ❌ Brak exact matches
#
# Sprawdzanie [96/99]: Ritz Carlton Phulay Bay...
#    🌍 Kraj: Thailand
#    📍 Kandydatów po filtrze krajów: 8063/95463 (8.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [97/99]: Intercontinental Phuket Resort, Tajlandia...
#    🌍 Kraj: Thailand
#    📍 Kandydatów po filtrze krajów: 8063/95463 (8.4%)
#    ❌ Brak exact matches
#
# Sprawdzanie [98/99]: Verdura Golf & Spa Resort, Sycylia...
#    🌍 Kraj: Italy
#    📍 Kandydatów po filtrze krajów: 5620/95463 (5.9%)
#    ❌ Brak exact matches
#
# Sprawdzanie [99/99]: Maxx Royal Belek Golf Resort, Belek...
#    🌍 Kraj: Turkey
#    📍 Kandydatów po filtrze krajów: 0/95463 (0.0%)
#    ❌ Brak exact matches
#
# 🎯 EXACT MATCHING ZAKOŃCZONY!
# ✅ Znaleziono 11 exact matches
# 📊 Coverage exact: 11/99 (11.1%)
# ⚡ Optymalizacja:
#    📊 Porównań wykonanych: 821,697
#    🚫 Pominięto przez filtr krajów: 8,629,140
#    🔥 Reduction: 91.3%
#
# ==================================================
# 🧠 KROK 3: FUZZY DECISION TREE MATCHING
# ==================================================
# Używanie własnego drzewa decyzyjnego z fuzzy features...
# Sprawdzanie 99 hoteli referencyjnych
# Decision Tree Logic:
#   NODE 1: High Similarity (>80%) + Same Country
#   NODE 2: Chain Match + Medium Similarity (>60%)
#   NODE 3: Word Order Match + Same City
#   NODE 4: Phonetic Match + High Partial
#   NODE 5: Token Sort + Medium Overall
#
# Analizowanie [ 1/99]: Regnum Carya Golf & Spa Resort, Turcja...
#    Sprawdzono 500/95463 kandydatów...
#    Sprawdzono 1000/95463 kandydatów...
#    Sprawdzono 1500/95463 kandydatów...
#    Sprawdzono 2000/95463 kandydatów...
#    Sprawdzono 2500/95463 kandydatów...
#    Sprawdzono 3000/95463 kandydatów...
#    Sprawdzono 3500/95463 kandydatów...
#    Sprawdzono 4000/95463 kandydatów...
#    Sprawdzono 4500/95463 kandydatów...
#    Sprawdzono 5000/95463 kandydatów...
#    Sprawdzono 5500/95463 kandydatów...
#    Sprawdzono 6000/95463 kandydatów...
#    Sprawdzono 6500/95463 kandydatów...
#    Sprawdzono 7000/95463 kandydatów...
#    Sprawdzono 7500/95463 kandydatów...
#    Sprawdzono 8000/95463 kandydatów...
#    Sprawdzono 8500/95463 kandydatów...
#    Sprawdzono 9000/95463 kandydatów...
#    Sprawdzono 9500/95463 kandydatów...
#    Sprawdzono 10000/95463 kandydatów...
#    Sprawdzono 10500/95463 kandydatów...
#    Sprawdzono 11000/95463 kandydatów...
#    Sprawdzono 11500/95463 kandydatów...
#    Sprawdzono 12000/95463 kandydatów...
#    Sprawdzono 12500/95463 kandydatów...
#    Sprawdzono 13000/95463 kandydatów...
#    Sprawdzono 13500/95463 kandydatów...
#    Sprawdzono 14000/95463 kandydatów...
#    Sprawdzono 14500/95463 kandydatów...
#    Sprawdzono 15000/95463 kandydatów...
#    Sprawdzono 15500/95463 kandydatów...
#    Sprawdzono 16000/95463 kandydatów...
#    Sprawdzono 16500/95463 kandydatów...
#    Sprawdzono 17000/95463 kandydatów...
#    Sprawdzono 17500/95463 kandydatów...
#    Sprawdzono 18000/95463 kandydatów...
#    Sprawdzono 18500/95463 kandydatów...
#    Sprawdzono 19000/95463 kandydatów...
#    Sprawdzono 19500/95463 kandydatów...
#    Sprawdzono 20000/95463 kandydatów...
#    Sprawdzono 20500/95463 kandydatów...
#    Sprawdzono 21000/95463 kandydatów...
#    Sprawdzono 21500/95463 kandydatów...
#    Sprawdzono 22000/95463 kandydatów...
#    Sprawdzono 22500/95463 kandydatów...
#    Sprawdzono 23000/95463 kandydatów...
#    Sprawdzono 23500/95463 kandydatów...
#    Sprawdzono 24000/95463 kandydatów...
#    Sprawdzono 24500/95463 kandydatów...
#    Sprawdzono 25000/95463 kandydatów...
#    Sprawdzono 25500/95463 kandydatów...
#    Sprawdzono 26000/95463 kandydatów...
#    Sprawdzono 26500/95463 kandydatów...
#    Sprawdzono 27000/95463 kandydatów...
#    Sprawdzono 27500/95463 kandydatów...
#    Sprawdzono 28000/95463 kandydatów...
#    Sprawdzono 28500/95463 kandydatów...
#    Sprawdzono 29000/95463 kandydatów...
#    Sprawdzono 29500/95463 kandydatów...
#    Sprawdzono 30000/95463 kandydatów...
#    Sprawdzono 30500/95463 kandydatów...
#    Sprawdzono 31000/95463 kandydatów...
#    Sprawdzono 31500/95463 kandydatów...
#    Sprawdzono 32000/95463 kandydatów...
#    Sprawdzono 32500/95463 kandydatów...
#    Sprawdzono 33000/95463 kandydatów...
#    Sprawdzono 33500/95463 kandydatów...
#    Sprawdzono 34000/95463 kandydatów...
#    Sprawdzono 34500/95463 kandydatów...
#    Sprawdzono 35000/95463 kandydatów...
#    Sprawdzono 35500/95463 kandydatów...
#    Sprawdzono 36000/95463 kandydatów...
#    Sprawdzono 36500/95463 kandydatów...
#    Sprawdzono 37000/95463 kandydatów...
#    Sprawdzono 37500/95463 kandydatów...
#    Sprawdzono 38000/95463 kandydatów...
#    Sprawdzono 38500/95463 kandydatów...
#    Sprawdzono 39000/95463 kandydatów...
#    Sprawdzono 39500/95463 kandydatów...
#    Sprawdzono 40000/95463 kandydatów...
#    Sprawdzono 40500/95463 kandydatów...
#    Sprawdzono 41000/95463 kandydatów...
#    Sprawdzono 41500/95463 kandydatów...
#    Sprawdzono 42000/95463 kandydatów...
#    Sprawdzono 42500/95463 kandydatów...
#    Sprawdzono 43000/95463 kandydatów...
#    Sprawdzono 43500/95463 kandydatów...
#    Sprawdzono 44000/95463 kandydatów...
#    Sprawdzono 44500/95463 kandydatów...
#    Sprawdzono 45000/95463 kandydatów...
#    Sprawdzono 45500/95463 kandydatów...
#    Sprawdzono 46000/95463 kandydatów...
#    Sprawdzono 46500/95463 kandydatów...
#    Sprawdzono 47000/95463 kandydatów...
#    Sprawdzono 47500/95463 kandydatów...
#    Sprawdzono 48000/95463 kandydatów...
#    Sprawdzono 48500/95463 kandydatów...
#    Sprawdzono 49000/95463 kandydatów...
#    Sprawdzono 49500/95463 kandydatów...
#    Sprawdzono 50000/95463 kandydatów...
#    Sprawdzono 50500/95463 kandydatów...
#    Sprawdzono 51000/95463 kandydatów...
#    Sprawdzono 51500/95463 kandydatów...
#    Sprawdzono 52000/95463 kandydatów...
#    Sprawdzono 52500/95463 kandydatów...
#    Sprawdzono 53000/95463 kandydatów...
#    Sprawdzono 53500/95463 kandydatów...
#    Sprawdzono 54000/95463 kandydatów...
#    Sprawdzono 54500/95463 kandydatów...
#    Sprawdzono 55000/95463 kandydatów...
#    Sprawdzono 55500/95463 kandydatów...
#    Sprawdzono 56000/95463 kandydatów...
#    Sprawdzono 56500/95463 kandydatów...
#    Sprawdzono 57000/95463 kandydatów...
#    Sprawdzono 57500/95463 kandydatów...
#    Sprawdzono 58000/95463 kandydatów...
#    Sprawdzono 58500/95463 kandydatów...
#    Sprawdzono 59000/95463 kandydatów...
#    Sprawdzono 59500/95463 kandydatów...
#    Sprawdzono 60000/95463 kandydatów...
#    Sprawdzono 60500/95463 kandydatów...
#    Sprawdzono 61000/95463 kandydatów...
#    Sprawdzono 61500/95463 kandydatów...
#    Sprawdzono 62000/95463 kandydatów...
#    Sprawdzono 62500/95463 kandydatów...
#    Sprawdzono 63000/95463 kandydatów...
#    Sprawdzono 63500/95463 kandydatów...
#    Sprawdzono 64000/95463 kandydatów...
#    Sprawdzono 64500/95463 kandydatów...
#    Sprawdzono 65000/95463 kandydatów...
#    Sprawdzono 65500/95463 kandydatów...
#    Sprawdzono 66000/95463 kandydatów...
#    Sprawdzono 66500/95463 kandydatów...
#    Sprawdzono 67000/95463 kandydatów...
#    Sprawdzono 67500/95463 kandydatów...
#    Sprawdzono 68000/95463 kandydatów...
#    Sprawdzono 68500/95463 kandydatów...
#    Sprawdzono 69000/95463 kandydatów...
#    Sprawdzono 69500/95463 kandydatów...
#    Sprawdzono 70000/95463 kandydatów...
#    Sprawdzono 70500/95463 kandydatów...
#    Sprawdzono 71000/95463 kandydatów...
#    Sprawdzono 71500/95463 kandydatów...
#    Sprawdzono 72000/95463 kandydatów...
#    Sprawdzono 72500/95463 kandydatów...
#    Sprawdzono 73000/95463 kandydatów...
#    Sprawdzono 73500/95463 kandydatów...
#    Sprawdzono 74000/95463 kandydatów...
#    Sprawdzono 74500/95463 kandydatów...
#    Sprawdzono 75000/95463 kandydatów...
#    Sprawdzono 75500/95463 kandydatów...
#    Sprawdzono 76000/95463 kandydatów...
#    Sprawdzono 76500/95463 kandydatów...
#    Sprawdzono 77000/95463 kandydatów...
#    Sprawdzono 77500/95463 kandydatów...
#    Sprawdzono 78000/95463 kandydatów...
#    Sprawdzono 78500/95463 kandydatów...
#    Sprawdzono 79000/95463 kandydatów...
#    Sprawdzono 79500/95463 kandydatów...
#    Sprawdzono 80000/95463 kandydatów...
#    Sprawdzono 80500/95463 kandydatów...
#    Sprawdzono 81000/95463 kandydatów...
#    Sprawdzono 81500/95463 kandydatów...
#    Sprawdzono 82000/95463 kandydatów...
#    Sprawdzono 82500/95463 kandydatów...
#    Sprawdzono 83000/95463 kandydatów...
#    Sprawdzono 83500/95463 kandydatów...
#    Sprawdzono 84000/95463 kandydatów...
#    Sprawdzono 84500/95463 kandydatów...
#    Sprawdzono 85000/95463 kandydatów...
#    Sprawdzono 85500/95463 kandydatów...
#    Sprawdzono 86000/95463 kandydatów...
#    Sprawdzono 86500/95463 kandydatów...
#    Sprawdzono 87000/95463 kandydatów...
#    Sprawdzono 87500/95463 kandydatów...
#    Sprawdzono 88000/95463 kandydatów...
#    Sprawdzono 88500/95463 kandydatów...
#    Sprawdzono 89000/95463 kandydatów...
#    Sprawdzono 89500/95463 kandydatów...
#    Sprawdzono 90000/95463 kandydatów...
#    Sprawdzono 90500/95463 kandydatów...
#    Sprawdzono 91000/95463 kandydatów...
#    Sprawdzono 91500/95463 kandydatów...
#    Sprawdzono 92000/95463 kandydatów...
#    Sprawdzono 92500/95463 kandydatów...
#    Sprawdzono 93000/95463 kandydatów...
#    Sprawdzono 93500/95463 kandydatów...
#    Sprawdzono 94000/95463 kandydatów...
#    Sprawdzono 94500/95463 kandydatów...
#    Sprawdzono 95000/95463 kandydatów...
#    ❌ Brak matches (best confidence: 0.000)
#
# Analizowanie [ 2/99]: SH Valencia Palace, Walencja...
#    Sprawdzono 500/95463 kandydatów...
#    Sprawdzono 1000/95463 kandydatów...
#    Sprawdzono 1500/95463 kandydatów...
#    Sprawdzono 2000/95463 kandydatów...
#    Sprawdzono 2500/95463 kandydatów...
#    Sprawdzono 3000/95463 kandydatów...
#    Sprawdzono 3500/95463 kandydatów...
#    Sprawdzono 4000/95463 kandydatów...
#    Sprawdzono 4500/95463 kandydatów...
#    Sprawdzono 5000/95463 kandydatów...
#    Sprawdzono 5500/95463 kandydatów...
#    Sprawdzono 6000/95463 kandydatów...
#    Sprawdzono 6500/95463 kandydatów...
#    Sprawdzono 7000/95463 kandydatów...
#    Sprawdzono 7500/95463 kandydatów...
#    Sprawdzono 8000/95463 kandydatów...
#    Sprawdzono 8500/95463 kandydatów...
#    Sprawdzono 9000/95463 kandydatów...
#    Sprawdzono 9500/95463 kandydatów...
#    Sprawdzono 10000/95463 kandydatów...
#    Sprawdzono 10500/95463 kandydatów...
#    Sprawdzono 11000/95463 kandydatów...
#    Sprawdzono 11500/95463 kandydatów...
#    Sprawdzono 12000/95463 kandydatów...
#    Sprawdzono 12500/95463 kandydatów...
#    Sprawdzono 13000/95463 kandydatów...
#    Sprawdzono 13500/95463 kandydatów...
#    Sprawdzono 14000/95463 kandydatów...
#    Sprawdzono 14500/95463 kandydatów...
#    Sprawdzono 15000/95463 kandydatów...
#    Sprawdzono 15500/95463 kandydatów...
#    Sprawdzono 16000/95463 kandydatów...
#    Sprawdzono 16500/95463 kandydatów...
#    Sprawdzono 17000/95463 kandydatów...
#    Sprawdzono 17500/95463 kandydatów...
#    Sprawdzono 18000/95463 kandydatów...
#    Sprawdzono 18500/95463 kandydatów...
#    Sprawdzono 19000/95463 kandydatów...
#    Sprawdzono 19500/95463 kandydatów...
#    Sprawdzono 20000/95463 kandydatów...
#    Sprawdzono 20500/95463 kandydatów...
#    Sprawdzono 21000/95463 kandydatów...
#    Sprawdzono 21500/95463 kandydatów...
#    Sprawdzono 22000/95463 kandydatów...
#    Sprawdzono 22500/95463 kandydatów...
#    Sprawdzono 23000/95463 kandydatów...
#    Sprawdzono 23500/95463 kandydatów...
#    Sprawdzono 24000/95463 kandydatów...
#    Sprawdzono 24500/95463 kandydatów...
#    Sprawdzono 25000/95463 kandydatów...
#    Sprawdzono 25500/95463 kandydatów...
#    Sprawdzono 26000/95463 kandydatów...
#    Sprawdzono 26500/95463 kandydatów...
#    Sprawdzono 27000/95463 kandydatów...
#    Sprawdzono 27500/95463 kandydatów...
#    Sprawdzono 28000/95463 kandydatów...
#    Sprawdzono 28500/95463 kandydatów...
#    Sprawdzono 29000/95463 kandydatów...
#    Sprawdzono 29500/95463 kandydatów...
#    Sprawdzono 30000/95463 kandydatów...
#    Sprawdzono 30500/95463 kandydatów...
#    Sprawdzono 31000/95463 kandydatów...
#    Sprawdzono 31500/95463 kandydatów...
#    Sprawdzono 32000/95463 kandydatów...
#    Sprawdzono 32500/95463 kandydatów...
#    Sprawdzono 33000/95463 kandydatów...
#    Sprawdzono 33500/95463 kandydatów...
#    Sprawdzono 34000/95463 kandydatów...
#    Sprawdzono 34500/95463 kandydatów...
#    Sprawdzono 35000/95463 kandydatów...
#    Sprawdzono 35500/95463 kandydatów...
#    Sprawdzono 36000/95463 kandydatów...
#    Sprawdzono 36500/95463 kandydatów...
#    Sprawdzono 37000/95463 kandydatów...
#    Sprawdzono 37500/95463 kandydatów...
#    Sprawdzono 38000/95463 kandydatów...
#    Sprawdzono 38500/95463 kandydatów...
#    Sprawdzono 39000/95463 kandydatów...
#    Sprawdzono 39500/95463 kandydatów...
#    Sprawdzono 40000/95463 kandydatów...
#    Sprawdzono 40500/95463 kandydatów...
#    Sprawdzono 41000/95463 kandydatów...
#    Sprawdzono 41500/95463 kandydatów...
#    Sprawdzono 42000/95463 kandydatów...
#    Sprawdzono 42500/95463 kandydatów...
#    Sprawdzono 43000/95463 kandydatów...
#    Sprawdzono 43500/95463 kandydatów...
#    Sprawdzono 44000/95463 kandydatów...
#    Sprawdzono 44500/95463 kandydatów...
#    Sprawdzono 45000/95463 kandydatów...
#    Sprawdzono 45500/95463 kandydatów...
#    Sprawdzono 46000/95463 kandydatów...
#    Sprawdzono 46500/95463 kandydatów...
#    Sprawdzono 47000/95463 kandydatów...
#    Sprawdzono 47500/95463 kandydatów...
#    Sprawdzono 48000/95463 kandydatów...
#    Sprawdzono 48500/95463 kandydatów...
#    Sprawdzono 49000/95463 kandydatów...
#    Sprawdzono 49500/95463 kandydatów...
#    Sprawdzono 50000/95463 kandydatów...
#    Sprawdzono 50500/95463 kandydatów...
#    Sprawdzono 51000/95463 kandydatów...
#    Sprawdzono 51500/95463 kandydatów...
#    Sprawdzono 52000/95463 kandydatów...
#    Sprawdzono 52500/95463 kandydatów...
#    Sprawdzono 53000/95463 kandydatów...
#    Sprawdzono 53500/95463 kandydatów...
#    Sprawdzono 54000/95463 kandydatów...
#    Sprawdzono 54500/95463 kandydatów...
#    Sprawdzono 55000/95463 kandydatów...
#    Sprawdzono 55500/95463 kandydatów...
#    Sprawdzono 56000/95463 kandydatów...
#    Sprawdzono 56500/95463 kandydatów...
#    Sprawdzono 57000/95463 kandydatów...
#    Sprawdzono 57500/95463 kandydatów...
#    Sprawdzono 58000/95463 kandydatów...
#    Sprawdzono 58500/95463 kandydatów...
#    Sprawdzono 59000/95463 kandydatów...
#    Sprawdzono 59500/95463 kandydatów...
#    Sprawdzono 60000/95463 kandydatów...
#    Sprawdzono 60500/95463 kandydatów...
#    Sprawdzono 61000/95463 kandydatów...
#    Sprawdzono 61500/95463 kandydatów...
#    Sprawdzono 62000/95463 kandydatów...
#    Sprawdzono 62500/95463 kandydatów...
#    Sprawdzono 63000/95463 kandydatów...
#    Sprawdzono 63500/95463 kandydatów...
#    Sprawdzono 64000/95463 kandydatów...
#    Sprawdzono 64500/95463 kandydatów...
#    Sprawdzono 65000/95463 kandydatów...
#    Sprawdzono 65500/95463 kandydatów...
#    Sprawdzono 66000/95463 kandydatów...
#    Sprawdzono 66500/95463 kandydatów...
#    Sprawdzono 67000/95463 kandydatów...
#    Sprawdzono 67500/95463 kandydatów...
#    Sprawdzono 68000/95463 kandydatów...
#    Sprawdzono 68500/95463 kandydatów...
#    Sprawdzono 69000/95463 kandydatów...
#    Sprawdzono 69500/95463 kandydatów...
#    Sprawdzono 70000/95463 kandydatów...
#    Sprawdzono 70500/95463 kandydatów...
#    Sprawdzono 71000/95463 kandydatów...
#    Sprawdzono 71500/95463 kandydatów...
#    Sprawdzono 72000/95463 kandydatów...
#    Sprawdzono 72500/95463 kandydatów...
#    Sprawdzono 73000/95463 kandydatów...
#    Sprawdzono 73500/95463 kandydatów...
#    Sprawdzono 74000/95463 kandydatów...
#    Sprawdzono 74500/95463 kandydatów...
#    Sprawdzono 75000/95463 kandydatów...
#    Sprawdzono 75500/95463 kandydatów...
#    Sprawdzono 76000/95463 kandydatów...
#    Sprawdzono 76500/95463 kandydatów...
#    Sprawdzono 77000/95463 kandydatów...
#    Sprawdzono 77500/95463 kandydatów...
#    Sprawdzono 78000/95463 kandydatów...
#    Sprawdzono 78500/95463 kandydatów...
#    Sprawdzono 79000/95463 kandydatów...
#    Sprawdzono 79500/95463 kandydatów...
#    Sprawdzono 80000/95463 kandydatów...
#    Sprawdzono 80500/95463 kandydatów...
#    Sprawdzono 81000/95463 kandydatów...
#    Sprawdzono 81500/95463 kandydatów...
#    Sprawdzono 82000/95463 kandydatów...
#    Sprawdzono 82500/95463 kandydatów...
#    Sprawdzono 83000/95463 kandydatów...
#    Sprawdzono 83500/95463 kandydatów...
#    Sprawdzono 84000/95463 kandydatów...
#    Sprawdzono 84500/95463 kandydatów...
#    Sprawdzono 85000/95463 kandydatów...
#    Sprawdzono 85500/95463 kandydatów...
#    Sprawdzono 86000/95463 kandydatów...
#    Sprawdzono 86500/95463 kandydatów...
#    Sprawdzono 87000/95463 kandydatów...
#    Sprawdzono 87500/95463 kandydatów...
#    Sprawdzono 88000/95463 kandydatów...
#    Sprawdzono 88500/95463 kandydatów...
#    Sprawdzono 89000/95463 kandydatów...
#    Sprawdzono 89500/95463 kandydatów...
#    Sprawdzono 90000/95463 kandydatów...
#    Sprawdzono 90500/95463 kandydatów...
#    Sprawdzono 91000/95463 kandydatów...
#    Sprawdzono 91500/95463 kandydatów...
#    Sprawdzono 92000/95463 kandydatów...
#    Sprawdzono 92500/95463 kandydatów...
#    Sprawdzono 93000/95463 kandydatów...
#    Sprawdzono 93500/95463 kandydatów...
#    Sprawdzono 94000/95463 kandydatów...
#    Sprawdzono 94500/95463 kandydatów...
#    Sprawdzono 95000/95463 kandydatów...
#    ❌ Brak matches (best confidence: 0.000)
#
# Analizowanie [ 3/99]: Atlantis The Royal...
#    Sprawdzono 500/95463 kandydatów...
#    Sprawdzono 1000/95463 kandydatów...
#    Sprawdzono 1500/95463 kandydatów...
#    Sprawdzono 2000/95463 kandydatów...
#    Sprawdzono 2500/95463 kandydatów...
#    Sprawdzono 3000/95463 kandydatów...
#    Sprawdzono 3500/95463 kandydatów...
#    Sprawdzono 4000/95463 kandydatów...
#    Sprawdzono 4500/95463 kandydatów...
#    Sprawdzono 5000/95463 kandydatów...
#    Sprawdzono 5500/95463 kandydatów...
#    Sprawdzono 6000/95463 kandydatów...
#    Sprawdzono 6500/95463 kandydatów...
#    Sprawdzono 7000/95463 kandydatów...
#    Sprawdzono 7500/95463 kandydatów...
#    Sprawdzono 8000/95463 kandydatów...
#    Sprawdzono 8500/95463 kandydatów...
#    Sprawdzono 9000/95463 kandydatów...
#    Sprawdzono 9500/95463 kandydatów...
#    Sprawdzono 10000/95463 kandydatów...
#    Sprawdzono 10500/95463 kandydatów...
#    Sprawdzono 11000/95463 kandydatów...
#    Sprawdzono 11500/95463 kandydatów...
#    Sprawdzono 12000/95463 kandydatów...
#    Sprawdzono 12500/95463 kandydatów...
#    Sprawdzono 13000/95463 kandydatów...
#    Sprawdzono 13500/95463 kandydatów...
#    Sprawdzono 14000/95463 kandydatów...
#    Sprawdzono 14500/95463 kandydatów...
#    Sprawdzono 15000/95463 kandydatów...
#    Sprawdzono 15500/95463 kandydatów...
#    Sprawdzono 16000/95463 kandydatów...
#    Sprawdzono 16500/95463 kandydatów...
#    Sprawdzono 17000/95463 kandydatów...
#    Sprawdzono 17500/95463 kandydatów...
#    Sprawdzono 18000/95463 kandydatów...
#    Sprawdzono 18500/95463 kandydatów...
#    Sprawdzono 19000/95463 kandydatów...
#    Sprawdzono 19500/95463 kandydatów...
#    Sprawdzono 20000/95463 kandydatów...
#    Sprawdzono 20500/95463 kandydatów...
#    Sprawdzono 21000/95463 kandydatów...
#    Sprawdzono 21500/95463 kandydatów...
#    Sprawdzono 22000/95463 kandydatów...
#    Sprawdzono 22500/95463 kandydatów...
#    Sprawdzono 23000/95463 kandydatów...
#    Sprawdzono 23500/95463 kandydatów...
#    Sprawdzono 24000/95463 kandydatów...
#    Sprawdzono 24500/95463 kandydatów...
#    Sprawdzono 25000/95463 kandydatów...
#    Sprawdzono 25500/95463 kandydatów...
#    Sprawdzono 26000/95463 kandydatów...
#    Sprawdzono 26500/95463 kandydatów...
#    Sprawdzono 27000/95463 kandydatów...
#    Sprawdzono 27500/95463 kandydatów...
#    Sprawdzono 28000/95463 kandydatów...
#    Sprawdzono 28500/95463 kandydatów...
#    Sprawdzono 29000/95463 kandydatów...
#    Sprawdzono 29500/95463 kandydatów...
#    Sprawdzono 30000/95463 kandydatów...
#    Sprawdzono 30500/95463 kandydatów...
#    Sprawdzono 31000/95463 kandydatów...
#    Sprawdzono 31500/95463 kandydatów...
#    Sprawdzono 32000/95463 kandydatów...
#    Sprawdzono 32500/95463 kandydatów...
#    Sprawdzono 33000/95463 kandydatów...
#    Sprawdzono 33500/95463 kandydatów...
#    Sprawdzono 34000/95463 kandydatów...
#    Sprawdzono 34500/95463 kandydatów...
#    Sprawdzono 35000/95463 kandydatów...
#    Sprawdzono 35500/95463 kandydatów...
#    Sprawdzono 36000/95463 kandydatów...
#    Sprawdzono 36500/95463 kandydatów...
#    Sprawdzono 37000/95463 kandydatów...
#    Sprawdzono 37500/95463 kandydatów...
#    Sprawdzono 38000/95463 kandydatów...
#    Sprawdzono 38500/95463 kandydatów...
#    Sprawdzono 39000/95463 kandydatów...
#    Sprawdzono 39500/95463 kandydatów...
#    Sprawdzono 40000/95463 kandydatów...
#    Sprawdzono 40500/95463 kandydatów...
#    Sprawdzono 41000/95463 kandydatów...
#    Sprawdzono 41500/95463 kandydatów...
#    Sprawdzono 42000/95463 kandydatów...
#    Sprawdzono 42500/95463 kandydatów...
#    Sprawdzono 43000/95463 kandydatów...
#    Sprawdzono 43500/95463 kandydatów...
#    Sprawdzono 44000/95463 kandydatów...
#    Sprawdzono 44500/95463 kandydatów...
#    Sprawdzono 45000/95463 kandydatów...
#    Sprawdzono 45500/95463 kandydatów...
#    Sprawdzono 46000/95463 kandydatów...
#    Sprawdzono 46500/95463 kandydatów...
#    Sprawdzono 47000/95463 kandydatów...
#    Sprawdzono 47500/95463 kandydatów...
#    Sprawdzono 48000/95463 kandydatów...
#    Sprawdzono 48500/95463 kandydatów...
#    Sprawdzono 49000/95463 kandydatów...
#    Sprawdzono 49500/95463 kandydatów...
#    Sprawdzono 50000/95463 kandydatów...
#    Sprawdzono 50500/95463 kandydatów...
#    Sprawdzono 51000/95463 kandydatów...
#    Sprawdzono 51500/95463 kandydatów...
#    Sprawdzono 52000/95463 kandydatów...
#    Sprawdzono 52500/95463 kandydatów...
#    Sprawdzono 53000/95463 kandydatów...
#    Sprawdzono 53500/95463 kandydatów...
#    Sprawdzono 54000/95463 kandydatów...
#    Sprawdzono 54500/95463 kandydatów...
#    Sprawdzono 55000/95463 kandydatów...
#    Sprawdzono 55500/95463 kandydatów...
#    Sprawdzono 56000/95463 kandydatów...
#    Sprawdzono 56500/95463 kandydatów...
#    Sprawdzono 57000/95463 kandydatów...
#    Sprawdzono 57500/95463 kandydatów...
#    Sprawdzono 58000/95463 kandydatów...
#    Sprawdzono 58500/95463 kandydatów...
#    Sprawdzono 59000/95463 kandydatów...
#    Sprawdzono 59500/95463 kandydatów...
#    Sprawdzono 60000/95463 kandydatów...
#    Sprawdzono 60500/95463 kandydatów...
#    Sprawdzono 61000/95463 kandydatów...
#    Sprawdzono 61500/95463 kandydatów...
#    Sprawdzono 62000/95463 kandydatów...
#    Sprawdzono 62500/95463 kandydatów...
#    Sprawdzono 63000/95463 kandydatów...
#    Sprawdzono 63500/95463 kandydatów...
#    Sprawdzono 64000/95463 kandydatów...
#    Sprawdzono 64500/95463 kandydatów...
#    Sprawdzono 65000/95463 kandydatów...
#    Sprawdzono 65500/95463 kandydatów...
#    Sprawdzono 66000/95463 kandydatów...
#    Sprawdzono 66500/95463 kandydatów...
#    Sprawdzono 67000/95463 kandydatów...
#    Sprawdzono 67500/95463 kandydatów...
#    Sprawdzono 68000/95463 kandydatów...
#    Sprawdzono 68500/95463 kandydatów...
#    Sprawdzono 69000/95463 kandydatów...
#    Sprawdzono 69500/95463 kandydatów...
#    Sprawdzono 70000/95463 kandydatów...
#    Sprawdzono 70500/95463 kandydatów...
#    Sprawdzono 71000/95463 kandydatów...
#    Sprawdzono 71500/95463 kandydatów...
#    Sprawdzono 72000/95463 kandydatów...
#    Sprawdzono 72500/95463 kandydatów...
#    Sprawdzono 73000/95463 kandydatów...
#    Sprawdzono 73500/95463 kandydatów...
#    Sprawdzono 74000/95463 kandydatów...
#    Sprawdzono 74500/95463 kandydatów...
#    Sprawdzono 75000/95463 kandydatów...
#    Sprawdzono 75500/95463 kandydatów...
#    Sprawdzono 76000/95463 kandydatów...
#    Sprawdzono 76500/95463 kandydatów...
#    Sprawdzono 77000/95463 kandydatów...
#    Sprawdzono 77500/95463 kandydatów...
#    Sprawdzono 78000/95463 kandydatów...
#    Sprawdzono 78500/95463 kandydatów...
#    Sprawdzono 79000/95463 kandydatów...
#    Sprawdzono 79500/95463 kandydatów...
#    Sprawdzono 80000/95463 kandydatów...
#    Sprawdzono 80500/95463 kandydatów...
#    Sprawdzono 81000/95463 kandydatów...
#    Sprawdzono 81500/95463 kandydatów...
#    Sprawdzono 82000/95463 kandydatów...
#    Sprawdzono 82500/95463 kandydatów...
#    Sprawdzono 83000/95463 kandydatów...
#    Sprawdzono 83500/95463 kandydatów...
#    Sprawdzono 84000/95463 kandydatów...
#    Sprawdzono 84500/95463 kandydatów...
#    Sprawdzono 85000/95463 kandydatów...
#    Sprawdzono 85500/95463 kandydatów...
#    Sprawdzono 86000/95463 kandydatów...
#    Sprawdzono 86500/95463 kandydatów...
#    Sprawdzono 87000/95463 kandydatów...
#    Sprawdzono 87500/95463 kandydatów...
#    Sprawdzono 88000/95463 kandydatów...
#    Sprawdzono 88500/95463 kandydatów...
#    Sprawdzono 89000/95463 kandydatów...
#    Sprawdzono 89500/95463 kandydatów...
#    Sprawdzono 90000/95463 kandydatów...
#    Sprawdzono 90500/95463 kandydatów...
#    Sprawdzono 91000/95463 kandydatów...
#    Sprawdzono 91500/95463 kandydatów...
#    Sprawdzono 92000/95463 kandydatów...
#    Sprawdzono 92500/95463 kandydatów...
#    Sprawdzono 93000/95463 kandydatów...
#    Sprawdzono 93500/95463 kandydatów...
#    Sprawdzono 94000/95463 kandydatów...
#    Sprawdzono 94500/95463 kandydatów...
#    Sprawdzono 95000/95463 kandydatów...
#    ✅ MATCH FOUND: Atlantis The Royal Hotel...
#    📊 Confidence: 0.950
#    🎯 Decision: HIGH_SIMILARITY + SAME_COUNTRY (ratio: 1.00)
#    📋 Top alternatives:
#    Candidate: Atlantis, The Palm... → HIGH_SIMILARITY + SAME_COUNTRY (ratio: 0.83)
#    Candidate: Atlantis The Royal Hotel... → HIGH_SIMILARITY + SAME_COUNTRY (ratio: 1.00)
#
# Analizowanie [ 4/99]: Ikos Porto Petro, Majorka...
#    Sprawdzono 500/95463 kandydatów...
#    Sprawdzono 1000/95463 kandydatów...
#    Sprawdzono 1500/95463 kandydatów...
#    Sprawdzono 2000/95463 kandydatów...
#    Sprawdzono 2500/95463 kandydatów...
#    Sprawdzono 3000/95463 kandydatów...
#    Sprawdzono 3500/95463 kandydatów...
#    Sprawdzono 4000/95463 kandydatów...
#    Sprawdzono 4500/95463 kandydatów...
#    Sprawdzono 5000/95463 kandydatów...
#    Sprawdzono 5500/95463 kandydatów...
#    Sprawdzono 6000/95463 kandydatów...
#    Sprawdzono 6500/95463 kandydatów...
#    Sprawdzono 7000/95463 kandydatów...
#    Sprawdzono 7500/95463 kandydatów...
#    Sprawdzono 8000/95463 kandydatów...
#    Sprawdzono 8500/95463 kandydatów...
#    Sprawdzono 9000/95463 kandydatów...
#    Sprawdzono 9500/95463 kandydatów...
#    Sprawdzono 10000/95463 kandydatów...
#    Sprawdzono 10500/95463 kandydatów...
#    Sprawdzono 11000/95463 kandydatów...
#    Sprawdzono 11500/95463 kandydatów...
#    Sprawdzono 12000/95463 kandydatów...
#    Sprawdzono 12500/95463 kandydatów...
#    Sprawdzono 13000/95463 kandydatów...
#    Sprawdzono 13500/95463 kandydatów...
#    Sprawdzono 14000/95463 kandydatów...
#    Sprawdzono 14500/95463 kandydatów...
#    Sprawdzono 15000/95463 kandydatów...
#    Sprawdzono 15500/95463 kandydatów...
#    Sprawdzono 16000/95463 kandydatów...
#    Sprawdzono 16500/95463 kandydatów...
#    Sprawdzono 17000/95463 kandydatów...
#    Sprawdzono 17500/95463 kandydatów...
#    Sprawdzono 18000/95463 kandydatów...
#    Sprawdzono 18500/95463 kandydatów...
#    Sprawdzono 19000/95463 kandydatów...
#    Sprawdzono 19500/95463 kandydatów...
#    Sprawdzono 20000/95463 kandydatów...
#    Sprawdzono 20500/95463 kandydatów...
#    Sprawdzono 21000/95463 kandydatów...
#    Sprawdzono 21500/95463 kandydatów...
#    Sprawdzono 22000/95463 kandydatów...
#    Sprawdzono 22500/95463 kandydatów...
#    Sprawdzono 23000/95463 kandydatów...
#    Sprawdzono 23500/95463 kandydatów...
#    Sprawdzono 24000/95463 kandydatów...
#    Sprawdzono 24500/95463 kandydatów...
#    Sprawdzono 25000/95463 kandydatów...
#    Sprawdzono 25500/95463 kandydatów...
#    Sprawdzono 26000/95463 kandydatów...
#    Sprawdzono 26500/95463 kandydatów...
#    Sprawdzono 27000/95463 kandydatów...
#    Sprawdzono 27500/95463 kandydatów...
#    Sprawdzono 28000/95463 kandydatów...
#    Sprawdzono 28500/95463 kandydatów...
#    Sprawdzono 29000/95463 kandydatów...
#    Sprawdzono 29500/95463 kandydatów...
#    Sprawdzono 30000/95463 kandydatów...
#    Sprawdzono 30500/95463 kandydatów...
#    Sprawdzono 31000/95463 kandydatów...
#    Sprawdzono 31500/95463 kandydatów...
#    Sprawdzono 32000/95463 kandydatów...
#    Sprawdzono 32500/95463 kandydatów...
#    Sprawdzono 33000/95463 kandydatów...
#    Sprawdzono 33500/95463 kandydatów...
#    Sprawdzono 34000/95463 kandydatów...
#    Sprawdzono 34500/95463 kandydatów...
#    Sprawdzono 35000/95463 kandydatów...
#    Sprawdzono 35500/95463 kandydatów...
#    Sprawdzono 36000/95463 kandydatów...
#    Sprawdzono 36500/95463 kandydatów...
#    Sprawdzono 37000/95463 kandydatów...
#    Sprawdzono 37500/95463 kandydatów...
#    Sprawdzono 38000/95463 kandydatów...
#    Sprawdzono 38500/95463 kandydatów...
#    Sprawdzono 39000/95463 kandydatów...
#    Sprawdzono 39500/95463 kandydatów...
#    Sprawdzono 40000/95463 kandydatów...
#    Sprawdzono 40500/95463 kandydatów...
#    Sprawdzono 41000/95463 kandydatów...
#    Sprawdzono 41500/95463 kandydatów...
#    Sprawdzono 42000/95463 kandydatów...
#    Sprawdzono 42500/95463 kandydatów...
#    Sprawdzono 43000/95463 kandydatów...
#    Sprawdzono 43500/95463 kandydatów...
#    Sprawdzono 44000/95463 kandydatów...
#    Sprawdzono 44500/95463 kandydatów...
#    Sprawdzono 45000/95463 kandydatów...
#    Sprawdzono 45500/95463 kandydatów...
#    Sprawdzono 46000/95463 kandydatów...
#    Sprawdzono 46500/95463 kandydatów...
#    Sprawdzono 47000/95463 kandydatów...
#    Sprawdzono 47500/95463 kandydatów...
#    Sprawdzono 48000/95463 kandydatów...
#    Sprawdzono 48500/95463 kandydatów...
#    Sprawdzono 49000/95463 kandydatów...
#    Sprawdzono 49500/95463 kandydatów...
#    Sprawdzono 50000/95463 kandydatów...
#    Sprawdzono 50500/95463 kandydatów...
#    Sprawdzono 51000/95463 kandydatów...
#    Sprawdzono 51500/95463 kandydatów...
#    Sprawdzono 52000/95463 kandydatów...
#    Sprawdzono 52500/95463 kandydatów...
#    Sprawdzono 53000/95463 kandydatów...
#    Sprawdzono 53500/95463 kandydatów...
#    Sprawdzono 54000/95463 kandydatów...
#    Sprawdzono 54500/95463 kandydatów...
#    Sprawdzono 55000/95463 kandydatów...
#    Sprawdzono 55500/95463 kandydatów...
#    Sprawdzono 56000/95463 kandydatów...
#    Sprawdzono 56500/95463 kandydatów...
#    Sprawdzono 57000/95463 kandydatów...
#    Sprawdzono 57500/95463 kandydatów...
#    Sprawdzono 58000/95463 kandydatów...
#    Sprawdzono 58500/95463 kandydatów...
#    Sprawdzono 59000/95463 kandydatów...
#    Sprawdzono 59500/95463 kandydatów...
#    Sprawdzono 60000/95463 kandydatów...
#    Sprawdzono 60500/95463 kandydatów...
#    Sprawdzono 61000/95463 kandydatów...
#    Sprawdzono 61500/95463 kandydatów...
#    Sprawdzono 62000/95463 kandydatów...
#    Sprawdzono 62500/95463 kandydatów...
#    Sprawdzono 63000/95463 kandydatów...
#    Sprawdzono 63500/95463 kandydatów...
#    Sprawdzono 64000/95463 kandydatów...
#    Sprawdzono 64500/95463 kandydatów...
#    Sprawdzono 65000/95463 kandydatów...
#    Sprawdzono 65500/95463 kandydatów...
#    Sprawdzono 66000/95463 kandydatów...
#    Sprawdzono 66500/95463 kandydatów...
#    Sprawdzono 67000/95463 kandydatów...
#    Sprawdzono 67500/95463 kandydatów...
#    Sprawdzono 68000/95463 kandydatów...
#    Sprawdzono 68500/95463 kandydatów...
#    Sprawdzono 69000/95463 kandydatów...
#    Sprawdzono 69500/95463 kandydatów...
#    Sprawdzono 70000/95463 kandydatów...
#    Sprawdzono 70500/95463 kandydatów...
#    Sprawdzono 71000/95463 kandydatów...
#    Sprawdzono 71500/95463 kandydatów...
#    Sprawdzono 72000/95463 kandydatów...
#    Sprawdzono 72500/95463 kandydatów...
#    Sprawdzono 73000/95463 kandydatów...
#    Sprawdzono 73500/95463 kandydatów...
#    Sprawdzono 74000/95463 kandydatów...
#    Sprawdzono 74500/95463 kandydatów...
#    Sprawdzono 75000/95463 kandydatów...
#    Sprawdzono 75500/95463 kandydatów...
#    Sprawdzono 76000/95463 kandydatów...
#    Sprawdzono 76500/95463 kandydatów...
#    Sprawdzono 77000/95463 kandydatów...
#    Sprawdzono 77500/95463 kandydatów...
#    Sprawdzono 78000/95463 kandydatów...
#    Sprawdzono 78500/95463 kandydatów...
#    Sprawdzono 79000/95463 kandydatów...
#    Sprawdzono 79500/95463 kandydatów...
#    Sprawdzono 80000/95463 kandydatów...
#    Sprawdzono 80500/95463 kandydatów...
#    Sprawdzono 81000/95463 kandydatów...
#    Sprawdzono 81500/95463 kandydatów...
#    Sprawdzono 82000/95463 kandydatów...
#    Sprawdzono 82500/95463 kandydatów...
#    Sprawdzono 83000/95463 kandydatów...
#    Sprawdzono 83500/95463 kandydatów...
#    Sprawdzono 84000/95463 kandydatów...
#    Sprawdzono 84500/95463 kandydatów...
#    Sprawdzono 85000/95463 kandydatów...
#    Sprawdzono 85500/95463 kandydatów...
# ...
#    Sprawdzono 6000/95463 kandydatów...
#    Sprawdzono 6500/95463 kandydatów...
#    Sprawdzono 7000/95463 kandydatów...
#    Sprawdzono 7500/95463 kandydatów...
#    Sprawdzono 8000/95463 kandydatów...
#    Sprawdzono 8500/95463 kandydatów...
#    Sprawdzono 9000/95463 kandydatów...
#    Sprawdzono 9500/95463 kandydatów...
#    Sprawdzono 10000/95463 kandydatów...
#    Sprawdzono 10500/95463 kandydatów...
#    Sprawdzono 11000/95463 kandydatów...
#    Sprawdzono 11500/95463 kandydatów...
#    Sprawdzono 12000/95463 kandydatów...
#    Sprawdzono 12500/95463 kandydatów...
#    Sprawdzono 13000/95463 kandydatów...
#    Sprawdzono 13500/95463 kandydatów...
#    Sprawdzono 14000/95463 kandydatów...
#    Sprawdzono 14500/95463 kandydatów...
#    Sprawdzono 15000/95463 kandydatów...
#    Sprawdzono 15500/95463 kandydatów...
#    Sprawdzono 16000/95463 kandydatów...
#    Sprawdzono 16500/95463 kandydatów...
#    Sprawdzono 17000/95463 kandydatów...
#    Sprawdzono 17500/95463 kandydatów...
#    Sprawdzono 18000/95463 kandydatów...
#    Sprawdzono 18500/95463 kandydatów...
#    Sprawdzono 19000/95463 kandydatów...
#    Sprawdzono 19500/95463 kandydatów...
#    Sprawdzono 20000/95463 kandydatów...
#    Sprawdzono 20500/95463 kandydatów...
#    Sprawdzono 21000/95463 kandydatów...
#    Sprawdzono 21500/95463 kandydatów...
#    Sprawdzono 22000/95463 kandydatów...
#    Sprawdzono 22500/95463 kandydatów...
#    Sprawdzono 23000/95463 kandydatów...
#    Sprawdzono 23500/95463 kandydatów...
#    Sprawdzono 24000/95463 kandydatów...
#    Sprawdzono 24500/95463 kandydatów...
#    Sprawdzono 25000/95463 kandydatów...
#    Sprawdzono 25500/95463 kandydatów...
#    Sprawdzono 26000/95463 kandydatów...
#    Sprawdzono 26500/95463 kandydatów...
#    Sprawdzono 27000/95463 kandydatów...
#    Sprawdzono 27500/95463 kandydatów...
#    Sprawdzono 28000/95463 kandydatów...
#    Sprawdzono 28500/95463 kandydatów...
#    Sprawdzono 29000/95463 kandydatów...
#    Sprawdzono 29500/95463 kandydatów...
#    Sprawdzono 30000/95463 kandydatów...
#    Sprawdzono 30500/95463 kandydatów...
#    Sprawdzono 31000/95463 kandydatów...
#    Sprawdzono 31500/95463 kandydatów...
#    Sprawdzono 32000/95463 kandydatów...
#    Sprawdzono 32500/95463 kandydatów...
#    Sprawdzono 33000/95463 kandydatów...
#    Sprawdzono 33500/95463 kandydatów...
#    Sprawdzono 34000/95463 kandydatów...
#    Sprawdzono 34500/95463 kandydatów...
#    Sprawdzono 35000/95463 kandydatów...
#    Sprawdzono 35500/95463 kandydatów...
#    Sprawdzono 36000/95463 kandydatów...
#    Sprawdzono 36500/95463 kandydatów...
#    Sprawdzono 37000/95463 kandydatów...
#    Sprawdzono 37500/95463 kandydatów...
#    Sprawdzono 38000/95463 kandydatów...
#    Sprawdzono 38500/95463 kandydatów...
#    Sprawdzono 39000/95463 kandydatów...
#    Sprawdzono 39500/95463 kandydatów...
#    Sprawdzono 40000/95463 kandydatów...
#    Sprawdzono 40500/95463 kandydatów...
#    Sprawdzono 41000/95463 kandydatów...
#    Sprawdzono 41500/95463 kandydatów...
#    Sprawdzono 42000/95463 kandydatów...
#    Sprawdzono 42500/95463 kandydatów...
#    Sprawdzono 43000/95463 kandydatów...
#    Sprawdzono 43500/95463 kandydatów...
#    Sprawdzono 44000/95463 kandydatów...
#    Sprawdzono 44500/95463 kandydatów...
#    Sprawdzono 45000/95463 kandydatów...
#    Sprawdzono 45500/95463 kandydatów...
#    Sprawdzono 46000/95463 kandydatów...
#    Sprawdzono 46500/95463 kandydatów...
#    Sprawdzono 47000/95463 kandydatów...
#    Sprawdzono 47500/95463 kandydatów...
#    Sprawdzono 48000/95463 kandydatów...
#    Sprawdzono 48500/95463 kandydatów...
#    Sprawdzono 49000/95463 kandydatów...
#    Sprawdzono 49500/95463 kandydatów...
#    Sprawdzono 50000/95463 kandydatów...
#    Sprawdzono 50500/95463 kandydatów...
#    Sprawdzono 51000/95463 kandydatów...
#    Sprawdzono 51500/95463 kandydatów...
#    Sprawdzono 52000/95463 kandydatów...
#    Sprawdzono 52500/95463 kandydatów...
#    Sprawdzono 53000/95463 kandydatów...
#    Sprawdzono 53500/95463 kandydatów...
#    Sprawdzono 54000/95463 kandydatów...
#    Sprawdzono 54500/95463 kandydatów...
#    Sprawdzono 55000/95463 kandydatów...
#    Sprawdzono 55500/95463 kandydatów...
#    Sprawdzono 56000/95463 kandydatów...
#    Sprawdzono 56500/95463 kandydatów...
#    Sprawdzono 57000/95463 kandydatów...
#    Sprawdzono 57500/95463 kandydatów...
#    Sprawdzono 58000/95463 kandydatów...
#    Sprawdzono 58500/95463 kandydatów...
#    Sprawdzono 59000/95463 kandydatów...
#    Sprawdzono 59500/95463 kandydatów...
#    Sprawdzono 60000/95463 kandydatów...
#    Sprawdzono 60500/95463 kandydatów...
#    Sprawdzono 61000/95463 kandydatów...
#    Sprawdzono 61500/95463 kandydatów...
#    Sprawdzono 62000/95463 kandydatów...
#    Sprawdzono 62500/95463 kandydatów...
#    Sprawdzono 63000/95463 kandydatów...
#    Sprawdzono 63500/95463 kandydatów...
#    Sprawdzono 64000/95463 kandydatów...
#    Sprawdzono 64500/95463 kandydatów...
#    Sprawdzono 65000/95463 kandydatów...
#    Sprawdzono 65500/95463 kandydatów...
#    Sprawdzono 66000/95463 kandydatów...
#    Sprawdzono 66500/95463 kandydatów...
#    Sprawdzono 67000/95463 kandydatów...
#    Sprawdzono 67500/95463 kandydatów...
#    Sprawdzono 68000/95463 kandydatów...
#    Sprawdzono 68500/95463 kandydatów...
#    Sprawdzono 69000/95463 kandydatów...
#    Sprawdzono 69500/95463 kandydatów...
#    Sprawdzono 70000/95463 kandydatów...
#    Sprawdzono 70500/95463 kandydatów...
#    Sprawdzono 71000/95463 kandydatów...
#    Sprawdzono 71500/95463 kandydatów...
#    Sprawdzono 72000/95463 kandydatów...
#    Sprawdzono 72500/95463 kandydatów...
#    Sprawdzono 73000/95463 kandydatów...
#    Sprawdzono 73500/95463 kandydatów...
#    Sprawdzono 74000/95463 kandydatów...
#    Sprawdzono 74500/95463 kandydatów...
#    Sprawdzono 75000/95463 kandydatów...
#    Sprawdzono 75500/95463 kandydatów...
#    Sprawdzono 76000/95463 kandydatów...
#    Sprawdzono 76500/95463 kandydatów...
#    Sprawdzono 77000/95463 kandydatów...
#    Sprawdzono 77500/95463 kandydatów...
#    Sprawdzono 78000/95463 kandydatów...
#    Sprawdzono 78500/95463 kandydatów...
#    Sprawdzono 79000/95463 kandydatów...
#    Sprawdzono 79500/95463 kandydatów...
#    Sprawdzono 80000/95463 kandydatów...
#    Sprawdzono 80500/95463 kandydatów...
#    Sprawdzono 81000/95463 kandydatów...
#    Sprawdzono 81500/95463 kandydatów...
#    Sprawdzono 82000/95463 kandydatów...
#    Sprawdzono 82500/95463 kandydatów...
#    Sprawdzono 83000/95463 kandydatów...
#    Sprawdzono 83500/95463 kandydatów...
#    Sprawdzono 84000/95463 kandydatów...
#    Sprawdzono 84500/95463 kandydatów...
#    Sprawdzono 85000/95463 kandydatów...
#    Sprawdzono 85500/95463 kandydatów...
#    Sprawdzono 86000/95463 kandydatów...
#    Sprawdzono 86500/95463 kandydatów...
#    Sprawdzono 87000/95463 kandydatów...
#    Sprawdzono 87500/95463 kandydatów...
#    Sprawdzono 88000/95463 kandydatów...
#    Sprawdzono 88500/95463 kandydatów...
#    Sprawdzono 89000/95463 kandydatów...
#    Sprawdzono 89500/95463 kandydatów...
#    Sprawdzono 90000/95463 kandydatów...
#    Sprawdzono 90500/95463 kandydatów...
#    Sprawdzono 91000/95463 kandydatów...
#    Sprawdzono 91500/95463 kandydatów...
#    Sprawdzono 92000/95463 kandydatów...
#    Sprawdzono 92500/95463 kandydatów...
#    Sprawdzono 93000/95463 kandydatów...
#    Sprawdzono 93500/95463 kandydatów...
#    Sprawdzono 94000/95463 kandydatów...
#    Sprawdzono 94500/95463 kandydatów...
#    Sprawdzono 95000/95463 kandydatów...
#    ❌ Brak matches (best confidence: 0.000)
#
# Analizowanie [99/99]: Maxx Royal Belek Golf Resort, Belek...
#    Sprawdzono 500/95463 kandydatów...
#    Sprawdzono 1000/95463 kandydatów...
#    Sprawdzono 1500/95463 kandydatów...
#    Sprawdzono 2000/95463 kandydatów...
#    Sprawdzono 2500/95463 kandydatów...
#    Sprawdzono 3000/95463 kandydatów...
#    Sprawdzono 3500/95463 kandydatów...
#    Sprawdzono 4000/95463 kandydatów...
#    Sprawdzono 4500/95463 kandydatów...
#    Sprawdzono 5000/95463 kandydatów...
#    Sprawdzono 5500/95463 kandydatów...
#    Sprawdzono 6000/95463 kandydatów...
#    Sprawdzono 6500/95463 kandydatów...
#    Sprawdzono 7000/95463 kandydatów...
#    Sprawdzono 7500/95463 kandydatów...
#    Sprawdzono 8000/95463 kandydatów...
#    Sprawdzono 8500/95463 kandydatów...
#    Sprawdzono 9000/95463 kandydatów...
#    Sprawdzono 9500/95463 kandydatów...
#    Sprawdzono 10000/95463 kandydatów...
#    Sprawdzono 10500/95463 kandydatów...
#    Sprawdzono 11000/95463 kandydatów...
#    Sprawdzono 11500/95463 kandydatów...
#    Sprawdzono 12000/95463 kandydatów...
#    Sprawdzono 12500/95463 kandydatów...
#    Sprawdzono 13000/95463 kandydatów...
#    Sprawdzono 13500/95463 kandydatów...
#    Sprawdzono 14000/95463 kandydatów...
#    Sprawdzono 14500/95463 kandydatów...
#    Sprawdzono 15000/95463 kandydatów...
#    Sprawdzono 15500/95463 kandydatów...
#    Sprawdzono 16000/95463 kandydatów...
#    Sprawdzono 16500/95463 kandydatów...
#    Sprawdzono 17000/95463 kandydatów...
#    Sprawdzono 17500/95463 kandydatów...
#    Sprawdzono 18000/95463 kandydatów...
#    Sprawdzono 18500/95463 kandydatów...
#    Sprawdzono 19000/95463 kandydatów...
#    Sprawdzono 19500/95463 kandydatów...
#    Sprawdzono 20000/95463 kandydatów...
#    Sprawdzono 20500/95463 kandydatów...
#    Sprawdzono 21000/95463 kandydatów...
#    Sprawdzono 21500/95463 kandydatów...
#    Sprawdzono 22000/95463 kandydatów...
#    Sprawdzono 22500/95463 kandydatów...
#    Sprawdzono 23000/95463 kandydatów...
#    Sprawdzono 23500/95463 kandydatów...
#    Sprawdzono 24000/95463 kandydatów...
#    Sprawdzono 24500/95463 kandydatów...
#    Sprawdzono 25000/95463 kandydatów...
#    Sprawdzono 25500/95463 kandydatów...
#    Sprawdzono 26000/95463 kandydatów...
#    Sprawdzono 26500/95463 kandydatów...
#    Sprawdzono 27000/95463 kandydatów...
#    Sprawdzono 27500/95463 kandydatów...
#    Sprawdzono 28000/95463 kandydatów...
#    Sprawdzono 28500/95463 kandydatów...
#    Sprawdzono 29000/95463 kandydatów...
#    Sprawdzono 29500/95463 kandydatów...
#    Sprawdzono 30000/95463 kandydatów...
#    Sprawdzono 30500/95463 kandydatów...
#    Sprawdzono 31000/95463 kandydatów...
#    Sprawdzono 31500/95463 kandydatów...
#    Sprawdzono 32000/95463 kandydatów...
#    Sprawdzono 32500/95463 kandydatów...
#    Sprawdzono 33000/95463 kandydatów...
#    Sprawdzono 33500/95463 kandydatów...
#    Sprawdzono 34000/95463 kandydatów...
#    Sprawdzono 34500/95463 kandydatów...
#    Sprawdzono 35000/95463 kandydatów...
#    Sprawdzono 35500/95463 kandydatów...
#    Sprawdzono 36000/95463 kandydatów...
#    Sprawdzono 36500/95463 kandydatów...
#    Sprawdzono 37000/95463 kandydatów...
#    Sprawdzono 37500/95463 kandydatów...
#    Sprawdzono 38000/95463 kandydatów...
#    Sprawdzono 38500/95463 kandydatów...
#    Sprawdzono 39000/95463 kandydatów...
#    Sprawdzono 39500/95463 kandydatów...
#    Sprawdzono 40000/95463 kandydatów...
#    Sprawdzono 40500/95463 kandydatów...
#    Sprawdzono 41000/95463 kandydatów...
#    Sprawdzono 41500/95463 kandydatów...
#    Sprawdzono 42000/95463 kandydatów...
#    Sprawdzono 42500/95463 kandydatów...
#    Sprawdzono 43000/95463 kandydatów...
#    Sprawdzono 43500/95463 kandydatów...
#    Sprawdzono 44000/95463 kandydatów...
#    Sprawdzono 44500/95463 kandydatów...
#    Sprawdzono 45000/95463 kandydatów...
#    Sprawdzono 45500/95463 kandydatów...
#    Sprawdzono 46000/95463 kandydatów...
#    Sprawdzono 46500/95463 kandydatów...
#    Sprawdzono 47000/95463 kandydatów...
#    Sprawdzono 47500/95463 kandydatów...
#    Sprawdzono 48000/95463 kandydatów...
#    Sprawdzono 48500/95463 kandydatów...
#    Sprawdzono 49000/95463 kandydatów...
#    Sprawdzono 49500/95463 kandydatów...
#    Sprawdzono 50000/95463 kandydatów...
#    Sprawdzono 50500/95463 kandydatów...
#    Sprawdzono 51000/95463 kandydatów...
#    Sprawdzono 51500/95463 kandydatów...
#    Sprawdzono 52000/95463 kandydatów...
#    Sprawdzono 52500/95463 kandydatów...
#    Sprawdzono 53000/95463 kandydatów...
#    Sprawdzono 53500/95463 kandydatów...
#    Sprawdzono 54000/95463 kandydatów...
#    Sprawdzono 54500/95463 kandydatów...
#    Sprawdzono 55000/95463 kandydatów...
#    Sprawdzono 55500/95463 kandydatów...
#    Sprawdzono 56000/95463 kandydatów...
#    Sprawdzono 56500/95463 kandydatów...
#    Sprawdzono 57000/95463 kandydatów...
#    Sprawdzono 57500/95463 kandydatów...
#    Sprawdzono 58000/95463 kandydatów...
#    Sprawdzono 58500/95463 kandydatów...
#    Sprawdzono 59000/95463 kandydatów...
#    Sprawdzono 59500/95463 kandydatów...
#    Sprawdzono 60000/95463 kandydatów...
#    Sprawdzono 60500/95463 kandydatów...
#    Sprawdzono 61000/95463 kandydatów...
#    Sprawdzono 61500/95463 kandydatów...
#    Sprawdzono 62000/95463 kandydatów...
#    Sprawdzono 62500/95463 kandydatów...
#    Sprawdzono 63000/95463 kandydatów...
#    Sprawdzono 63500/95463 kandydatów...
#    Sprawdzono 64000/95463 kandydatów...
#    Sprawdzono 64500/95463 kandydatów...
#    Sprawdzono 65000/95463 kandydatów...
#    Sprawdzono 65500/95463 kandydatów...
#    Sprawdzono 66000/95463 kandydatów...
#    Sprawdzono 66500/95463 kandydatów...
#    Sprawdzono 67000/95463 kandydatów...
#    Sprawdzono 67500/95463 kandydatów...
#    Sprawdzono 68000/95463 kandydatów...
#    Sprawdzono 68500/95463 kandydatów...
#    Sprawdzono 69000/95463 kandydatów...
#    Sprawdzono 69500/95463 kandydatów...
#    Sprawdzono 70000/95463 kandydatów...
#    Sprawdzono 70500/95463 kandydatów...
#    Sprawdzono 71000/95463 kandydatów...
#    Sprawdzono 71500/95463 kandydatów...
#    Sprawdzono 72000/95463 kandydatów...
#    Sprawdzono 72500/95463 kandydatów...
#    Sprawdzono 73000/95463 kandydatów...
#    Sprawdzono 73500/95463 kandydatów...
#    Sprawdzono 74000/95463 kandydatów...
#    Sprawdzono 74500/95463 kandydatów...
#    Sprawdzono 75000/95463 kandydatów...
#    Sprawdzono 75500/95463 kandydatów...
#    Sprawdzono 76000/95463 kandydatów...
#    Sprawdzono 76500/95463 kandydatów...
#    Sprawdzono 77000/95463 kandydatów...
#    Sprawdzono 77500/95463 kandydatów...
#    Sprawdzono 78000/95463 kandydatów...
#    Sprawdzono 78500/95463 kandydatów...
#    Sprawdzono 79000/95463 kandydatów...
#    Sprawdzono 79500/95463 kandydatów...
#    Sprawdzono 80000/95463 kandydatów...
#    Sprawdzono 80500/95463 kandydatów...
#    Sprawdzono 81000/95463 kandydatów...
#    Sprawdzono 81500/95463 kandydatów...
#    Sprawdzono 82000/95463 kandydatów...
#    Sprawdzono 82500/95463 kandydatów...
#    Sprawdzono 83000/95463 kandydatów...
#    Sprawdzono 83500/95463 kandydatów...
#    Sprawdzono 84000/95463 kandydatów...
#    Sprawdzono 84500/95463 kandydatów...
#    Sprawdzono 85000/95463 kandydatów...
#    Sprawdzono 85500/95463 kandydatów...
#    Sprawdzono 86000/95463 kandydatów...
#    Sprawdzono 86500/95463 kandydatów...
#    Sprawdzono 87000/95463 kandydatów...
#    Sprawdzono 87500/95463 kandydatów...
#    Sprawdzono 88000/95463 kandydatów...
#    Sprawdzono 88500/95463 kandydatów...
#    Sprawdzono 89000/95463 kandydatów...
#    Sprawdzono 89500/95463 kandydatów...
#    Sprawdzono 90000/95463 kandydatów...
#    Sprawdzono 90500/95463 kandydatów...
#    Sprawdzono 91000/95463 kandydatów...
#    Sprawdzono 91500/95463 kandydatów...
#    Sprawdzono 92000/95463 kandydatów...
#    Sprawdzono 92500/95463 kandydatów...
#    Sprawdzono 93000/95463 kandydatów...
#    Sprawdzono 93500/95463 kandydatów...
#    Sprawdzono 94000/95463 kandydatów...
#    Sprawdzono 94500/95463 kandydatów...
#    Sprawdzono 95000/95463 kandydatów...
#    ❌ Brak matches (best confidence: 0.000)
#
# 🧠 FUZZY DECISION MATCHING ZAKOŃCZONY!
# ✅ Znaleziono 48 fuzzy matches
# 📊 Coverage fuzzy: 48/99 (48.5%)
#
# ==================================================
# 🔗 KROK 4: KOMBINOWANIE WYNIKÓW
# ==================================================
# 📊 Exact matches: 11
# 📊 Nowe fuzzy matches: 37
# 📊 Duplikaty pominięte: 11
# 📊 Łączne matches: 48
#
# ==================================================
# 📈 KROK 5: GENEROWANIE RAPORTÓW
# ==================================================
# 🎯 FINAL RESULTS:
#    📚 Hoteli referencyjnych: 99
#    📡 Hoteli z API: 95,463
#    ✅ Exact matches: 11
#    🧠 Fuzzy matches: 37
#    🎯 Total matches: 48
#    📊 Coverage: 48.5%
#
# 📊 CONFIDENCE DISTRIBUTION:
#    🟢 High confidence (≥0.9): 20
#    🟡 Medium confidence (0.7-0.9): 27
#    🔴 Low confidence (<0.7): 1
#
# Zapisywanie wyników...
# Zapisano: hotel_mapping_reference_with_iso.csv
# Zapisano: hotel_mapping_matches.csv
# Zapisano: hotel_mapping_summary.csv
#
# Coverage: 48.5% (48/99)
#
# ============================================================
# SIMPLE DECISION TREE MATCHING ZAKOŃCZONY!
# ============================================================

# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
import re
import phonetics
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

class ISOHotelMatcher:
    def __init__(self):
        self.reference_hotels = None
        self.api_hotels = None
        self.iso_mappings = self._create_iso_mappings()
        self.country_to_iso = self._create_reverse_iso_lookup()
        self.luxury_brands = self._create_luxury_brands()
        
    def _create_iso_mappings(self) -> Dict[str, Dict]:
        return {
            'AE': {
                'iso_code': 'AE',
                'official_name': 'United Arab Emirates',
                'variants': ['UAE', 'U.A.E', 'United Arab Emirates', 'Emiraty Arabskie', 'Zjednoczone Emiraty Arabskie']
            },
            'TH': {
                'iso_code': 'TH',
                'official_name': 'Thailand', 
                'variants': ['Thailand', 'Tajlandia', 'Siam', 'Kingdom of Thailand']
            },
            'SC': {
                'iso_code': 'SC',
                'official_name': 'Seychelles',
                'variants': ['Seychelles', 'Seszele', 'Republic of Seychelles', 'Sesel']
            },
            'TR': {
                'iso_code': 'TR',
                'official_name': 'Turkey',
                'variants': ['Turkey', 'Turcja', 'Türkiye', 'Republic of Turkey']
            },
            'ES': {
                'iso_code': 'ES', 
                'official_name': 'Spain',
                'variants': ['Spain', 'Hiszpania', 'España', 'Kingdom of Spain']
            },
            'ME': {
                'iso_code': 'ME',
                'official_name': 'Montenegro',
                'variants': ['Montenegro', 'Czarnogóra', 'Crna Gora']
            },
            'IT': {
                'iso_code': 'IT',
                'official_name': 'Italy',
                'variants': ['Italy', 'Włochy', 'Italia', 'Italian Republic']
            },
            'MY': {
                'iso_code': 'MY',
                'official_name': 'Malaysia',
                'variants': ['Malaysia', 'Malezja']
            },
            'MV': {
                'iso_code': 'MV',
                'official_name': 'Maldives',
                'variants': ['Maldives', 'Malediwy', 'Republic of Maldives']
            },
            'GR': {
                'iso_code': 'GR',
                'official_name': 'Greece',
                'variants': ['Greece', 'Grecja', 'Hellas', 'Hellenic Republic']
            },
            'MA': {
                'iso_code': 'MA',
                'official_name': 'Morocco',
                'variants': ['Morocco', 'Maroko', 'Kingdom of Morocco']
            },
            'EG': {
                'iso_code': 'EG',
                'official_name': 'Egypt',
                'variants': ['Egypt', 'Egipt', 'Arab Republic of Egypt']
            },
            'MU': {
                'iso_code': 'MU',
                'official_name': 'Mauritius',
                'variants': ['Mauritius', 'Republic of Mauritius']
            },
            'GB': {
                'iso_code': 'GB',
                'official_name': 'United Kingdom',
                'variants': ['United Kingdom', 'Wielka Brytania', 'UK', 'Great Britain']
            },
            'PT': {
                'iso_code': 'PT',
                'official_name': 'Portugal',
                'variants': ['Portugal', 'Portugalia', 'Portuguese Republic']
            },
            'CH': {
                'iso_code': 'CH',
                'official_name': 'Switzerland',
                'variants': ['Switzerland', 'Szwajcaria', 'Swiss Confederation']
            },
            'AU': {
                'iso_code': 'AU',
                'official_name': 'Australia',
                'variants': ['Australia', 'Commonwealth of Australia']
            },
            'ID': {
                'iso_code': 'ID',
                'official_name': 'Indonesia',
                'variants': ['Indonesia', 'Indonezja', 'Republic of Indonesia']
            },
            'AW': {
                'iso_code': 'AW',
                'official_name': 'Aruba',
                'variants': ['Aruba']
            },
            'GL': {
                'iso_code': 'GL',
                'official_name': 'Greenland',
                'variants': ['Greenland', 'Grenlandia']
            },
            'VN': {
                'iso_code': 'VN',
                'official_name': 'Vietnam',
                'variants': ['Vietnam', 'Wietnam', 'Socialist Republic of Vietnam']
            },
            'FR': {
                'iso_code': 'FR',
                'official_name': 'France',
                'variants': ['France', 'Francja', 'French Republic']
            },
            'US': {
                'iso_code': 'US',
                'official_name': 'United States',
                'variants': ['United States', 'USA', 'US', 'America']
            },
            'SG': {
                'iso_code': 'SG',
                'official_name': 'Singapore',
                'variants': ['Singapore', 'Singapur', 'Republic of Singapore']
            },
            'IS': {
                'iso_code': 'IS',
                'official_name': 'Iceland',
                'variants': ['Iceland', 'Islandia', 'Republic of Iceland']
            },
            'QA': {
                'iso_code': 'QA',
                'official_name': 'Qatar',
                'variants': ['Qatar', 'State of Qatar']
            },
            'ZA': {
                'iso_code': 'ZA',
                'official_name': 'South Africa',
                'variants': ['South Africa', 'RPA', 'Republic of South Africa']
            },
            'DO': {
                'iso_code': 'DO',
                'official_name': 'Dominican Republic',
                'variants': ['Dominican Republic', 'Dominikana']
            },
            'CL': {
                'iso_code': 'CL',
                'official_name': 'Chile',
                'variants': ['Chile', 'Republic of Chile', 'Explora']
            }
        }
    
    def _create_reverse_iso_lookup(self) -> Dict[str, str]:
        lookup = {}
        for iso_code, data in self.iso_mappings.items():
            for variant in data['variants']:
                lookup[variant.lower().strip()] = iso_code
        return lookup
    
    def _create_luxury_brands(self) -> List[str]:
        return [
            'four seasons', 'atlantis', 'banyan tree', 'mandarin oriental',
            'one only', 'angsana', 'shangri-la', 'ritz carlton', 'ritz-carlton',
            'st regis', 'waldorf astoria', 'hilton', 'marriott', 'hyatt',
            'intercontinental', 'sheraton', 'westin', 'doubletree', 'regent',
            'fairmont', 'raffles', 'rosewood', 'belmond', 'six senses',
            'chedi', 'dusit thani', 'movenpick', 'mövenpick'
        ]
    
    def _map_country_to_iso(self, country_str: str) -> Optional[str]:
        if not country_str:
            return None
        
        country_clean = country_str.lower().strip()
        return self.country_to_iso.get(country_clean)
    
    def _extract_brand(self, hotel_name: str) -> Optional[str]:
        if not hotel_name:
            return None
        
        name_lower = hotel_name.lower()
        for brand in self.luxury_brands:
            if brand in name_lower:
                return brand
        return None
    
    def _normalize_hotel_name(self, name: str) -> str:
        if pd.isna(name) or not name:
            return ""
        
        name = str(name).lower().strip()
        name = re.sub(r'[^\w\s]', ' ', name)
        
        stop_words = [
            'hotel', 'resort', 'spa', 'suites', 'inn', 'lodge', 
            'motel', 'palace', 'club', 'grand', 'royal', 'the', 'at'
        ]
        
        words = [word for word in name.split() if word not in stop_words and len(word) > 1]
        
        seen = set()
        unique_words = []
        for word in words:
            if word not in seen:
                unique_words.append(word)
                seen.add(word)
        
        return ' '.join(unique_words)
    
    def _normalize_city_name(self, city: str) -> str:
        if not city:
            return ""
        
        city_mappings = {
            'dubaj': 'dubai',
            'krabi': 'krabi',
            'desroches': 'desroches island'
        }
        
        city_clean = city.lower().strip()
        return city_mappings.get(city_clean, city_clean)
    
    def load_reference_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📂 LOADING REFERENCE HOTELS")
        print("="*60)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Loaded file: {csv_path}")
            print(f"📊 Found {len(df)} reference hotels")
        except Exception as e:
            print(f"❌ Error loading file: {e}")
            return None
        
        print("\n🧹 Processing reference data...")
        df['clean_location'] = df['Lokalizacja'].str.strip()
        df['clean_hotel'] = df['Hotel'].str.strip()
        
        df[['country_raw', 'city_raw']] = df['clean_location'].str.split(',', n=1, expand=True)
        df['country_raw'] = df['country_raw'].fillna('').str.strip()
        df['city_raw'] = df['city_raw'].fillna('').str.strip()
        
        print("🌍 Mapping countries to ISO codes...")
        df['country_iso'] = df['country_raw'].apply(self._map_country_to_iso)
        
        unmapped_countries = df[df['country_iso'].isna()]['country_raw'].unique()
        if len(unmapped_countries) > 0:
            print(f"⚠️  Unmapped countries: {list(unmapped_countries)}")
        
        df['city'] = df['city_raw'].apply(self._normalize_city_name)
        df['normalized_name'] = df['clean_hotel'].apply(self._normalize_hotel_name)
        df['brand'] = df['clean_hotel'].apply(self._extract_brand)
        df['reference_id'] = df.index.astype(str).str.zfill(3)
        
        country_stats = df['country_iso'].value_counts()
        print(f"📈 Countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count} hotels")
        
        brands_found = df['brand'].dropna().nunique()
        print(f"🏨 Luxury brands detected: {brands_found}")
        
        self.reference_hotels = df
        print(f"✅ Processed {len(df)} reference hotels")
        return df
    
    def load_api_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📡 LOADING API HOTELS")
        print("="*60)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Loaded file: {csv_path}")
            print(f"📊 Found {len(df):,} API hotels")
        except Exception as e:
            print(f"❌ Error loading file: {e}")
            return None
        
        print("\n🧹 Processing API data...")
        df['clean_name'] = df['name'].fillna('').str.strip()
        df['clean_city'] = df['city'].fillna('').str.strip()
        df['clean_address'] = df['address'].fillna('').str.strip()
        df['clean_chain'] = df['hotel_chain'].fillna('').str.strip()
        
        df['country_iso'] = df['country'].fillna('').str.upper().str.strip()
        df['normalized_name'] = df['clean_name'].apply(self._normalize_hotel_name)
        df['city_normalized'] = df['clean_city'].apply(self._normalize_city_name)
        
        df['lat'] = pd.to_numeric(df['latitude'], errors='coerce')
        df['lng'] = pd.to_numeric(df['longitude'], errors='coerce')
        
        country_stats = df['country_iso'].value_counts()
        print(f"🌍 API countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count:,} hotels")
        
        coords_valid = df[['lat', 'lng']].notna().all(axis=1).sum()
        print(f"📍 Hotels with coordinates: {coords_valid:,}/{len(df):,} ({coords_valid/len(df)*100:.1f}%)")
        
        chain_stats = df[df['clean_chain'] != '']['clean_chain'].value_counts()
        print(f"🏨 Top 3 hotel chains:")
        for chain, count in chain_stats.head(3).items():
            print(f"   {chain}: {count:,} hotels")
        
        self.api_hotels = df
        print(f"✅ Processed {len(df):,} API hotels")
        return df
    
    def _calculate_features(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return self._empty_features()
        
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'country_exact': ref_hotel['country_iso'] == api_hotel['country_iso'],
            'city_similarity': self._city_similarity(ref_hotel['city'], api_hotel['city_normalized']),
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        return features
    
    def _empty_features(self) -> Dict:
        return {
            'fuzz_ratio': 0.0, 'fuzz_partial': 0.0, 'fuzz_token_sort': 0.0,
            'fuzz_token_set': 0.0, 'country_exact': False, 'city_similarity': 0.0,
            'brand_exact': False, 'brand_similarity': 0.0, 'soundex_match': False,
            'word_intersection': 0.0, 'premium_keywords': 0.0
        }
    
    def _city_similarity(self, city1: str, city2: str) -> float:
        if not city1 or not city2:
            return 0.0
        return fuzz.ratio(city1.lower(), city2.lower()) / 100.0
    
    def _brand_exact_match(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> bool:
        ref_brand = ref_hotel.get('brand')
        api_chain = api_hotel.get('clean_chain', '').lower()
        
        if not ref_brand or not api_chain:
            return False
        
        return ref_brand.lower() in api_chain or api_chain in ref_brand.lower()
    
    def _brand_similarity(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> float:
        ref_brand = ref_hotel.get('brand', '')
        api_chain = api_hotel.get('clean_chain', '')
        
        if not ref_brand or not api_chain:
            return 0.0
        
        return fuzz.ratio(ref_brand, api_chain) / 100.0
    
    def _soundex_match(self, name1: str, name2: str) -> bool:
        if not name1 or not name2:
            return False
        
        try:
            soundex1 = phonetics.soundex(name1.replace(' ', ''))
            soundex2 = phonetics.soundex(name2.replace(' ', ''))
            return soundex1 == soundex2
        except:
            return False
    
    def _word_intersection_ratio(self, name1: str, name2: str) -> float:
        if not name1 or not name2:
            return 0.0
        
        words1 = set(name1.lower().split())
        words2 = set(name2.lower().split())
        
        if not words1 or not words2:
            return 0.0
        
        intersection = len(words1 & words2)
        union = len(words1 | words2)
        
        return intersection / union if union > 0 else 0.0
    
    def _premium_keywords_overlap(self, name1: str, name2: str) -> float:
        premium_keywords = ['royal', 'palace', 'luxury', 'exclusive', 'premium', 'collection', 'reserve']
        
        name1_lower = name1.lower()
        name2_lower = name2.lower()
        
        name1_keywords = sum(1 for kw in premium_keywords if kw in name1_lower)
        name2_keywords = sum(1 for kw in premium_keywords if kw in name2_lower)
        
        if name1_keywords == 0 and name2_keywords == 0:
            return 0.0
        
        common_keywords = sum(1 for kw in premium_keywords if kw in name1_lower and kw in name2_lower)
        total_keywords = max(name1_keywords, name2_keywords)
        
        return common_keywords / total_keywords if total_keywords > 0 else 0.0
    
    def _high_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['brand_exact'] and features['country_exact'] and features['city_similarity'] > 0.8:
            return {
                'match': True,
                'confidence': 0.95,
                'reason': 'Perfect brand + location'
            }
        
        if features['fuzz_token_sort'] > 0.92 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.90,
                'reason': f'Very high token sort ({features["fuzz_token_sort"]:.2f}) + country'
            }
        
        if features['fuzz_token_set'] > 0.90 and features['country_exact'] and features['city_similarity'] > 0.7:
            return {
                'match': True,
                'confidence': 0.88,
                'reason': f'High token set ({features["fuzz_token_set"]:.2f}) + location'
            }
        
        return None
    
    def _medium_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['brand_similarity'] > 0.8 and features['fuzz_token_sort'] > 0.75 and features['country_exact']:
            confidence = 0.70 + (features['fuzz_token_sort'] - 0.75) * 0.4
            return {
                'match': True,
                'confidence': min(confidence, 0.85),
                'reason': f'Brand + good name similarity ({features["fuzz_token_sort"]:.2f})'
            }
        
        if features['fuzz_partial'] > 0.85 and features['country_exact'] and (features['brand_similarity'] > 0.6 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'High partial ({features["fuzz_partial"]:.2f}) + indicators'
            }
        
        if features['fuzz_token_set'] > 0.80 and features['country_exact'] and features['city_similarity'] > 0.6:
            confidence = 0.65 + (features['fuzz_token_set'] - 0.80) * 0.5
            return {
                'match': True,
                'confidence': min(confidence, 0.82),
                'reason': f'Token set ({features["fuzz_token_set"]:.2f}) + location'
            }
        
        return None
    
    def _lower_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['soundex_match'] and features['fuzz_partial'] > 0.75 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.60,
                'reason': f'Phonetic + partial ({features["fuzz_partial"]:.2f})'
            }
        
        if (features['word_intersection'] > 0.6 and features['premium_keywords'] > 0.4 and 
            features['country_exact'] and features['city_similarity'] > 0.5):
            return {
                'match': True,
                'confidence': 0.55,
                'reason': f'Word intersection ({features["word_intersection"]:.2f}) + premium + location'
            }
        
        return None
    
    def _make_matching_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        features = self._calculate_features(ref_hotel, api_hotel)
        
        result = self._high_confidence_rules(features)
        if result:
            return result
        
        result = self._medium_confidence_rules(features)
        if result:
            return result
        
        result = self._lower_confidence_rules(features)
        if result:
            return result
        
        return None
    
    def run_matching(self) -> List[Dict]:
        print("\n" + "="*60)
        print("🎯 RUNNING HOTEL MATCHING")
        print("="*60)
        
        matches = []
        api_by_country = self.api_hotels.groupby('country_iso')
        total_hotels = len(self.reference_hotels)
        
        print(f"📊 Processing {total_hotels} reference hotels")
        print(f"🔧 ISO pre-filtering active - grouping API by country")
        print(f"🌍 API countries available: {len(api_by_country.groups)}")
        
        skipped_no_country = 0
        skipped_no_api_country = 0
        total_comparisons = 0
        
        for idx, (_, ref_hotel) in enumerate(self.reference_hotels.iterrows(), 1):
            ref_iso = ref_hotel['country_iso']
            ref_name = ref_hotel['clean_hotel']
            
            print(f"\n[{idx:2d}/{total_hotels}] Processing: {ref_name[:50]}...")
            print(f"    🌍 Country: {ref_iso}")
            
            if not ref_iso:
                print(f"    ❌ No ISO code mapping - skipped")
                skipped_no_country += 1
                continue
            
            if ref_iso not in api_by_country.groups:
                print(f"    ❌ No API hotels for {ref_iso} - skipped") 
                skipped_no_api_country += 1
                continue
            
            candidates = api_by_country.get_group(ref_iso)
            print(f"    📍 Candidates after ISO filter: {len(candidates):,}")
            
            best_match = None
            best_confidence = 0.0
            candidates_checked = 0
            
            for _, api_hotel in candidates.iterrows():
                candidates_checked += 1
                total_comparisons += 1
                
                result = self._make_matching_decision(ref_hotel, api_hotel)
                
                if result and result['confidence'] > best_confidence:
                    best_confidence = result['confidence']
                    best_match = {
                        'reference_id': ref_hotel['reference_id'],
                        'reference_name': ref_hotel['clean_hotel'],
                        'api_id': api_hotel['id'],
                        'api_name': api_hotel['clean_name'],
                        'api_chain': api_hotel['clean_chain'],
                        'api_city': api_hotel['clean_city'],
                        'api_address': api_hotel['clean_address'],
                        'api_latitude': api_hotel.get('lat'),
                        'api_longitude': api_hotel.get('lng'),
                        'confidence': result['confidence'],
                        'match_reason': result['reason']
                    }
                
                if candidates_checked % 1000 == 0:
                    print(f"    ... checked {candidates_checked:,}/{len(candidates):,} candidates")
            
            if best_match and best_confidence >= 0.55:
                matches.append(best_match)
                confidence_level = "🟢 HIGH" if best_confidence >= 0.85 else "🟡 MEDIUM" if best_confidence >= 0.70 else "🔴 LOW"
                print(f"    ✅ MATCH FOUND: {best_match['api_name'][:40]}...")
                print(f"    📊 Confidence: {best_confidence:.3f} ({confidence_level})")
                print(f"    🎯 Reason: {best_match['match_reason']}")
            else:
                print(f"    ❌ No match found (best confidence: {best_confidence:.3f})")
        
        print(f"\n" + "="*60)
        print("🎯 MATCHING COMPLETED")
        print("="*60)
        print(f"✅ Total matches found: {len(matches)}")
        print(f"📊 Coverage: {len(matches)}/{total_hotels} ({len(matches)/total_hotels*100:.1f}%)")
        print(f"⚡ Performance stats:")
        print(f"   📊 Total comparisons: {total_comparisons:,}")
        print(f"   🚫 Skipped (no ISO): {skipped_no_country}")
        print(f"   🚫 Skipped (no API country): {skipped_no_api_country}")
        
        if matches:
            confidences = [m['confidence'] for m in matches]
            high_conf = sum(1 for c in confidences if c >= 0.85)
            med_conf = sum(1 for c in confidences if 0.70 <= c < 0.85)
            low_conf = sum(1 for c in confidences if c < 0.70)
            
            print(f"📈 Confidence distribution:")
            print(f"   🟢 High (≥0.85): {high_conf}")
            print(f"   🟡 Medium (0.70-0.84): {med_conf}")
            print(f"   🔴 Low (<0.70): {low_conf}")
        
        return matches
    
    def create_full_reference_with_results(self, matches: List[Dict]) -> pd.DataFrame:
        results_df = self.reference_hotels[['Lokalizacja', 'Hotel', 'reference_id']].copy()
        
        match_dict = {match['reference_id']: match for match in matches}
        
        results_df['api_id'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_id', ''))
        results_df['api_name'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_name', ''))
        results_df['api_chain'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_chain', ''))
        results_df['api_city'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_city', ''))
        results_df['api_address'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_address', ''))
        results_df['api_latitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_latitude', ''))
        results_df['api_longitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_longitude', ''))
        results_df['confidence'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('confidence', ''))
        results_df['match_reason'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_reason', ''))
        results_df['matched'] = results_df['api_id'] != ''
        
        return results_df
    
    def run_complete_matching(self, reference_csv: str, api_csv: str) -> Dict:
        print("🚀" + "="*58 + "🚀")
        print("🚀 HOTEL MAPPING ENGINE - ISO OPTIMIZED VERSION 🚀")
        print("🚀" + "="*58 + "🚀")
        print("Algorithm: ISO Pre-filtering + Rule-based Decision Tree")
        print("Features: Brand extraction + Geographic + String similarity")
        
        self.load_reference_hotels(reference_csv)
        if self.reference_hotels is None:
            return {'error': 'Failed to load reference hotels'}
            
        self.load_api_hotels(api_csv)
        if self.api_hotels is None:
            return {'error': 'Failed to load API hotels'}
        
        matches = self.run_matching()
        
        results = {
            'total_reference_hotels': len(self.reference_hotels),
            'total_api_hotels': len(self.api_hotels),
            'total_matches': len(matches),
            'coverage_percentage': len(matches) / len(self.reference_hotels) * 100,
            'matches': matches
        }
        
        return results
    
    def save_results(self, results: Dict, output_prefix: str = "hotel_mapping_iso"):
        print("\n" + "="*60)
        print("💾 SAVING RESULTS")
        print("="*60)
        
        matches = results['matches']
        
        if matches:
            matches_df = pd.DataFrame(matches)
            matches_file = f"{output_prefix}_matches.csv"
            matches_df.to_csv(matches_file, index=False)
            print(f"✅ Saved matches: {matches_file}")
        
        full_results = self.create_full_reference_with_results(matches)
        full_file = f"{output_prefix}_full_reference.csv"
        full_results.to_csv(full_file, index=False)
        print(f"✅ Saved full reference: {full_file}")
        
        summary = pd.DataFrame({
            'metric': ['Total Reference Hotels', 'Total API Hotels', 'Total Matches', 'Coverage Percentage'],
            'value': [results['total_reference_hotels'], results['total_api_hotels'], 
                     results['total_matches'], f"{results['coverage_percentage']:.1f}%"]
        })
        summary_file = f"{output_prefix}_summary.csv"
        summary.to_csv(summary_file, index=False)
        print(f"✅ Saved summary: {summary_file}")
        
        print(f"\n🎯 FINAL RESULTS:")
        print(f"   📚 Reference hotels: {results['total_reference_hotels']}")
        print(f"   📡 API hotels: {results['total_api_hotels']:,}")
        print(f"   ✅ Matches found: {results['total_matches']}")
        print(f"   📊 Coverage: {results['coverage_percentage']:.1f}%")


if __name__ == "__main__":
    matcher = ISOHotelMatcher()
    
    results = matcher.run_complete_matching(
        reference_csv="lista_referencyjna.csv",
        api_csv="01_api_rate_hawk.csv"
    )
    
    matcher.save_results(results)
    
    print("\n" + "="*60)
    print("🏁 HOTEL MAPPING COMPLETED!")
    print("="*60)
# Out:
# 🚀==========================================================🚀
# 🚀 HOTEL MAPPING ENGINE - ISO OPTIMIZED VERSION 🚀
# 🚀==========================================================🚀
# Algorithm: ISO Pre-filtering + Rule-based Decision Tree
# Features: Brand extraction + Geographic + String similarity
#
# ============================================================
# 📂 LOADING REFERENCE HOTELS
# ============================================================
# ✅ Loaded file: lista_referencyjna.csv
# 📊 Found 99 reference hotels
#
# 🧹 Processing reference data...
# 🌍 Mapping countries to ISO codes...
# ⚠️  Unmapped countries: ['The Ritz-Carlton Yacht Collection']
# 📈 Countries distribution:
#    GR (Greece): 13 hotels
#    MV (Maldives): 12 hotels
#    AE (United Arab Emirates): 11 hotels
#    ES (Spain): 8 hotels
#    TH (Thailand): 7 hotels
# 🏨 Luxury brands detected: 23
# ✅ Processed 99 reference hotels
#
# ============================================================
# 📡 LOADING API HOTELS
# ============================================================
# ✅ Loaded file: 01_api_rate_hawk.csv
# 📊 Found 95,463 API hotels
#
# 🧹 Processing API data...
# 🌍 API countries distribution:
#    AE (United Arab Emirates): 12,942 hotels
#    GR (Greece): 8,592 hotels
#    TH (Thailand): 8,063 hotels
#    US (United States): 7,858 hotels
#    ES (Spain): 6,906 hotels
# 📍 Hotels with coordinates: 95,463/95,463 (100.0%)
# 🏨 Top 3 hotel chains:
#    No chain: 91,821 hotels
#    ZenRooms: 162 hotels
#    Choice Hotels: 144 hotels
# ✅ Processed 95,463 API hotels
#
# ============================================================
# 🎯 RUNNING HOTEL MATCHING
# ============================================================
# 📊 Processing 99 reference hotels
# 🔧 ISO pre-filtering active - grouping API by country
# 🌍 API countries available: 27
#
# [ 1/99] Processing: Regnum Carya Golf & Spa Resort, Turcja...
#     🌍 Country: TR
#     📍 Candidates after ISO filter: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [ 2/99] Processing: SH Valencia Palace, Walencja...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: SH Valencia Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [ 3/99] Processing: Atlantis The Royal...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis The Royal Hotel...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [ 4/99] Processing: Ikos Porto Petro, Majorka...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [ 5/99] Processing: One & Only Royal Mirage...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only Royal Mirage Hotel...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [ 6/99] Processing: Atlantis The Palm...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis, The Palm...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [ 7/99] Processing: One & Only Portovovi, Czarnogóra...
#     🌍 Country: ME
#     📍 Candidates after ISO filter: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [ 8/99] Processing: Bahia Del Duque...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [ 9/99] Processing: Lefay Resort & SPA Dolomiti...
#     🌍 Country: IT
#     📍 Candidates after ISO filter: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [10/99] Processing: Ikos Andalusia...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [11/99] Processing: Four Seasons Langkawi...
#     🌍 Country: MY
#     📍 Candidates after ISO filter: 1,694
#     ... checked 1,000/1,694 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Langkawi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [12/99] Processing: Movenpick Resort Kuredhivaru Maldives...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [13/99] Processing: Sani Club Hotel, Chalkidiki...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [14/99] Processing: Marbella Club...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Hotel Marbella...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [15/99] Processing: The Ritz-Carlton Yacht Collection...
#     🌍 Country: None
#     ❌ No ISO code mapping - skipped
#
# [16/99] Processing: Waldorf Astoria Seychelles...
#     🌍 Country: SC
#     📍 Candidates after ISO filter: 747
#     ❌ No match found (best confidence: 0.000)
#
# [17/99] Processing: Finolhu, Malediwy...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [18/99] Processing: Gloria Serenity Resort...
#     🌍 Country: TR
#     📍 Candidates after ISO filter: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     ✅ MATCH FOUND: Serenity Lara Hotel...
#     📊 Confidence: 0.679 (🔴 LOW)
#     🎯 Reason: Token set (0.86) + location
#
# [19/99] Processing: Dukley Hotel & Resort, Czarnogóra...
#     🌍 Country: ME
#     📍 Candidates after ISO filter: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [20/99] Processing: Grecotel Corfu Imperial...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Corfu Palace...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [21/99] Processing: JW Marriott Mauritius Resort...
#     🌍 Country: MU
#     📍 Candidates after ISO filter: 1,930
#     ... checked 1,000/1,930 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [22/99] Processing: Four Seasons Resort Seychelles at Desroches Island...
#     🌍 Country: SC
#     📍 Candidates after ISO filter: 747
#     ✅ MATCH FOUND: Four Seasons Resort Seychelles at Desroc...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [23/99] Processing: The St. Regis La Bahia Blanca Resort, Maroko...
#     🌍 Country: MA
#     📍 Candidates after ISO filter: 545
#     ❌ No match found (best confidence: 0.000)
#
# [24/99] Processing: One & Only Aesthesis, Ateny...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [25/99] Processing: Forte Village, Sardynia...
#     🌍 Country: IT
#     📍 Candidates after ISO filter: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [26/99] Processing: Four Seasons Sharm El Sheikh, Egipt...
#     🌍 Country: EG
#     📍 Candidates after ISO filter: 1,788
#     ... checked 1,000/1,788 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Sharm EL Sheikh...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [27/99] Processing: One & Only Reethi Rah...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: One&Only Reethi Rah Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [28/99] Processing: Vakkaru...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [29/99] Processing: Six Senses Zil Pasyon...
#     🌍 Country: SC
#     📍 Candidates after ISO filter: 747
#     ✅ MATCH FOUND: Six Senses Zil Pasyon Seychelles...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Reason: High partial (1.00) + indicators
#
# [30/99] Processing: Fairmont St Andrews, Szkocja...
#     🌍 Country: GB
#     📍 Candidates after ISO filter: 943
#     ❌ No match found (best confidence: 0.000)
#
# [31/99] Processing: The Lodge Hotel, Porto...
#     🌍 Country: PT
#     📍 Candidates after ISO filter: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: Vincci Porto...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [32/99] Processing: Banyan Tree Krabi...
#     🌍 Country: TH
#     📍 Candidates after ISO filter: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Banyan Tree Krabi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [33/99] Processing: Mandarin Oriental Jumeira Dubai...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Hotel mandarin oriental jumeira, dubai...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [34/99] Processing: Angsana Corfu Resort...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Angsana Corfu Resort & Spa...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [35/99] Processing: JOALI Being...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Joali Being...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [36/99] Processing: Patina Maldives, Fari Islands...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Patina Maldives, Fari Islands...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [37/99] Processing: Four Seasons Marakesh, Maroko...
#     🌍 Country: MA
#     📍 Candidates after ISO filter: 545
#     ❌ No match found (best confidence: 0.000)
#
# [38/99] Processing: Dusit Thani, Pattaya...
#     🌍 Country: TH
#     📍 Candidates after ISO filter: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dusit Thani Pattaya...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [39/99] Processing: Chedi Andermatt, Szwajcaria...
#     🌍 Country: CH
#     📍 Candidates after ISO filter: 392
#     ✅ MATCH FOUND: The Chedi Andermatt...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [40/99] Processing: Shangri-La Sydney...
#     🌍 Country: AU
#     📍 Candidates after ISO filter: 3,669
#     ... checked 1,000/3,669 candidates
#     ... checked 2,000/3,669 candidates
#     ... checked 3,000/3,669 candidates
#     ✅ MATCH FOUND: Shangri-La Sydney...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [41/99] Processing: The Stanley, Ateny...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: The Stanley...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [42/99] Processing: Daios Cove, Kreta...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [43/99] Processing: Romanos, Costa Navarino...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [44/99] Processing: Four Seasons Jimbaran Bay, Bali...
#     🌍 Country: ID
#     📍 Candidates after ISO filter: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Bali at Jimbaran Bay...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [45/99] Processing: Hilton Aruba Caribbean Resort & Casino, Aruba...
#     🌍 Country: AW
#     📍 Candidates after ISO filter: 1,255
#     ... checked 1,000/1,255 candidates
#     ✅ MATCH FOUND: Hilton Aruba Caribbean Resort and Casino...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (0.94) + country
#
# [46/99] Processing: Mandarin Oriental, Costa Navarino...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Costa Navarino...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [47/99] Processing: Quark Expeditions...
#     🌍 Country: GL
#     ❌ No API hotels for GL - skipped
#
# [48/99] Processing: JOALI Maldives...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: JOALI Maldives Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [49/99] Processing: Belmond Reid's Palace, Portugalia...
#     🌍 Country: PT
#     📍 Candidates after ISO filter: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: GA Palace Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Reason: High partial (1.00) + indicators
#
# [50/99] Processing: Velaa Private Island...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Velaa Private Island...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [51/99] Processing: The Abi d'Oru Hotel & Spa, Sardynia...
#     🌍 Country: IT
#     📍 Candidates after ISO filter: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [52/99] Processing: Burj Al Arab...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Jumeirah Burj Al Arab Dubai...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [53/99] Processing: One & Only The Palm...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only The Palm, Dubai Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [54/99] Processing: Rosewood Phuket...
#     🌍 Country: TH
#     📍 Candidates after ISO filter: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [55/99] Processing: Wyndham Grand Athens, Ateny...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Athens Suites...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [56/99] Processing: Ikos Oceania, Chalkidiki...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [57/99] Processing: Saii Phi Phi Island Village Resort, Tajlandia...
#     🌍 Country: TH
#     📍 Candidates after ISO filter: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phi Phi Inn...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Reason: Token set (1.00) + location
#
# [58/99] Processing: Raffles Prasiln...
#     🌍 Country: SC
#     📍 Candidates after ISO filter: 747
#     ❌ No match found (best confidence: 0.000)
#
# [59/99] Processing: Waldorf Astoria Maldives Ithaafushi...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Maldives Ithaafushi Hote...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [60/99] Processing: Regent Phu Quoc Hotel, Wietnam...
#     🌍 Country: VN
#     📍 Candidates after ISO filter: 1,058
#     ... checked 1,000/1,058 candidates
#     ✅ MATCH FOUND: M Resort Phu Quoc...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [61/99] Processing: The Ritz-Carlton, Jumeirah...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: The Ritz-Carlton, Dubai Hotel...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [62/99] Processing: METT Marbella Hotel, Hiszpania...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Marbella Resort...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [63/99] Processing: Niyama Private Island...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [64/99] Processing: Hotel Du Palais Biarritz - The Unbound Collection ...
#     🌍 Country: FR
#     📍 Candidates after ISO filter: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     ✅ MATCH FOUND: Hôtel du Palais...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [65/99] Processing: Four Seasons Resort Orlando at Walt Disney World R...
#     🌍 Country: US
#     📍 Candidates after ISO filter: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: Orlando Motel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [66/99] Processing: Mandarin Oriental, Singapur...
#     🌍 Country: SG
#     📍 Candidates after ISO filter: 1,085
#     ... checked 1,000/1,085 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Singapore...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (0.94) + country
#
# [67/99] Processing: The Datai, Malezja...
#     🌍 Country: MY
#     📍 Candidates after ISO filter: 1,694
#     ... checked 1,000/1,694 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [68/99] Processing: The Betsy Hotel, Miami...
#     🌍 Country: US
#     📍 Candidates after ISO filter: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: W Miami...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [69/99] Processing: Ikos Dassia, Korfu...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [70/99] Processing: Puente Romano, Hiszpania...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [71/99] Processing: Domes Zeen, a Luxury Collection Resort, Kreta...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Luxury V Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Reason: High partial (1.00) + indicators
#
# [72/99] Processing: Emerald Resort, Malediwy...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [73/99] Processing: Badrutt's Palace, Szwajcaria...
#     🌍 Country: CH
#     📍 Candidates after ISO filter: 392
#     ✅ MATCH FOUND: Badrutt's Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [74/99] Processing: Four Seasons Resort at Jumeirah Beach...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Four Seasons Dubai at Jumeirah Beach Res...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [75/99] Processing: DoubleTree by Hilton Resort & Spa Marjan Island, U...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Rixos Al Mairid Ras Al Khaimah...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [76/99] Processing: Alpin & Vital Hotel La Perla, Ortisei, Włochy...
#     🌍 Country: IT
#     📍 Candidates after ISO filter: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [77/99] Processing: The Retreat at Blue Lagoon Iceland...
#     🌍 Country: IS
#     📍 Candidates after ISO filter: 15
#     ✅ MATCH FOUND: The Retreat at Blue Lagoon Iceland...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [78/99] Processing: Jaal Riad Resort, Maroko...
#     🌍 Country: MA
#     📍 Candidates after ISO filter: 545
#     ❌ No match found (best confidence: 0.000)
#
# [79/99] Processing: The Raffles Doha...
#     🌍 Country: QA
#     📍 Candidates after ISO filter: 498
#     ✅ MATCH FOUND: Raffles Doha...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [80/99] Processing: Jumeirah at Saadiyat Island Resort, UAE...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Jumeirah Saadiyat Island Abu Dhabi...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (0.92) + location
#
# [81/99] Processing: The Chedi El Gouna, Egipt...
#     🌍 Country: EG
#     📍 Candidates after ISO filter: 1,788
#     ... checked 1,000/1,788 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [82/99] Processing: El Fuerte Marbella, Hiszpania...
#     🌍 Country: ES
#     📍 Candidates after ISO filter: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: El Fuerte Marbella...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [83/99] Processing: Fancourt Hotel...
#     🌍 Country: ZA
#     📍 Candidates after ISO filter: 601
#     ✅ MATCH FOUND: Fancourt...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [84/99] Processing: Waldorf Astoria The Palm...
#     🌍 Country: AE
#     📍 Candidates after ISO filter: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Al Habtoor Palace Hotel...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [85/99] Processing: The Laguna, A Luxury Collection Resort & Spa...
#     🌍 Country: ID
#     📍 Candidates after ISO filter: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: The Laguna, a Luxury Collection Resort &...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Reason: High partial (1.00) + indicators
#
# [86/99] Processing: Six Senses Yao Noi...
#     🌍 Country: TH
#     📍 Candidates after ISO filter: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Six Senses Yao Noi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [87/99] Processing: Le Fitz Roy, Val Thorens...
#     🌍 Country: FR
#     📍 Candidates after ISO filter: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [88/99] Processing: Sugar Beach Mauritius...
#     🌍 Country: MU
#     📍 Candidates after ISO filter: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: Sugar Beach Mauritius...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (1.00) + country
#
# [89/99] Processing: Lefay Resort Lago Di Garda, Włochy...
#     🌍 Country: IT
#     📍 Candidates after ISO filter: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [90/99] Processing: Elivi Skiathos...
#     🌍 Country: GR
#     📍 Candidates after ISO filter: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [91/99] Processing: One & Only Le Saint Geran...
#     🌍 Country: MU
#     📍 Candidates after ISO filter: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: One&Only Le Saint Géran...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Reason: Very high token sort (0.96) + country
#
# [92/99] Processing: The St Regis Bali Resort Nusa Dua...
#     🌍 Country: ID
#     📍 Candidates after ISO filter: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [93/99] Processing: Explora II...
#     🌍 Country: CL
#     ❌ No API hotels for CL - skipped
#
# [94/99] Processing: Lily Beach Resort & Spa, Malediwy...
#     🌍 Country: MV
#     📍 Candidates after ISO filter: 1,441
#     ... checked 1,000/1,441 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [95/99] Processing: Tortuga Bay Puntacana Resort & Club, Dominikana...
#     🌍 Country: DO
#     📍 Candidates after ISO filter: 5,826
#     ... checked 1,000/5,826 candidates
#     ... checked 2,000/5,826 candidates
#     ... checked 3,000/5,826 candidates
#     ... checked 4,000/5,826 candidates
#     ... checked 5,000/5,826 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [96/99] Processing: Ritz Carlton Phulay Bay...
#     🌍 Country: TH
#     📍 Candidates after ISO filter: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phulay Bay, a Ritz-Carlton Reserve...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# [97/99] Processing: Intercontinental Phuket Resort, Tajlandia...
#     🌍 Country: TH
#     📍 Candidates after ISO filter: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dinso Resort & Villas Phuket, Vignette C...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Reason: Perfect brand + location
#
# [98/99] Processing: Verdura Golf & Spa Resort, Sycylia...
#     🌍 Country: IT
#     📍 Candidates after ISO filter: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     ❌ No match found (best confidence: 0.000)
#
# [99/99] Processing: Maxx Royal Belek Golf Resort, Belek...
#     🌍 Country: TR
#     📍 Candidates after ISO filter: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     ✅ MATCH FOUND: Belek...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Reason: High token set (1.00) + location
#
# ============================================================
# 🎯 MATCHING COMPLETED
# ============================================================
# ✅ Total matches found: 57
# 📊 Coverage: 57/99 (57.6%)
# ⚡ Performance stats:
#    📊 Total comparisons: 518,032
#    🚫 Skipped (no ISO): 1
#    🚫 Skipped (no API country): 2
# 📈 Confidence distribution:
#    🟢 High (≥0.85): 51
#    🟡 Medium (0.70-0.84): 5
#    🔴 Low (<0.70): 1
#
# ============================================================
# 💾 SAVING RESULTS
# ============================================================
# ✅ Saved matches: hotel_mapping_iso_matches.csv
# ✅ Saved full reference: hotel_mapping_iso_full_reference.csv
# ✅ Saved summary: hotel_mapping_iso_summary.csv
#
# 🎯 FINAL RESULTS:
#    📚 Reference hotels: 99
#    📡 API hotels: 95,463
#    ✅ Matches found: 57
#    📊 Coverage: 57.6%
#
# ============================================================
# 🏁 HOTEL MAPPING COMPLETED!
# ============================================================

# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
import re
import phonetics
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

class ISOHotelMatcher:
    def __init__(self):
        self.reference_hotels = None
        self.api_hotels = None
        self.iso_mappings = self._create_iso_mappings()
        self.country_to_iso = self._create_reverse_iso_lookup()
        self.luxury_brands = self._create_luxury_brands()
        
    def _create_iso_mappings(self) -> Dict[str, Dict]:
        return {
            'AE': {
                'iso_code': 'AE',
                'official_name': 'United Arab Emirates',
                'variants': ['UAE', 'U.A.E', 'United Arab Emirates', 'Emiraty Arabskie', 'Zjednoczone Emiraty Arabskie']
            },
            'TH': {
                'iso_code': 'TH',
                'official_name': 'Thailand', 
                'variants': ['Thailand', 'Tajlandia', 'Siam', 'Kingdom of Thailand']
            },
            'SC': {
                'iso_code': 'SC',
                'official_name': 'Seychelles',
                'variants': ['Seychelles', 'Seszele', 'Republic of Seychelles', 'Sesel']
            },
            'TR': {
                'iso_code': 'TR',
                'official_name': 'Turkey',
                'variants': ['Turkey', 'Turcja', 'Türkiye', 'Republic of Turkey']
            },
            'ES': {
                'iso_code': 'ES', 
                'official_name': 'Spain',
                'variants': ['Spain', 'Hiszpania', 'España', 'Kingdom of Spain']
            },
            'ME': {
                'iso_code': 'ME',
                'official_name': 'Montenegro',
                'variants': ['Montenegro', 'Czarnogóra', 'Crna Gora']
            },
            'IT': {
                'iso_code': 'IT',
                'official_name': 'Italy',
                'variants': ['Italy', 'Włochy', 'Italia', 'Italian Republic']
            },
            'MY': {
                'iso_code': 'MY',
                'official_name': 'Malaysia',
                'variants': ['Malaysia', 'Malezja']
            },
            'MV': {
                'iso_code': 'MV',
                'official_name': 'Maldives',
                'variants': ['Maldives', 'Malediwy', 'Republic of Maldives']
            },
            'GR': {
                'iso_code': 'GR',
                'official_name': 'Greece',
                'variants': ['Greece', 'Grecja', 'Hellas', 'Hellenic Republic']
            },
            'MA': {
                'iso_code': 'MA',
                'official_name': 'Morocco',
                'variants': ['Morocco', 'Maroko', 'Kingdom of Morocco']
            },
            'EG': {
                'iso_code': 'EG',
                'official_name': 'Egypt',
                'variants': ['Egypt', 'Egipt', 'Arab Republic of Egypt']
            },
            'MU': {
                'iso_code': 'MU',
                'official_name': 'Mauritius',
                'variants': ['Mauritius', 'Republic of Mauritius']
            },
            'GB': {
                'iso_code': 'GB',
                'official_name': 'United Kingdom',
                'variants': ['United Kingdom', 'Wielka Brytania', 'UK', 'Great Britain']
            },
            'PT': {
                'iso_code': 'PT',
                'official_name': 'Portugal',
                'variants': ['Portugal', 'Portugalia', 'Portuguese Republic']
            },
            'CH': {
                'iso_code': 'CH',
                'official_name': 'Switzerland',
                'variants': ['Switzerland', 'Szwajcaria', 'Swiss Confederation']
            },
            'AU': {
                'iso_code': 'AU',
                'official_name': 'Australia',
                'variants': ['Australia', 'Commonwealth of Australia']
            },
            'ID': {
                'iso_code': 'ID',
                'official_name': 'Indonesia',
                'variants': ['Indonesia', 'Indonezja', 'Republic of Indonesia']
            },
            'AW': {
                'iso_code': 'AW',
                'official_name': 'Aruba',
                'variants': ['Aruba']
            },
            'GL': {
                'iso_code': 'GL',
                'official_name': 'Greenland',
                'variants': ['Greenland', 'Grenlandia']
            },
            'VN': {
                'iso_code': 'VN',
                'official_name': 'Vietnam',
                'variants': ['Vietnam', 'Wietnam', 'Socialist Republic of Vietnam']
            },
            'FR': {
                'iso_code': 'FR',
                'official_name': 'France',
                'variants': ['France', 'Francja', 'French Republic']
            },
            'US': {
                'iso_code': 'US',
                'official_name': 'United States',
                'variants': ['United States', 'USA', 'US', 'America']
            },
            'SG': {
                'iso_code': 'SG',
                'official_name': 'Singapore',
                'variants': ['Singapore', 'Singapur', 'Republic of Singapore']
            },
            'IS': {
                'iso_code': 'IS',
                'official_name': 'Iceland',
                'variants': ['Iceland', 'Islandia', 'Republic of Iceland']
            },
            'QA': {
                'iso_code': 'QA',
                'official_name': 'Qatar',
                'variants': ['Qatar', 'State of Qatar']
            },
            'ZA': {
                'iso_code': 'ZA',
                'official_name': 'South Africa',
                'variants': ['South Africa', 'RPA', 'Republic of South Africa']
            },
            'DO': {
                'iso_code': 'DO',
                'official_name': 'Dominican Republic',
                'variants': ['Dominican Republic', 'Dominikana']
            },
            'CL': {
                'iso_code': 'CL',
                'official_name': 'Chile',
                'variants': ['Chile', 'Republic of Chile', 'Explora']
            }
        }
    
    def _create_reverse_iso_lookup(self) -> Dict[str, str]:
        lookup = {}
        for iso_code, data in self.iso_mappings.items():
            for variant in data['variants']:
                lookup[variant.lower().strip()] = iso_code
        return lookup
    
    def _create_luxury_brands(self) -> List[str]:
        return [
            'four seasons', 'atlantis', 'banyan tree', 'mandarin oriental',
            'one only', 'angsana', 'shangri-la', 'ritz carlton', 'ritz-carlton',
            'st regis', 'waldorf astoria', 'hilton', 'marriott', 'hyatt',
            'intercontinental', 'sheraton', 'westin', 'doubletree', 'regent',
            'fairmont', 'raffles', 'rosewood', 'belmond', 'six senses',
            'chedi', 'dusit thani', 'movenpick', 'mövenpick'
        ]
    
    def _map_country_to_iso(self, country_str: str) -> Optional[str]:
        if not country_str:
            return None
        
        country_clean = country_str.lower().strip()
        return self.country_to_iso.get(country_clean)
    
    def _extract_brand(self, hotel_name: str) -> Optional[str]:
        if not hotel_name:
            return None
        
        name_lower = hotel_name.lower()
        for brand in self.luxury_brands:
            if brand in name_lower:
                return brand
        return None
    
    def _normalize_hotel_name(self, name: str) -> str:
        if pd.isna(name) or not name:
            return ""
        
        name = str(name).lower().strip()
        name = re.sub(r'[^\w\s]', ' ', name)
        
        stop_words = [
            'hotel', 'resort', 'spa', 'suites', 'inn', 'lodge', 
            'motel', 'palace', 'club', 'grand', 'royal', 'the', 'at'
        ]
        
        words = [word for word in name.split() if word not in stop_words and len(word) > 1]
        
        seen = set()
        unique_words = []
        for word in words:
            if word not in seen:
                unique_words.append(word)
                seen.add(word)
        
        return ' '.join(unique_words)
    
    def _normalize_city_name(self, city: str) -> str:
        if not city:
            return ""
        
        city_mappings = {
            'dubaj': 'dubai',
            'krabi': 'krabi',
            'desroches': 'desroches island'
        }
        
        city_clean = city.lower().strip()
        return city_mappings.get(city_clean, city_clean)
    
    def load_reference_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📂 LOADING REFERENCE HOTELS")
        print("="*60)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Loaded file: {csv_path}")
            print(f"📊 Found {len(df)} reference hotels")
        except Exception as e:
            print(f"❌ Error loading file: {e}")
            return None
        
        print("\n🧹 Processing reference data...")
        df['clean_location'] = df['Lokalizacja'].str.strip()
        df['clean_hotel'] = df['Hotel'].str.strip()
        
        df[['country_raw', 'city_raw']] = df['clean_location'].str.split(',', n=1, expand=True)
        df['country_raw'] = df['country_raw'].fillna('').str.strip()
        df['city_raw'] = df['city_raw'].fillna('').str.strip()
        
        print("🌍 Mapping countries to ISO codes...")
        df['country_iso'] = df['country_raw'].apply(self._map_country_to_iso)
        
        unmapped_countries = df[df['country_iso'].isna()]['country_raw'].unique()
        if len(unmapped_countries) > 0:
            print(f"⚠️  Unmapped countries: {list(unmapped_countries)}")
        
        df['city'] = df['city_raw'].apply(self._normalize_city_name)
        df['normalized_name'] = df['clean_hotel'].apply(self._normalize_hotel_name)
        df['brand'] = df['clean_hotel'].apply(self._extract_brand)
        df['reference_id'] = df.index.astype(str).str.zfill(3)
        
        country_stats = df['country_iso'].value_counts()
        print(f"📈 Countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count} hotels")
        
        brands_found = df['brand'].dropna().nunique()
        print(f"🏨 Luxury brands detected: {brands_found}")
        
        self.reference_hotels = df
        print(f"✅ Processed {len(df)} reference hotels")
        return df
    
    def load_api_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📡 LOADING API HOTELS")
        print("="*60)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Loaded file: {csv_path}")
            print(f"📊 Found {len(df):,} API hotels")
        except Exception as e:
            print(f"❌ Error loading file: {e}")
            return None
        
        print("\n🧹 Processing API data...")
        df['clean_name'] = df['name'].fillna('').str.strip()
        df['clean_city'] = df['city'].fillna('').str.strip()
        df['clean_address'] = df['address'].fillna('').str.strip()
        df['clean_chain'] = df['hotel_chain'].fillna('').str.strip()
        
        df['country_iso'] = df['country'].fillna('').str.upper().str.strip()
        df['normalized_name'] = df['clean_name'].apply(self._normalize_hotel_name)
        df['city_normalized'] = df['clean_city'].apply(self._normalize_city_name)
        
        df['lat'] = pd.to_numeric(df['latitude'], errors='coerce')
        df['lng'] = pd.to_numeric(df['longitude'], errors='coerce')
        
        country_stats = df['country_iso'].value_counts()
        print(f"🌍 API countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count:,} hotels")
        
        coords_valid = df[['lat', 'lng']].notna().all(axis=1).sum()
        print(f"📍 Hotels with coordinates: {coords_valid:,}/{len(df):,} ({coords_valid/len(df)*100:.1f}%)")
        
        chain_stats = df[df['clean_chain'] != '']['clean_chain'].value_counts()
        print(f"🏨 Top 3 hotel chains:")
        for chain, count in chain_stats.head(3).items():
            print(f"   {chain}: {count:,} hotels")
        
        self.api_hotels = df
        print(f"✅ Processed {len(df):,} API hotels")
        return df
    
    def _calculate_features(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return self._empty_features()
        
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'country_exact': ref_hotel['country_iso'] == api_hotel['country_iso'],
            'city_similarity': self._city_similarity(ref_hotel['city'], api_hotel['city_normalized']),
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        return features
    
    def _empty_features(self) -> Dict:
        return {
            'fuzz_ratio': 0.0, 'fuzz_partial': 0.0, 'fuzz_token_sort': 0.0,
            'fuzz_token_set': 0.0, 'country_exact': False, 'city_similarity': 0.0,
            'brand_exact': False, 'brand_similarity': 0.0, 'soundex_match': False,
            'word_intersection': 0.0, 'premium_keywords': 0.0
        }
    
    def _city_similarity(self, city1: str, city2: str) -> float:
        if not city1 or not city2:
            return 0.0
        return fuzz.ratio(city1.lower(), city2.lower()) / 100.0
    
    def _brand_exact_match(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> bool:
        ref_brand = ref_hotel.get('brand')
        api_chain = api_hotel.get('clean_chain', '').lower()
        
        if not ref_brand or not api_chain:
            return False
        
        return ref_brand.lower() in api_chain or api_chain in ref_brand.lower()
    
    def _brand_similarity(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> float:
        ref_brand = ref_hotel.get('brand', '')
        api_chain = api_hotel.get('clean_chain', '')
        
        if not ref_brand or not api_chain:
            return 0.0
        
        return fuzz.ratio(ref_brand, api_chain) / 100.0
    
    def _soundex_match(self, name1: str, name2: str) -> bool:
        if not name1 or not name2:
            return False
        
        try:
            soundex1 = phonetics.soundex(name1.replace(' ', ''))
            soundex2 = phonetics.soundex(name2.replace(' ', ''))
            return soundex1 == soundex2
        except:
            return False
    
    def _word_intersection_ratio(self, name1: str, name2: str) -> float:
        if not name1 or not name2:
            return 0.0
        
        words1 = set(name1.lower().split())
        words2 = set(name2.lower().split())
        
        if not words1 or not words2:
            return 0.0
        
        intersection = len(words1 & words2)
        union = len(words1 | words2)
        
        return intersection / union if union > 0 else 0.0
    
    def _premium_keywords_overlap(self, name1: str, name2: str) -> float:
        premium_keywords = ['royal', 'palace', 'luxury', 'exclusive', 'premium', 'collection', 'reserve']
        
        name1_lower = name1.lower()
        name2_lower = name2.lower()
        
        name1_keywords = sum(1 for kw in premium_keywords if kw in name1_lower)
        name2_keywords = sum(1 for kw in premium_keywords if kw in name2_lower)
        
        if name1_keywords == 0 and name2_keywords == 0:
            return 0.0
        
        common_keywords = sum(1 for kw in premium_keywords if kw in name1_lower and kw in name2_lower)
        total_keywords = max(name1_keywords, name2_keywords)
        
        return common_keywords / total_keywords if total_keywords > 0 else 0.0
    
    def _high_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['brand_exact'] and features['country_exact'] and features['city_similarity'] > 0.8:
            return {
                'match': True,
                'confidence': 0.95,
                'reason': 'Perfect brand + location'
            }
        
        if features['fuzz_token_sort'] > 0.92 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.90,
                'reason': f'Very high token sort ({features["fuzz_token_sort"]:.2f}) + country'
            }
        
        if features['fuzz_token_set'] > 0.90 and features['country_exact'] and features['city_similarity'] > 0.7:
            return {
                'match': True,
                'confidence': 0.88,
                'reason': f'High token set ({features["fuzz_token_set"]:.2f}) + location'
            }
        
        return None
    
    def _medium_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['brand_similarity'] > 0.8 and features['fuzz_token_sort'] > 0.75 and features['country_exact']:
            confidence = 0.70 + (features['fuzz_token_sort'] - 0.75) * 0.4
            return {
                'match': True,
                'confidence': min(confidence, 0.85),
                'reason': f'Brand + good name similarity ({features["fuzz_token_sort"]:.2f})'
            }
        
        if features['fuzz_partial'] > 0.85 and features['country_exact'] and (features['brand_similarity'] > 0.6 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'High partial ({features["fuzz_partial"]:.2f}) + indicators'
            }
        
        if features['fuzz_token_set'] > 0.80 and features['country_exact'] and features['city_similarity'] > 0.6:
            confidence = 0.65 + (features['fuzz_token_set'] - 0.80) * 0.5
            return {
                'match': True,
                'confidence': min(confidence, 0.82),
                'reason': f'Token set ({features["fuzz_token_set"]:.2f}) + location'
            }
        
        return None
    
    def _lower_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['soundex_match'] and features['fuzz_partial'] > 0.75 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.60,
                'reason': f'Phonetic + partial ({features["fuzz_partial"]:.2f})'
            }
        
        if (features['word_intersection'] > 0.6 and features['premium_keywords'] > 0.4 and 
            features['country_exact'] and features['city_similarity'] > 0.5):
            return {
                'match': True,
                'confidence': 0.55,
                'reason': f'Word intersection ({features["word_intersection"]:.2f}) + premium + location'
            }
        
        return None
    
    def _make_name_only_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        """
        Name-only matching decision for fallback cases
        More permissive rules when no geography available
        """
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return None
        
        # Calculate basic features for name-only matching
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        # Name-only rules (more permissive thresholds)
        
        # Rule 1: Perfect brand match + decent name similarity
        if features['brand_exact'] and features['fuzz_token_sort'] > 0.70:
            return {
                'match': True,
                'confidence': 0.80,
                'reason': 'Perfect brand + decent name (name-only)'
            }
        
        # Rule 2: Very high name similarity
        if features['fuzz_token_sort'] > 0.88:
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Very high token sort ({features["fuzz_token_sort"]:.2f}) (name-only)'
            }
        
        # Rule 3: High token set similarity
        if features['fuzz_token_set'] > 0.85:
            return {
                'match': True,
                'confidence': 0.70,
                'reason': f'High token set ({features["fuzz_token_set"]:.2f}) (name-only)'
            }
        
        # Rule 4: Brand similarity + good name match
        if features['brand_similarity'] > 0.75 and features['fuzz_token_sort'] > 0.65:
            confidence = 0.60 + (features['fuzz_token_sort'] - 0.65) * 0.3
            return {
                'match': True,
                'confidence': min(confidence, 0.75),
                'reason': f'Brand similarity + name match (name-only)'
            }
        
        # Rule 5: High partial ratio + premium indicators
        if features['fuzz_partial'] > 0.80 and (features['brand_similarity'] > 0.5 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.65,
                'reason': f'High partial + indicators (name-only)'
            }
        
        return None
    def _make_name_only_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        """
        Name-only matching decision for fallback cases
        More permissive rules when no geography available
        """
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return None
        
        # Calculate basic features for name-only matching
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        # Name-only rules (more permissive thresholds)
        
        # Rule 1: Perfect brand match + decent name similarity
        if features['brand_exact'] and features['fuzz_token_sort'] > 0.70:
            return {
                'match': True,
                'confidence': 0.80,
                'reason': 'Perfect brand + decent name (name-only)'
            }
        
        # Rule 2: Very high name similarity
        if features['fuzz_token_sort'] > 0.88:
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Very high token sort ({features["fuzz_token_sort"]:.2f}) (name-only)'
            }
        
        # Rule 3: High token set similarity
        if features['fuzz_token_set'] > 0.85:
            return {
                'match': True,
                'confidence': 0.70,
                'reason': f'High token set ({features["fuzz_token_set"]:.2f}) (name-only)'
            }
        
        # Rule 4: Brand similarity + good name match
        if features['brand_similarity'] > 0.75 and features['fuzz_token_sort'] > 0.65:
            confidence = 0.60 + (features['fuzz_token_sort'] - 0.65) * 0.3
            return {
                'match': True,
                'confidence': min(confidence, 0.75),
                'reason': f'Brand similarity + name match (name-only)'
            }
        
        # Rule 5: High partial ratio + premium indicators
        if features['fuzz_partial'] > 0.80 and (features['brand_similarity'] > 0.5 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.65,
                'reason': f'High partial + indicators (name-only)'
            }
        
        return None
    
    def _make_matching_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        features = self._calculate_features(ref_hotel, api_hotel)
        
        result = self._high_confidence_rules(features)
        if result:
            return result
        
        result = self._medium_confidence_rules(features)
        if result:
            return result
        
        result = self._lower_confidence_rules(features)
        if result:
            return result
        
        return None
    
    def run_matching(self) -> List[Dict]:
        print("\n" + "="*60)
        print("🎯 RUNNING HOTEL MATCHING")
        print("="*60)
        
        matches = []
        api_by_country = self.api_hotels.groupby('country_iso')
        total_hotels = len(self.reference_hotels)
        
        # Algorithm performance tracking
        algorithm_stats = {
            'Perfect brand + location': 0,
            'Very high token sort + country': 0,
            'High token set + location': 0,
            'Brand + good name similarity': 0,
            'High partial + indicators': 0,
            'Token set + location': 0,
            'Phonetic + partial': 0,
            'Word intersection + premium + location': 0,
            'Name-only fallback': 0
        }
        
        print(f"📊 Processing {total_hotels} reference hotels")
        print(f"🔧 ISO pre-filtering active - grouping API by country")
        print(f"🌍 API countries available: {len(api_by_country.groups)}")
        
        skipped_no_country = 0
        skipped_no_api_country = 0
        total_comparisons = 0
        
        for idx, (_, ref_hotel) in enumerate(self.reference_hotels.iterrows(), 1):
            ref_iso = ref_hotel['country_iso']
            ref_name = ref_hotel['clean_hotel']
            
            print(f"\n[{idx:2d}/{total_hotels}] Processing: {ref_name[:50]}...")
            print(f"    🌍 Country: {ref_iso}")
            
            best_match = None
            best_confidence = 0.0
            candidates_checked = 0
            
            # Strategy 1: ISO-based matching (preferred)
            if ref_iso and ref_iso in api_by_country.groups:
                candidates = api_by_country.get_group(ref_iso)
                print(f"    📍 ISO candidates: {len(candidates):,}")
                
                for _, api_hotel in candidates.iterrows():
                    candidates_checked += 1
                    total_comparisons += 1
                    
                    result = self._make_matching_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel['id'],
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'ISO-based'
                        }
                    
                    if candidates_checked % 1000 == 0:
                        print(f"    ... checked {candidates_checked:,}/{len(candidates):,} candidates")
            
            # Strategy 2: Name-only fallback (when no ISO or no ISO matches)
            if not best_match or best_confidence < 0.75:
                if not ref_iso:
                    print(f"    ⚠️  No ISO mapping - trying name-only fallback")
                elif ref_iso not in api_by_country.groups:
                    print(f"    ⚠️  No API hotels for {ref_iso} - trying name-only fallback")
                else:
                    print(f"    🔄 Low confidence ({best_confidence:.3f}) - trying name-only fallback")
                
                fallback_candidates = 0
                fallback_checked = 0
                
                # Use top 5000 hotels by similarity for performance
                name_similarities = []
                for _, api_hotel in self.api_hotels.iterrows():
                    if api_hotel['normalized_name']:
                        sim = fuzz.ratio(ref_hotel['normalized_name'], api_hotel['normalized_name']) / 100.0
                        if sim > 0.4:  # Basic threshold
                            name_similarities.append((sim, api_hotel))
                
                # Sort by similarity and take top candidates
                name_similarities.sort(key=lambda x: x[0], reverse=True)
                top_candidates = name_similarities[:5000]  # Limit for performance
                fallback_candidates = len(top_candidates)
                
                print(f"    🔍 Name-only candidates: {fallback_candidates}")
                
                for sim_score, api_hotel in top_candidates:
                    fallback_checked += 1
                    total_comparisons += 1
                    
                    # Use name-only decision logic
                    result = self._make_name_only_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel['id'],
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'Name-only fallback'
                        }
                
                if fallback_candidates == 0:
                    if not ref_iso:
                        skipped_no_country += 1
                    else:
                        skipped_no_api_country += 1
            
            # Record result
            if best_match and best_confidence >= 0.55:
                matches.append(best_match)
                
                # Track algorithm performance
                reason = best_match['match_reason']
                algorithm_found = False
                for algo_name in algorithm_stats.keys():
                    if algo_name.lower() in reason.lower():
                        algorithm_stats[algo_name] += 1
                        algorithm_found = True
                        break
                
                if not algorithm_found and best_match['match_strategy'] == 'Name-only fallback':
                    algorithm_stats['Name-only fallback'] += 1
                
                confidence_level = "🟢 HIGH" if best_confidence >= 0.85 else "🟡 MEDIUM" if best_confidence >= 0.70 else "🔴 LOW"
                print(f"    ✅ MATCH FOUND: {best_match['api_name'][:40]}...")
                print(f"    📊 Confidence: {best_confidence:.3f} ({confidence_level})")
                print(f"    🎯 Strategy: {best_match['match_strategy']}")
                print(f"    📝 Reason: {best_match['match_reason']}")
            else:
                print(f"    ❌ No match found (best confidence: {best_confidence:.3f})")
        
        print(f"\n" + "="*60)
        print("🎯 MATCHING COMPLETED")
        print("="*60)
        print(f"✅ Total matches found: {len(matches)}")
        print(f"📊 Coverage: {len(matches)}/{total_hotels} ({len(matches)/total_hotels*100:.1f}%)")
        print(f"⚡ Performance stats:")
        print(f"   📊 Total comparisons: {total_comparisons:,}")
        print(f"   🚫 Skipped (no ISO): {skipped_no_country}")
        print(f"   🚫 Skipped (no API country): {skipped_no_api_country}")
        
        # Algorithm effectiveness breakdown
        print(f"\n🧠 ALGORITHM EFFECTIVENESS:")
        for algo_name, count in algorithm_stats.items():
            if count > 0:
                percentage = (count / len(matches)) * 100 if matches else 0
                print(f"   📈 {algo_name}: {count} matches ({percentage:.1f}%)")
        
        # Strategy breakdown
        if matches:
            iso_matches = sum(1 for m in matches if m['match_strategy'] == 'ISO-based')
            name_matches = sum(1 for m in matches if m['match_strategy'] == 'Name-only fallback')
            
            print(f"\n📊 STRATEGY BREAKDOWN:")
            print(f"   🌍 ISO-based matching: {iso_matches} ({iso_matches/len(matches)*100:.1f}%)")
            print(f"   🔍 Name-only fallback: {name_matches} ({name_matches/len(matches)*100:.1f}%)")
        
        if matches:
            confidences = [m['confidence'] for m in matches]
            high_conf = sum(1 for c in confidences if c >= 0.85)
            med_conf = sum(1 for c in confidences if 0.70 <= c < 0.85)
            low_conf = sum(1 for c in confidences if c < 0.70)
            
            print(f"\n📈 CONFIDENCE DISTRIBUTION:")
            print(f"   🟢 High (≥0.85): {high_conf}")
            print(f"   🟡 Medium (0.70-0.84): {med_conf}")
            print(f"   🔴 Low (<0.70): {low_conf}")
        
        return matches
    
    def create_full_reference_with_results(self, matches: List[Dict]) -> pd.DataFrame:
        results_df = self.reference_hotels[['Lokalizacja', 'Hotel', 'reference_id']].copy()
        
        match_dict = {match['reference_id']: match for match in matches}
        
        results_df['api_id'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_id', ''))
        results_df['api_name'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_name', ''))
        results_df['api_chain'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_chain', ''))
        results_df['api_city'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_city', ''))
        results_df['api_address'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_address', ''))
        results_df['api_latitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_latitude', ''))
        results_df['api_longitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_longitude', ''))
        results_df['confidence'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('confidence', ''))
        results_df['match_reason'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_reason', ''))
        results_df['matched'] = results_df['api_id'] != ''
        
        return results_df
    
    def run_complete_matching(self, reference_csv: str, api_csv: str) -> Dict:
        print("🚀" + "="*58 + "🚀")
        print("🚀 HOTEL MAPPING ENGINE - ISO OPTIMIZED VERSION 🚀")
        print("🚀" + "="*58 + "🚀")
        print("Algorithm: ISO Pre-filtering + Rule-based Decision Tree")
        print("Features: Brand extraction + Geographic + String similarity")
        
        self.load_reference_hotels(reference_csv)
        if self.reference_hotels is None:
            return {'error': 'Failed to load reference hotels'}
            
        self.load_api_hotels(api_csv)
        if self.api_hotels is None:
            return {'error': 'Failed to load API hotels'}
        
        matches = self.run_matching()
        
        results = {
            'total_reference_hotels': len(self.reference_hotels),
            'total_api_hotels': len(self.api_hotels),
            'total_matches': len(matches),
            'coverage_percentage': len(matches) / len(self.reference_hotels) * 100,
            'matches': matches
        }
        
        return results
    
    def save_results(self, results: Dict, output_prefix: str = "hotel_mapping_iso"):
        print("\n" + "="*60)
        print("💾 SAVING RESULTS")
        print("="*60)
        
        matches = results['matches']
        
        if matches:
            matches_df = pd.DataFrame(matches)
            matches_file = f"{output_prefix}_matches.csv"
            matches_df.to_csv(matches_file, index=False)
            print(f"✅ Saved matches: {matches_file}")
        
        full_results = self.create_full_reference_with_results(matches)
        full_file = f"{output_prefix}_full_reference.csv"
        full_results.to_csv(full_file, index=False)
        print(f"✅ Saved full reference: {full_file}")
        
        summary = pd.DataFrame({
            'metric': ['Total Reference Hotels', 'Total API Hotels', 'Total Matches', 'Coverage Percentage'],
            'value': [results['total_reference_hotels'], results['total_api_hotels'], 
                     results['total_matches'], f"{results['coverage_percentage']:.1f}%"]
        })
        summary_file = f"{output_prefix}_summary.csv"
        summary.to_csv(summary_file, index=False)
        print(f"✅ Saved summary: {summary_file}")
        
        print(f"\n🎯 FINAL RESULTS:")
        print(f"   📚 Reference hotels: {results['total_reference_hotels']}")
        print(f"   📡 API hotels: {results['total_api_hotels']:,}")
        print(f"   ✅ Matches found: {results['total_matches']}")
        print(f"   📊 Coverage: {results['coverage_percentage']:.1f}%")


if __name__ == "__main__":
    matcher = ISOHotelMatcher()
    
    results = matcher.run_complete_matching(
        reference_csv="00_api_lista_referencyjna.csv",
        api_csv="01_api_rate_hawk.csv"
    )
    
    matcher.save_results(results)
    
    print("\n" + "="*60)
    print("🏁 HOTEL MAPPING COMPLETED!")
    print("="*60)
# Out:
# 🚀==========================================================🚀
# 🚀 HOTEL MAPPING ENGINE - ISO OPTIMIZED VERSION 🚀
# 🚀==========================================================🚀
# Algorithm: ISO Pre-filtering + Rule-based Decision Tree
# Features: Brand extraction + Geographic + String similarity
#
# ============================================================
# 📂 LOADING REFERENCE HOTELS
# ============================================================
# ✅ Loaded file: 00_api_lista_referencyjna.csv
# 📊 Found 97 reference hotels
#
# 🧹 Processing reference data...
# 🌍 Mapping countries to ISO codes...
# 📈 Countries distribution:
#    GR (Greece): 13 hotels
#    MV (Maldives): 12 hotels
#    AE (United Arab Emirates): 11 hotels
#    ES (Spain): 8 hotels
#    TH (Thailand): 7 hotels
# 🏨 Luxury brands detected: 23
# ✅ Processed 97 reference hotels
#
# ============================================================
# 📡 LOADING API HOTELS
# ============================================================
# ✅ Loaded file: 01_api_rate_hawk.csv
# 📊 Found 95,463 API hotels
#
# 🧹 Processing API data...
# 🌍 API countries distribution:
#    AE (United Arab Emirates): 12,942 hotels
#    GR (Greece): 8,592 hotels
#    TH (Thailand): 8,063 hotels
#    US (United States): 7,858 hotels
#    ES (Spain): 6,906 hotels
# 📍 Hotels with coordinates: 95,463/95,463 (100.0%)
# 🏨 Top 3 hotel chains:
#    No chain: 91,821 hotels
#    ZenRooms: 162 hotels
#    Choice Hotels: 144 hotels
# ✅ Processed 95,463 API hotels
#
# ============================================================
# 🎯 RUNNING HOTEL MATCHING
# ============================================================
# 📊 Processing 97 reference hotels
# 🔧 ISO pre-filtering active - grouping API by country
# 🌍 API countries available: 27
#
# [ 1/97] Processing: Hilton Aruba Caribbean Resort & Casino, Aruba...
#     🌍 Country: AW
#     📍 ISO candidates: 1,255
#     ... checked 1,000/1,255 candidates
#     ✅ MATCH FOUND: Hilton Aruba Caribbean Resort and Casino...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (0.94) + country
#
# [ 2/97] Processing: Shangri-La Sydney...
#     🌍 Country: AU
#     📍 ISO candidates: 3,669
#     ... checked 1,000/3,669 candidates
#     ... checked 2,000/3,669 candidates
#     ... checked 3,000/3,669 candidates
#     ✅ MATCH FOUND: Shangri-La Sydney...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [ 3/97] Processing: One & Only Portovovi, Czarnogóra...
#     🌍 Country: ME
#     📍 ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3597
#     ❌ No match found (best confidence: 0.000)
#
# [ 4/97] Processing: Dukley Hotel & Resort, Czarnogóra...
#     🌍 Country: ME
#     📍 ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1171
#     ✅ MATCH FOUND: Dukley Hotel & Resort...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [ 5/97] Processing: Tortuga Bay Puntacana Resort & Club, Dominikana...
#     🌍 Country: DO
#     📍 ISO candidates: 5,826
#     ... checked 1,000/5,826 candidates
#     ... checked 2,000/5,826 candidates
#     ... checked 3,000/5,826 candidates
#     ... checked 4,000/5,826 candidates
#     ... checked 5,000/5,826 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4003
#     ✅ MATCH FOUND: Tortuga Bay Hotel at Puntacana Resort & ...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [ 6/97] Processing: The Chedi El Gouna, Egipt...
#     🌍 Country: EG
#     📍 ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3691
#     ❌ No match found (best confidence: 0.000)
#
# [ 7/97] Processing: Four Seasons Sharm El Sheikh, Egipt...
#     🌍 Country: EG
#     📍 ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Sharm EL Sheikh...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [ 8/97] Processing: Hotel Du Palais Biarritz - The Unbound Collection ...
#     🌍 Country: FR
#     📍 ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     ✅ MATCH FOUND: Hôtel du Palais...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [ 9/97] Processing: Le Fitz Roy, Val Thorens...
#     🌍 Country: FR
#     📍 ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Le Val Thorens...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [10/97] Processing: One & Only Aesthesis, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [11/97] Processing: The Stanley, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: The Stanley...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [12/97] Processing: Wyndham Grand Athens, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Athens Suites...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [13/97] Processing: Sani Club Hotel, Chalkidiki...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1956
#     ❌ No match found (best confidence: 0.000)
#
# [14/97] Processing: Ikos Oceania, Chalkidiki...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2297
#     ❌ No match found (best confidence: 0.000)
#
# [15/97] Processing: Romanos, Costa Navarino...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [16/97] Processing: Mandarin Oriental, Costa Navarino...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Costa Navarino...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [17/97] Processing: Grecotel Corfu Imperial...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Corfu Palace...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [18/97] Processing: Angsana Corfu Resort...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Angsana Corfu Resort & Spa...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [19/97] Processing: Ikos Dassia, Korfu...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1956
#     ❌ No match found (best confidence: 0.000)
#
# [20/97] Processing: Daios Cove, Kreta...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [21/97] Processing: Domes Zeen, a Luxury Collection Resort, Kreta...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Luxury V Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: High partial (1.00) + indicators
#
# [22/97] Processing: Elivi Skiathos...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4225
#     ❌ No match found (best confidence: 0.000)
#
# [23/97] Processing: Quark Expeditions...
#     🌍 Country: GL
#     ⚠️  No API hotels for GL - trying name-only fallback
#     🔍 Name-only candidates: 1836
#     ❌ No match found (best confidence: 0.000)
#
# [24/97] Processing: Ikos Andalusia...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4918
#     ❌ No match found (best confidence: 0.000)
#
# [25/97] Processing: Ikos Porto Petro, Majorka...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [26/97] Processing: Marbella Club...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Hotel Marbella...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [27/97] Processing: METT Marbella Hotel, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Marbella Resort...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [28/97] Processing: Puente Romano, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [29/97] Processing: El Fuerte Marbella, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: El Fuerte Marbella...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [30/97] Processing: Bahia Del Duque...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4149
#     ❌ No match found (best confidence: 0.000)
#
# [31/97] Processing: SH Valencia Palace, Walencja...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: SH Valencia Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [32/97] Processing: Four Seasons Jimbaran Bay, Bali...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Bali at Jimbaran Bay...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [33/97] Processing: The Laguna, A Luxury Collection Resort & Spa...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: The Laguna, a Luxury Collection Resort &...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: High partial (1.00) + indicators
#
# [34/97] Processing: The St Regis Bali Resort Nusa Dua...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Bali Nusa Dua Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [35/97] Processing: The Retreat at Blue Lagoon Iceland...
#     🌍 Country: IS
#     📍 ISO candidates: 15
#     ✅ MATCH FOUND: The Retreat at Blue Lagoon Iceland...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [36/97] Processing: Movenpick Resort Kuredhivaru Maldives...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2236
#     ✅ MATCH FOUND: Kuredhivaru Resort & Spa Maldives...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Perfect brand + decent name (name-only)
#
# [37/97] Processing: Finolhu, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1660
#     ❌ No match found (best confidence: 0.000)
#
# [38/97] Processing: Vakkaru...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 681
#     ✅ MATCH FOUND: Vakkaru Maldives Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [39/97] Processing: JOALI Being...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Joali Being...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [40/97] Processing: Patina Maldives, Fari Islands...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Patina Maldives, Fari Islands...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [41/97] Processing: JOALI Maldives...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: JOALI Maldives Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [42/97] Processing: Velaa Private Island...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Velaa Private Island...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [43/97] Processing: Waldorf Astoria Maldives Ithaafushi...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Maldives Ithaafushi Hote...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [44/97] Processing: Emerald Resort, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2926
#     ✅ MATCH FOUND: Emerald Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [45/97] Processing: One & Only Reethi Rah...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: One&Only Reethi Rah Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [46/97] Processing: Niyama Private Island...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Royal Island Resort & Spa...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [47/97] Processing: Lily Beach Resort & Spa, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Lily Beach Resort & Spa...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [48/97] Processing: Four Seasons Langkawi...
#     🌍 Country: MY
#     📍 ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Langkawi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [49/97] Processing: The Datai, Malezja...
#     🌍 Country: MY
#     📍 ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4704
#     ❌ No match found (best confidence: 0.000)
#
# [50/97] Processing: Four Seasons Marakesh, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4888
#     ✅ MATCH FOUND: Four Seasons Hotel Doha...
#     📊 Confidence: 0.650 (🔴 LOW)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High partial + indicators (name-only)
#
# [51/97] Processing: Jaal Riad Resort, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [52/97] Processing: The St. Regis La Bahia Blanca Resort, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Bahia Blanca...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [53/97] Processing: JW Marriott Mauritius Resort...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3276
#     ✅ MATCH FOUND: JW Marriott Miami...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Perfect brand + decent name (name-only)
#
# [54/97] Processing: Sugar Beach Mauritius...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: Sugar Beach Mauritius...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [55/97] Processing: One & Only Le Saint Geran...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: One&Only Le Saint Géran...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (0.96) + country
#
# [56/97] Processing: Belmond Reid's Palace, Portugalia...
#     🌍 Country: PT
#     📍 ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: GA Palace Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: High partial (1.00) + indicators
#
# [57/97] Processing: The Lodge Hotel, Porto...
#     🌍 Country: PT
#     📍 ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: Vincci Porto...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [58/97] Processing: The Raffles Doha...
#     🌍 Country: QA
#     📍 ISO candidates: 498
#     ✅ MATCH FOUND: Raffles Doha...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [59/97] Processing: Fancourt Hotel...
#     🌍 Country: ZA
#     📍 ISO candidates: 601
#     ✅ MATCH FOUND: Fancourt...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [60/97] Processing: Waldorf Astoria Seychelles...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4694
#     ✅ MATCH FOUND: Waldorf Astoria Seychelles Platte Island...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [61/97] Processing: Four Seasons Resort Seychelles at Desroches Island...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Four Seasons Resort Seychelles at Desroc...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [62/97] Processing: Six Senses Zil Pasyon...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Six Senses Zil Pasyon Seychelles...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: High partial (1.00) + indicators
#
# [63/97] Processing: Raffles Prasiln...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4941
#     ✅ MATCH FOUND: Raffles Dubai Hotel...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Perfect brand + decent name (name-only)
#
# [64/97] Processing: Mandarin Oriental, Singapur...
#     🌍 Country: SG
#     📍 ISO candidates: 1,085
#     ... checked 1,000/1,085 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Singapore...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (0.94) + country
#
# [65/97] Processing: Chedi Andermatt, Szwajcaria...
#     🌍 Country: CH
#     📍 ISO candidates: 392
#     ✅ MATCH FOUND: The Chedi Andermatt...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [66/97] Processing: Badrutt's Palace, Szwajcaria...
#     🌍 Country: CH
#     📍 ISO candidates: 392
#     ✅ MATCH FOUND: Badrutt's Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [67/97] Processing: Banyan Tree Krabi...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Banyan Tree Krabi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [68/97] Processing: Ritz Carlton Phulay Bay...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phulay Bay, a Ritz-Carlton Reserve...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [69/97] Processing: Dusit Thani, Pattaya...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dusit Thani Pattaya...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [70/97] Processing: Saii Phi Phi Island Village Resort, Tajlandia...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phi Phi Inn...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Token set (1.00) + location
#
# [71/97] Processing: Rosewood Phuket...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2281
#     ✅ MATCH FOUND: Rosewood Doha...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Perfect brand + decent name (name-only)
#
# [72/97] Processing: Intercontinental Phuket Resort, Tajlandia...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dinso Resort & Villas Phuket, Vignette C...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [73/97] Processing: Six Senses Yao Noi...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Six Senses Yao Noi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [74/97] Processing: Gloria Serenity Resort...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.679) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Serenity Inn...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [75/97] Processing: Regnum Carya Golf & Spa Resort, Turcja...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2492
#     ❌ No match found (best confidence: 0.000)
#
# [76/97] Processing: Maxx Royal Belek Golf Resort, Belek...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     ✅ MATCH FOUND: Belek...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [77/97] Processing: Jumeirah at Saadiyat Island Resort, UAE...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Jumeirah Saadiyat Island Abu Dhabi...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (0.92) + location
#
# [78/97] Processing: Atlantis The Royal...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis The Royal Hotel...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [79/97] Processing: One & Only Royal Mirage...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only Royal Mirage Hotel...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [80/97] Processing: Atlantis The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis, The Palm...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Very high token sort (1.00) + country
#
# [81/97] Processing: Mandarin Oriental Jumeira Dubai...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Hotel mandarin oriental jumeira, dubai...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [82/97] Processing: Burj Al Arab...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Jumeirah Burj Al Arab Dubai...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [83/97] Processing: One & Only The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only The Palm, Dubai Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [84/97] Processing: The Ritz-Carlton, Jumeirah...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: The Ritz-Carlton, Dubai Hotel...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [85/97] Processing: Four Seasons Resort at Jumeirah Beach...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Four Seasons Dubai at Jumeirah Beach Res...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [86/97] Processing: Waldorf Astoria The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Al Habtoor Palace Hotel...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [87/97] Processing: DoubleTree by Hilton Resort & Spa Marjan Island, U...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Rixos Al Mairid Ras Al Khaimah...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Perfect brand + location
#
# [88/97] Processing: The Betsy Hotel, Miami...
#     🌍 Country: US
#     📍 ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: W Miami...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [89/97] Processing: Four Seasons Resort Orlando at Walt Disney World R...
#     🌍 Country: US
#     📍 ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: Orlando Motel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [90/97] Processing: Fairmont St Andrews, Szkocja...
#     🌍 Country: GB
#     📍 ISO candidates: 943
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [91/97] Processing: Regent Phu Quoc Hotel, Wietnam...
#     🌍 Country: VN
#     📍 ISO candidates: 1,058
#     ... checked 1,000/1,058 candidates
#     ✅ MATCH FOUND: M Resort Phu Quoc...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: High token set (1.00) + location
#
# [92/97] Processing: Lefay Resort & SPA Dolomiti...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2691
#     ✅ MATCH FOUND: Dolomiti...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [93/97] Processing: Alpin & Vital Hotel La Perla, Ortisei, Włochy...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [94/97] Processing: Lefay Resort Lago Di Garda, Włochy...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2570
#     ❌ No match found (best confidence: 0.000)
#
# [95/97] Processing: Forte Village, Sardynia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: The Village Resort...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [96/97] Processing: The Abi d'Oru Hotel & Spa, Sardynia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [97/97] Processing: Verdura Golf & Spa Resort, Sycylia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1804
#     ❌ No match found (best confidence: 0.000)
#
# ============================================================
# 🎯 MATCHING COMPLETED
# ============================================================
# ✅ Total matches found: 74
# 📊 Coverage: 74/97 (76.3%)
# ⚡ Performance stats:
#    📊 Total comparisons: 673,675
#    🚫 Skipped (no ISO): 0
#    🚫 Skipped (no API country): 0
#
# 🧠 ALGORITHM EFFECTIVENESS:
#    📈 Perfect brand + location: 13 matches (17.6%)
#    📈 High partial + indicators: 1 matches (1.4%)
#    📈 Name-only fallback: 17 matches (23.0%)
#
# 📊 STRATEGY BREAKDOWN:
#    🌍 ISO-based matching: 56 (75.7%)
#    🔍 Name-only fallback: 18 (24.3%)
#
# 📈 CONFIDENCE DISTRIBUTION:
#    🟢 High (≥0.85): 51
#    🟡 Medium (0.70-0.84): 22
#    🔴 Low (<0.70): 1
#
# ============================================================
# 💾 SAVING RESULTS
# ============================================================
# ✅ Saved matches: hotel_mapping_iso_matches.csv
# ✅ Saved full reference: hotel_mapping_iso_full_reference.csv
# ✅ Saved summary: hotel_mapping_iso_summary.csv
#
# 🎯 FINAL RESULTS:
#    📚 Reference hotels: 97
#    📡 API hotels: 95,463
#    ✅ Matches found: 74
#    📊 Coverage: 76.3%
#
# ============================================================
# 🏁 HOTEL MAPPING COMPLETED!
# ============================================================

# %%
import pandas as pd
import numpy as np
from collections import Counter
import re
from typing import Dict, List, Tuple

class APIPatternAnalyzer:
    def __init__(self):
        self.api_data = None
        
    def load_api_data(self, csv_path: str):
        """Load API data for analysis"""
        print("🔍 Loading API data for pattern analysis...")
        self.api_data = pd.read_csv(csv_path)
        print(f"✅ Loaded {len(self.api_data):,} hotels from API")
        
    def analyze_naming_patterns(self, sample_size: int = 10000):
        """Analyze hotel naming patterns in API"""
        print("\n" + "="*60)
        print("📝 HOTEL NAMING PATTERNS ANALYSIS")
        print("="*60)
        
        # Sample for performance
        sample_data = self.api_data.sample(min(sample_size, len(self.api_data)))
        names = sample_data['name'].dropna()
        
        print(f"Analyzing {len(names):,} hotel names...")
        
        # Common words analysis
        all_words = []
        for name in names:
            words = re.findall(r'\b\w+\b', str(name).lower())
            all_words.extend(words)
        
        word_freq = Counter(all_words)
        
        print(f"\n🔤 MOST COMMON WORDS (top 20):")
        for word, count in word_freq.most_common(20):
            percentage = (count / len(all_words)) * 100
            print(f"   {word:<15}: {count:,} ({percentage:.1f}%)")
        
        # Naming patterns
        patterns = {
            'hotel_word': names.str.contains(r'\bhotel\b', case=False, na=False).sum(),
            'resort_word': names.str.contains(r'\bresort\b', case=False, na=False).sum(),
            'spa_word': names.str.contains(r'\bspa\b', case=False, na=False).sum(),
            'palace_word': names.str.contains(r'\bpalace\b', case=False, na=False).sum(),
            'royal_word': names.str.contains(r'\broyal\b', case=False, na=False).sum(),
            'grand_word': names.str.contains(r'\bgrand\b', case=False, na=False).sum(),
            'luxury_word': names.str.contains(r'\bluxury\b', case=False, na=False).sum(),
            'club_word': names.str.contains(r'\bclub\b', case=False, na=False).sum(),
            'suites_word': names.str.contains(r'\bsuites?\b', case=False, na=False).sum(),
            'inn_word': names.str.contains(r'\binn\b', case=False, na=False).sum(),
            'lodge_word': names.str.contains(r'\blodge\b', case=False, na=False).sum(),
            'villa_word': names.str.contains(r'\bvilla\b', case=False, na=False).sum(),
            'apartments': names.str.contains(r'\bapartments?\b', case=False, na=False).sum(),
            'hostel_word': names.str.contains(r'\bhostel\b', case=False, na=False).sum(),
            'guest_house': names.str.contains(r'\bguest.?house\b', case=False, na=False).sum(),
            'bed_breakfast': names.str.contains(r'\bb&b\b|\bbed.?breakfast\b', case=False, na=False).sum(),
        }
        
        print(f"\n🏨 HOTEL TYPE PATTERNS:")
        total_names = len(names)
        for pattern, count in sorted(patterns.items(), key=lambda x: x[1], reverse=True):
            percentage = (count / total_names) * 100
            if count > 0:
                print(f"   {pattern.replace('_', ' ').title():<20}: {count:,} ({percentage:.1f}%)")
    
    def analyze_chain_patterns(self):
        """Analyze hotel chain distribution and patterns"""
        print("\n" + "="*60)
        print("🏢 HOTEL CHAIN PATTERNS ANALYSIS")
        print("="*60)
        
        chains = self.api_data['hotel_chain'].dropna()
        chain_counts = chains.value_counts()
        
        print(f"📊 Total hotels with chain info: {len(chains):,}")
        print(f"📊 Unique chains: {chain_counts.nunique():,}")
        print(f"📊 Hotels without chain: {self.api_data['hotel_chain'].isna().sum():,}")
        
        print(f"\n🏆 TOP 15 HOTEL CHAINS:")
        for chain, count in chain_counts.head(15).items():
            percentage = (count / len(chains)) * 100
            print(f"   {chain:<25}: {count:,} ({percentage:.1f}%)")
        
        # Chain size distribution
        chain_sizes = chain_counts.value_counts().sort_index()
        print(f"\n📈 CHAIN SIZE DISTRIBUTION:")
        print(f"   Single property chains: {(chain_sizes == 1).sum():,}")
        print(f"   2-5 properties: {chain_sizes[(chain_sizes >= 2) & (chain_sizes <= 5)].sum():,}")
        print(f"   6-20 properties: {chain_sizes[(chain_sizes >= 6) & (chain_sizes <= 20)].sum():,}")
        print(f"   21-100 properties: {chain_sizes[(chain_sizes >= 21) & (chain_sizes <= 100)].sum():,}")
        print(f"   100+ properties: {chain_sizes[chain_sizes > 100].sum():,}")
    
    def analyze_geographic_patterns(self):
        """Analyze geographic distribution and patterns"""
        print("\n" + "="*60)
        print("🌍 GEOGRAPHIC PATTERNS ANALYSIS")
        print("="*60)
        
        # Country distribution
        countries = self.api_data['country'].dropna()
        country_counts = countries.value_counts()
        
        print(f"📊 Total countries: {country_counts.nunique()}")
        print(f"\n🌍 TOP 15 COUNTRIES BY HOTEL COUNT:")
        for country, count in country_counts.head(15).items():
            percentage = (count / len(countries)) * 100
            print(f"   {country:<5}: {count:,} ({percentage:.1f}%)")
        
        # City patterns
        cities = self.api_data['city'].dropna()
        city_counts = cities.value_counts()
        
        print(f"\n🏙️  TOP 15 CITIES BY HOTEL COUNT:")
        for city, count in city_counts.head(15).items():
            percentage = (count / len(cities)) * 100
            print(f"   {city:<20}: {count:,} ({percentage:.1f}%)")
        
        # Coordinate coverage
        coords_available = self.api_data[['latitude', 'longitude']].notna().all(axis=1).sum()
        coords_percentage = (coords_available / len(self.api_data)) * 100
        print(f"\n📍 COORDINATE COVERAGE:")
        print(f"   Hotels with coordinates: {coords_available:,} ({coords_percentage:.1f}%)")
        print(f"   Hotels without coordinates: {len(self.api_data) - coords_available:,}")
    
    def analyze_address_patterns(self, sample_size: int = 5000):
        """Analyze address patterns and structure"""
        print("\n" + "="*60)
        print("📮 ADDRESS PATTERNS ANALYSIS")
        print("="*60)
        
        sample_data = self.api_data.sample(min(sample_size, len(self.api_data)))
        addresses = sample_data['address'].dropna()
        
        print(f"Analyzing {len(addresses):,} addresses...")
        
        # Address length distribution
        addr_lengths = addresses.str.len()
        print(f"\n📏 ADDRESS LENGTH STATS:")
        print(f"   Average length: {addr_lengths.mean():.1f} characters")
        print(f"   Median length: {addr_lengths.median():.1f} characters")
        print(f"   Min length: {addr_lengths.min()}")
        print(f"   Max length: {addr_lengths.max()}")
        
        # Common address words
        all_addr_words = []
        for addr in addresses:
            words = re.findall(r'\b\w+\b', str(addr).lower())
            all_addr_words.extend(words)
        
        addr_word_freq = Counter(all_addr_words)
        
        print(f"\n🔤 MOST COMMON ADDRESS WORDS (top 15):")
        for word, count in addr_word_freq.most_common(15):
            if len(word) > 2:  # Skip very short words
                percentage = (count / len(all_addr_words)) * 100
                print(f"   {word:<15}: {count:,} ({percentage:.1f}%)")
        
        # Address patterns
        street_pattern = r'\bstreet\b|\bst\b|\bstr\b'
        avenue_pattern = r'\bavenue\b|\bave\b'
        road_pattern = r'\broad\b|\brd\b'
        boulevard_pattern = r'\bboulevard\b|\bblvd\b'
        number_pattern = r'\d+'
        postal_pattern = r'\b\d{5,6}\b'
        
        addr_patterns = {
            'contains_street': addresses.str.contains(street_pattern, case=False, na=False).sum(),
            'contains_avenue': addresses.str.contains(avenue_pattern, case=False, na=False).sum(),
            'contains_road': addresses.str.contains(road_pattern, case=False, na=False).sum(),
            'contains_boulevard': addresses.str.contains(boulevard_pattern, case=False, na=False).sum(),
            'contains_numbers': addresses.str.contains(number_pattern, na=False).sum(),
            'contains_postal': addresses.str.contains(postal_pattern, na=False).sum(),
        }
        
        print(f"\n🗺️  ADDRESS STRUCTURE PATTERNS:")
        total_addresses = len(addresses)
        for pattern, count in addr_patterns.items():
            percentage = (count / total_addresses) * 100
            print(f"   {pattern.replace('_', ' ').title():<20}: {count:,} ({percentage:.1f}%)")
    
    def analyze_data_quality(self):
        """Analyze data quality and completeness"""
        print("\n" + "="*60)
        print("✅ DATA QUALITY ANALYSIS")
        print("="*60)
        
        total_hotels = len(self.api_data)
        
        # Field completeness
        fields = ['name', 'city', 'country', 'address', 'latitude', 'longitude', 'hotel_chain']
        
        print(f"📊 FIELD COMPLETENESS (total: {total_hotels:,} hotels):")
        for field in fields:
            non_null = self.api_data[field].notna().sum()
            percentage = (non_null / total_hotels) * 100
            empty_str = (self.api_data[field] == '').sum() if self.api_data[field].dtype == 'object' else 0
            effective_data = non_null - empty_str
            effective_percentage = (effective_data / total_hotels) * 100
            
            print(f"   {field:<15}: {effective_data:,} ({effective_percentage:.1f}%) [null: {total_hotels-non_null:,}, empty: {empty_str:,}]")
        
        # Duplicates analysis
        name_duplicates = self.api_data['name'].duplicated().sum()
        id_duplicates = self.api_data['id'].duplicated().sum()
        
        print(f"\n🔍 DUPLICATES ANALYSIS:")
        print(f"   Duplicate names: {name_duplicates:,}")
        print(f"   Duplicate IDs: {id_duplicates:,}")
        
        # Name quality patterns
        names = self.api_data['name'].dropna()
        digit_pattern = r'\d'
        print(f"\n📝 NAME QUALITY PATTERNS:")
        print(f"   Very short names (≤3 chars): {(names.str.len() <= 3).sum():,}")
        print(f"   Very long names (≥100 chars): {(names.str.len() >= 100).sum():,}")
        print(f"   Names with numbers: {names.str.contains(digit_pattern, na=False).sum():,}")
        print(f"   Names all caps: {names.str.isupper().sum():,}")
        print(f"   Names all lowercase: {names.str.islower().sum():,}")
    
    def find_premium_indicators(self, sample_size: int = 10000):
        """Find patterns that indicate premium/luxury hotels"""
        print("\n" + "="*60)
        print("💎 PREMIUM HOTEL INDICATORS ANALYSIS")
        print("="*60)
        
        sample_data = self.api_data.sample(min(sample_size, len(self.api_data)))
        names = sample_data['name'].dropna()
        
        # Premium keywords
        premium_keywords = {
            'luxury': names.str.contains(r'\bluxury\b', case=False, na=False).sum(),
            'premium': names.str.contains(r'\bpremium\b', case=False, na=False).sum(),
            'deluxe': names.str.contains(r'\bdeluxe\b', case=False, na=False).sum(),
            'exclusive': names.str.contains(r'\bexclusive\b', case=False, na=False).sum(),
            'royal': names.str.contains(r'\broyal\b', case=False, na=False).sum(),
            'grand': names.str.contains(r'\bgrand\b', case=False, na=False).sum(),
            'palace': names.str.contains(r'\bpalace\b', case=False, na=False).sum(),
            'imperial': names.str.contains(r'\bimperial\b', case=False, na=False).sum(),
            'signature': names.str.contains(r'\bsignature\b', case=False, na=False).sum(),
            'collection': names.str.contains(r'\bcollection\b', case=False, na=False).sum(),
            'reserve': names.str.contains(r'\breserve\b', case=False, na=False).sum(),
            'retreat': names.str.contains(r'\bretreat\b', case=False, na=False).sum(),
            'estate': names.str.contains(r'\bestate\b', case=False, na=False).sum(),
            'private': names.str.contains(r'\bprivate\b', case=False, na=False).sum(),
            'boutique': names.str.contains(r'\bboutique\b', case=False, na=False).sum(),
        }
        
        print(f"💎 PREMIUM KEYWORDS FREQUENCY:")
        total_names = len(names)
        for keyword, count in sorted(premium_keywords.items(), key=lambda x: x[1], reverse=True):
            if count > 0:
                percentage = (count / total_names) * 100
                print(f"   {keyword.title():<12}: {count:,} ({percentage:.1f}%)")
        
        # Number patterns that might indicate luxury (like "5*", "five star")
        star_patterns = {
            'five_star': names.str.contains(r'\b5\s*star|\bfive\s*star\b', case=False, na=False).sum(),
            'four_star': names.str.contains(r'\b4\s*star|\bfour\s*star\b', case=False, na=False).sum(),
            'stars_symbol': names.str.contains(r'\*+', na=False).sum(),
        }
        
        print(f"\n⭐ STAR RATING PATTERNS:")
        for pattern, count in star_patterns.items():
            if count > 0:
                percentage = (count / total_names) * 100
                print(f"   {pattern.replace('_', ' ').title():<15}: {count:,} ({percentage:.1f}%)")
    
    def run_complete_analysis(self, csv_path: str):
        """Run all analyses"""
        self.load_api_data(csv_path)
        
        self.analyze_naming_patterns()
        self.analyze_chain_patterns()
        self.analyze_geographic_patterns()
        self.analyze_address_patterns()
        self.analyze_data_quality()
        self.find_premium_indicators()
        
        print("\n" + "="*60)
        print("🏁 PATTERN ANALYSIS COMPLETED!")
        print("="*60)
        print("💡 Use these insights to optimize matching algorithms!")

if __name__ == "__main__":
    analyzer = APIPatternAnalyzer()
    analyzer.run_complete_analysis("01_api_rate_hawk.csv")
# Out:
# 🔍 Loading API data for pattern analysis...
# ✅ Loaded 95,463 hotels from API
#
# ============================================================
# 📝 HOTEL NAMING PATTERNS ANALYSIS
# ============================================================
# Analyzing 10,000 hotel names...
#
# 🔤 MOST COMMON WORDS (top 20):
#    apartment      : 1,008 (2.1%)
#    hotel          : 930 (1.9%)
#    villa          : 854 (1.8%)
#    in             : 843 (1.7%)
#    beach          : 751 (1.6%)
#    apartments     : 661 (1.4%)
#    by             : 638 (1.3%)
#    the            : 635 (1.3%)
#    with           : 634 (1.3%)
#    2              : 466 (1.0%)
#    view           : 465 (1.0%)
#    house          : 425 (0.9%)
#    bedroom        : 380 (0.8%)
#    resort         : 377 (0.8%)
#    1              : 369 (0.8%)
#    pool           : 340 (0.7%)
#    studio         : 331 (0.7%)
#    3              : 316 (0.7%)
#    and            : 304 (0.6%)
#    luxury         : 270 (0.6%)
#
# 🏨 HOTEL TYPE PATTERNS:
#    Apartments          : 1,656 (16.6%)
#    Hotel Word          : 922 (9.2%)
#    Villa Word          : 831 (8.3%)
#    Resort Word         : 373 (3.7%)
#    Suites Word         : 324 (3.2%)
#    Luxury Word         : 270 (2.7%)
#    Inn Word            : 197 (2.0%)
#    Guest House         : 197 (2.0%)
#    Hostel Word         : 116 (1.2%)
#    Spa Word            : 97 (1.0%)
#    Club Word           : 78 (0.8%)
#    Grand Word          : 60 (0.6%)
#    Royal Word          : 56 (0.6%)
#    Lodge Word          : 51 (0.5%)
#    Bed Breakfast       : 43 (0.4%)
#    Palace Word         : 42 (0.4%)
#
# ============================================================
# 🏢 HOTEL CHAIN PATTERNS ANALYSIS
# ============================================================
# 📊 Total hotels with chain info: 95,463
# 📊 Unique chains: 42
# 📊 Hotels without chain: 0
#
# 🏆 TOP 15 HOTEL CHAINS:
#    No chain                 : 91,821 (96.2%)
#    ZenRooms                 : 162 (0.2%)
#    Choice Hotels            : 144 (0.2%)
#    Marriott Hotels & Resorts: 130 (0.1%)
#    Accor Hotels             : 124 (0.1%)
#    Hilton Hotels & Resorts  : 101 (0.1%)
#    Wyndham                  : 91 (0.1%)
#    Best Western             : 74 (0.1%)
#    InterContinental Hotels & Resorts: 71 (0.1%)
#    Hyatt                    : 48 (0.1%)
#    Millennium Hotels and Resorts: 43 (0.0%)
#    Holiday Inn              : 40 (0.0%)
#    Ibis                     : 37 (0.0%)
#    Holiday Inn Express      : 36 (0.0%)
#    Courtyard by Marriott    : 34 (0.0%)
#
# 📈 CHAIN SIZE DISTRIBUTION:
#    Single property chains: 19
#    2-5 properties: 36
#    6-20 properties: 63
#    21-100 properties: 235
#    100+ properties: 171
#
# ============================================================
# 🌍 GEOGRAPHIC PATTERNS ANALYSIS
# ============================================================
# 📊 Total countries: 27
#
# 🌍 TOP 15 COUNTRIES BY HOTEL COUNT:
#    AE   : 12,942 (13.6%)
#    GR   : 8,592 (9.0%)
#    TH   : 8,063 (8.4%)
#    US   : 7,858 (8.2%)
#    ES   : 6,906 (7.2%)
#    ME   : 6,233 (6.5%)
#    DO   : 5,826 (6.1%)
#    IT   : 5,620 (5.9%)
#    ID   : 5,189 (5.4%)
#    PT   : 4,368 (4.6%)
#    AU   : 3,669 (3.8%)
#    TR   : 3,267 (3.4%)
#    FR   : 2,938 (3.1%)
#    MU   : 1,930 (2.0%)
#    EG   : 1,788 (1.9%)
#
# 🏙️  TOP 15 CITIES BY HOTEL COUNT:
#    Dubai               : 12,267 (12.9%)
#    Athens              : 5,249 (5.5%)
#    Pattaya             : 4,226 (4.4%)
#    Porto               : 3,748 (3.9%)
#    Sydney              : 3,372 (3.5%)
#    Marbella            : 2,655 (2.8%)
#    Miami Beach         : 1,811 (1.9%)
#    Orlando             : 1,662 (1.7%)
#    Valencia            : 1,588 (1.7%)
#    Antalya             : 1,503 (1.6%)
#    Miami               : 1,325 (1.4%)
#    Budva               : 1,265 (1.3%)
#    Singapore           : 1,084 (1.1%)
#    Porto Cesareo       : 1,066 (1.1%)
#    Phu Quoc            : 1,056 (1.1%)
#
# 📍 COORDINATE COVERAGE:
#    Hotels with coordinates: 95,463 (100.0%)
#    Hotels without coordinates: 0
#
# ============================================================
# 📮 ADDRESS PATTERNS ANALYSIS
# ============================================================
# Analyzing 5,000 addresses...
#
# 📏 ADDRESS LENGTH STATS:
#    Average length: 45.4 characters
#    Median length: 40.0 characters
#    Min length: 11
#    Max length: 192
#
# 🔤 MOST COMMON ADDRESS WORDS (top 15):
#    dubai          : 881 (2.4%)
#    porto          : 582 (1.6%)
#    beach          : 376 (1.0%)
#    athens         : 345 (0.9%)
#    pattaya        : 331 (0.9%)
#    road           : 315 (0.9%)
#    bali           : 286 (0.8%)
#    miami          : 283 (0.8%)
#    street         : 272 (0.7%)
#    via            : 219 (0.6%)
#    calle          : 198 (0.5%)
#
# 🗺️  ADDRESS STRUCTURE PATTERNS:
#    Contains Street     : 461 (9.2%)
#    Contains Avenue     : 204 (4.1%)
#    Contains Road       : 408 (8.2%)
#    Contains Boulevard  : 109 (2.2%)
#    Contains Numbers    : 3,733 (74.7%)
#    Contains Postal     : 1,267 (25.3%)
#
# ============================================================
# ✅ DATA QUALITY ANALYSIS
# ============================================================
# 📊 FIELD COMPLETENESS (total: 95,463 hotels):
#    name           : 95,463 (100.0%) [null: 0, empty: 0]
#    city           : 95,463 (100.0%) [null: 0, empty: 0]
#    country        : 95,463 (100.0%) [null: 0, empty: 0]
#    address        : 95,463 (100.0%) [null: 0, empty: 0]
#    latitude       : 95,463 (100.0%) [null: 0, empty: 0]
#    longitude      : 95,463 (100.0%) [null: 0, empty: 0]
#    hotel_chain    : 95,463 (100.0%) [null: 0, empty: 0]
#
# 🔍 DUPLICATES ANALYSIS:
#    Duplicate names: 3,733
#    Duplicate IDs: 0
#
# 📝 NAME QUALITY PATTERNS:
#    Very short names (≤3 chars): 24
#    Very long names (≥100 chars): 555
#    Names with numbers: 30,185
#    Names all caps: 152
#    Names all lowercase: 401
#
# ============================================================
# 💎 PREMIUM HOTEL INDICATORS ANALYSIS
# ============================================================
# 💎 PREMIUM KEYWORDS FREQUENCY:
#    Luxury      : 272 (2.7%)
#    Private     : 153 (1.5%)
#    Boutique    : 93 (0.9%)
#    Grand       : 72 (0.7%)
#    Deluxe      : 69 (0.7%)
#    Royal       : 56 (0.6%)
#    Retreat     : 44 (0.4%)
#    Premium     : 39 (0.4%)
#    Palace      : 37 (0.4%)
#    Collection  : 27 (0.3%)
#    Signature   : 20 (0.2%)
#    Exclusive   : 13 (0.1%)
#    Estate      : 8 (0.1%)
#    Reserve     : 5 (0.1%)
#    Imperial    : 3 (0.0%)
#
# ⭐ STAR RATING PATTERNS:
#    Five Star      : 6 (0.1%)
#    Four Star      : 4 (0.0%)
#    Stars Symbol   : 9 (0.1%)
#
# ============================================================
# 🏁 PATTERN ANALYSIS COMPLETED!
# ============================================================
# 💡 Use these insights to optimize matching algorithms!

# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
import re
import phonetics
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

class ISOHotelMatcher:
    def __init__(self):
        self.reference_hotels = None
        self.api_hotels = None
        self.iso_mappings = self._create_iso_mappings()
        self.country_to_iso = self._create_reverse_iso_lookup()
        self.luxury_brands = self._create_luxury_brands()
        
    def _create_iso_mappings(self) -> Dict[str, Dict]:
        return {
            'AE': {
                'iso_code': 'AE',
                'official_name': 'United Arab Emirates',
                'variants': ['UAE', 'U.A.E', 'United Arab Emirates', 'Emiraty Arabskie', 'Zjednoczone Emiraty Arabskie']
            },
            'TH': {
                'iso_code': 'TH',
                'official_name': 'Thailand', 
                'variants': ['Thailand', 'Tajlandia', 'Siam', 'Kingdom of Thailand']
            },
            'SC': {
                'iso_code': 'SC',
                'official_name': 'Seychelles',
                'variants': ['Seychelles', 'Seszele', 'Republic of Seychelles', 'Sesel']
            },
            'TR': {
                'iso_code': 'TR',
                'official_name': 'Turkey',
                'variants': ['Turkey', 'Turcja', 'Türkiye', 'Republic of Turkey']
            },
            'ES': {
                'iso_code': 'ES', 
                'official_name': 'Spain',
                'variants': ['Spain', 'Hiszpania', 'España', 'Kingdom of Spain']
            },
            'ME': {
                'iso_code': 'ME',
                'official_name': 'Montenegro',
                'variants': ['Montenegro', 'Czarnogóra', 'Crna Gora']
            },
            'IT': {
                'iso_code': 'IT',
                'official_name': 'Italy',
                'variants': ['Italy', 'Włochy', 'Italia', 'Italian Republic']
            },
            'MY': {
                'iso_code': 'MY',
                'official_name': 'Malaysia',
                'variants': ['Malaysia', 'Malezja']
            },
            'MV': {
                'iso_code': 'MV',
                'official_name': 'Maldives',
                'variants': ['Maldives', 'Malediwy', 'Republic of Maldives']
            },
            'GR': {
                'iso_code': 'GR',
                'official_name': 'Greece',
                'variants': ['Greece', 'Grecja', 'Hellas', 'Hellenic Republic']
            },
            'MA': {
                'iso_code': 'MA',
                'official_name': 'Morocco',
                'variants': ['Morocco', 'Maroko', 'Kingdom of Morocco']
            },
            'EG': {
                'iso_code': 'EG',
                'official_name': 'Egypt',
                'variants': ['Egypt', 'Egipt', 'Arab Republic of Egypt']
            },
            'MU': {
                'iso_code': 'MU',
                'official_name': 'Mauritius',
                'variants': ['Mauritius', 'Republic of Mauritius']
            },
            'GB': {
                'iso_code': 'GB',
                'official_name': 'United Kingdom',
                'variants': ['United Kingdom', 'Wielka Brytania', 'UK', 'Great Britain']
            },
            'PT': {
                'iso_code': 'PT',
                'official_name': 'Portugal',
                'variants': ['Portugal', 'Portugalia', 'Portuguese Republic']
            },
            'CH': {
                'iso_code': 'CH',
                'official_name': 'Switzerland',
                'variants': ['Switzerland', 'Szwajcaria', 'Swiss Confederation']
            },
            'AU': {
                'iso_code': 'AU',
                'official_name': 'Australia',
                'variants': ['Australia', 'Commonwealth of Australia']
            },
            'ID': {
                'iso_code': 'ID',
                'official_name': 'Indonesia',
                'variants': ['Indonesia', 'Indonezja', 'Republic of Indonesia']
            },
            'AW': {
                'iso_code': 'AW',
                'official_name': 'Aruba',
                'variants': ['Aruba']
            },
            'GL': {
                'iso_code': 'GL',
                'official_name': 'Greenland',
                'variants': ['Greenland', 'Grenlandia']
            },
            'VN': {
                'iso_code': 'VN',
                'official_name': 'Vietnam',
                'variants': ['Vietnam', 'Wietnam', 'Socialist Republic of Vietnam']
            },
            'FR': {
                'iso_code': 'FR',
                'official_name': 'France',
                'variants': ['France', 'Francja', 'French Republic']
            },
            'US': {
                'iso_code': 'US',
                'official_name': 'United States',
                'variants': ['United States', 'USA', 'US', 'America']
            },
            'SG': {
                'iso_code': 'SG',
                'official_name': 'Singapore',
                'variants': ['Singapore', 'Singapur', 'Republic of Singapore']
            },
            'IS': {
                'iso_code': 'IS',
                'official_name': 'Iceland',
                'variants': ['Iceland', 'Islandia', 'Republic of Iceland']
            },
            'QA': {
                'iso_code': 'QA',
                'official_name': 'Qatar',
                'variants': ['Qatar', 'State of Qatar']
            },
            'ZA': {
                'iso_code': 'ZA',
                'official_name': 'South Africa',
                'variants': ['South Africa', 'RPA', 'Republic of South Africa']
            },
            'DO': {
                'iso_code': 'DO',
                'official_name': 'Dominican Republic',
                'variants': ['Dominican Republic', 'Dominikana']
            },
            'CL': {
                'iso_code': 'CL',
                'official_name': 'Chile',
                'variants': ['Chile', 'Republic of Chile', 'Explora']
            }
        }
    
    def _create_reverse_iso_lookup(self) -> Dict[str, str]:
        lookup = {}
        for iso_code, data in self.iso_mappings.items():
            for variant in data['variants']:
                lookup[variant.lower().strip()] = iso_code
        return lookup
    
    def _create_luxury_brands(self) -> List[str]:
        return [
            'four seasons', 'atlantis', 'banyan tree', 'mandarin oriental',
            'one only', 'angsana', 'shangri-la', 'ritz carlton', 'ritz-carlton',
            'st regis', 'waldorf astoria', 'hilton', 'marriott', 'hyatt',
            'intercontinental', 'sheraton', 'westin', 'doubletree', 'regent',
            'fairmont', 'raffles', 'rosewood', 'belmond', 'six senses',
            'chedi', 'dusit thani', 'movenpick', 'mövenpick'
        ]
    
    def _map_country_to_iso(self, country_str: str) -> Optional[str]:
        if not country_str:
            return None
        
        country_clean = country_str.lower().strip()
        return self.country_to_iso.get(country_clean)
    
    def _extract_brand(self, hotel_name: str) -> Optional[str]:
        if not hotel_name:
            return None
        
        name_lower = hotel_name.lower()
        for brand in self.luxury_brands:
            if brand in name_lower:
                return brand
        return None
    
    def _normalize_hotel_name(self, name: str) -> str:
        if pd.isna(name) or not name:
            return ""
        
        name = str(name).lower().strip()
        name = re.sub(r'[^\w\s]', ' ', name)
        
        # Enhanced stop words based on API analysis
        stop_words = [
            # Basic hotel types
            'hotel', 'resort', 'spa', 'suites', 'inn', 'lodge', 'motel',
            # Accommodation types (from API analysis)
            'apartment', 'apartments', 'villa', 'house', 'studio', 'bedroom',
            # Descriptors
            'luxury', 'grand', 'royal', 'palace', 'club', 'boutique', 'deluxe',
            # Location words
            'beach', 'view', 'pool', 'marina', 'bay', 'island',
            # Common words
            'in', 'by', 'with', 'and', 'the', 'at', 'of', 'for',
            # Numbers (converted to words later)
            '1', '2', '3', '4', '5', 'one', 'two', 'three', 'four', 'five'
        ]
        
        # Convert numbers to words for better matching
        number_map = {'1': 'one', '2': 'two', '3': 'three', '4': 'four', '5': 'five', '6': 'six',
                      '7': 'seven', '8': 'eight', '9': 'nine', '0': 'zero'}
        for digit, word in number_map.items():
            name = name.replace(f' {digit} ', f' {word} ')
        
        words = [word for word in name.split() if word not in stop_words and len(word) > 1]
        
        # Remove duplicates while preserving order
        seen = set()
        unique_words = []
        for word in words:
            if word not in seen:
                unique_words.append(word)
                seen.add(word)
        
        return ' '.join(unique_words)
    
    def _normalize_city_name(self, city: str) -> str:
        if not city:
            return ""
        
        city_mappings = {
            'dubaj': 'dubai',
            'krabi': 'krabi',
            'desroches': 'desroches island'
        }
        
        city_clean = city.lower().strip()
        return city_mappings.get(city_clean, city_clean)
    
    def load_reference_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📂 LOADING REFERENCE HOTELS")
        print("="*60)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Loaded file: {csv_path}")
            print(f"📊 Found {len(df)} reference hotels")
        except Exception as e:
            print(f"❌ Error loading file: {e}")
            return None
        
        print("\n🧹 Processing reference data...")
        df['clean_location'] = df['Lokalizacja'].str.strip()
        df['clean_hotel'] = df['Hotel'].str.strip()
        
        df[['country_raw', 'city_raw']] = df['clean_location'].str.split(',', n=1, expand=True)
        df['country_raw'] = df['country_raw'].fillna('').str.strip()
        df['city_raw'] = df['city_raw'].fillna('').str.strip()
        
        print("🌍 Mapping countries to ISO codes...")
        df['country_iso'] = df['country_raw'].apply(self._map_country_to_iso)
        
        unmapped_countries = df[df['country_iso'].isna()]['country_raw'].unique()
        if len(unmapped_countries) > 0:
            print(f"⚠️  Unmapped countries: {list(unmapped_countries)}")
        
        df['city'] = df['city_raw'].apply(self._normalize_city_name)
        df['normalized_name'] = df['clean_hotel'].apply(self._normalize_hotel_name)
        df['brand'] = df['clean_hotel'].apply(self._extract_brand)
        df['reference_id'] = df.index.astype(str).str.zfill(3)
        
        country_stats = df['country_iso'].value_counts()
        print(f"📈 Countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count} hotels")
        
        brands_found = df['brand'].dropna().nunique()
        print(f"🏨 Luxury brands detected: {brands_found}")
        
        self.reference_hotels = df
        print(f"✅ Processed {len(df)} reference hotels")
        return df
    
    def load_api_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📡 LOADING API HOTELS")
        print("="*60)
        
        try:
            df = pd.read_csv(csv_path)
            print(f"✅ Loaded file: {csv_path}")
            print(f"📊 Found {len(df):,} API hotels")
        except Exception as e:
            print(f"❌ Error loading file: {e}")
            return None
        
        print("\n🧹 Processing API data...")
        df['clean_name'] = df['name'].fillna('').str.strip()
        df['clean_city'] = df['city'].fillna('').str.strip()
        df['clean_address'] = df['address'].fillna('').str.strip()
        df['clean_chain'] = df['hotel_chain'].fillna('').str.strip()
        
        df['country_iso'] = df['country'].fillna('').str.upper().str.strip()
        df['normalized_name'] = df['clean_name'].apply(self._normalize_hotel_name)
        df['city_normalized'] = df['clean_city'].apply(self._normalize_city_name)
        
        df['lat'] = pd.to_numeric(df['latitude'], errors='coerce')
        df['lng'] = pd.to_numeric(df['longitude'], errors='coerce')
        
        country_stats = df['country_iso'].value_counts()
        print(f"🌍 API countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count:,} hotels")
        
        coords_valid = df[['lat', 'lng']].notna().all(axis=1).sum()
        print(f"📍 Hotels with coordinates: {coords_valid:,}/{len(df):,} ({coords_valid/len(df)*100:.1f}%)")
        
        chain_stats = df[df['clean_chain'] != '']['clean_chain'].value_counts()
        print(f"🏨 Top 3 hotel chains:")
        for chain, count in chain_stats.head(3).items():
            print(f"   {chain}: {count:,} hotels")
        
        self.api_hotels = df
        print(f"✅ Processed {len(df):,} API hotels")
        return df
    
    def _calculate_features(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return self._empty_features()
        
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'country_exact': ref_hotel['country_iso'] == api_hotel['country_iso'],
            'city_similarity': self._city_similarity(ref_hotel['city'], api_hotel['city_normalized']),
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        return features
    
    def _empty_features(self) -> Dict:
        return {
            'fuzz_ratio': 0.0, 'fuzz_partial': 0.0, 'fuzz_token_sort': 0.0,
            'fuzz_token_set': 0.0, 'country_exact': False, 'city_similarity': 0.0,
            'brand_exact': False, 'brand_similarity': 0.0, 'soundex_match': False,
            'word_intersection': 0.0, 'premium_keywords': 0.0
        }
    
    def _city_similarity(self, city1: str, city2: str) -> float:
        if not city1 or not city2:
            return 0.0
        return fuzz.ratio(city1.lower(), city2.lower()) / 100.0
    
    def _brand_exact_match(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> bool:
        ref_brand = ref_hotel.get('brand')
        api_chain = api_hotel.get('clean_chain', '').lower()
        
        if not ref_brand or not api_chain:
            return False
        
        return ref_brand.lower() in api_chain or api_chain in ref_brand.lower()
    
    def _brand_similarity(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> float:
        ref_brand = ref_hotel.get('brand', '')
        api_chain = api_hotel.get('clean_chain', '')
        
        if not ref_brand or not api_chain:
            return 0.0
        
        return fuzz.ratio(ref_brand, api_chain) / 100.0
    
    def _soundex_match(self, name1: str, name2: str) -> bool:
        if not name1 or not name2:
            return False
        
        try:
            soundex1 = phonetics.soundex(name1.replace(' ', ''))
            soundex2 = phonetics.soundex(name2.replace(' ', ''))
            return soundex1 == soundex2
        except:
            return False
    
    def _word_intersection_ratio(self, name1: str, name2: str) -> float:
        if not name1 or not name2:
            return 0.0
        
        words1 = set(name1.lower().split())
        words2 = set(name2.lower().split())
        
        if not words1 or not words2:
            return 0.0
        
        intersection = len(words1 & words2)
        union = len(words1 | words2)
        
        return intersection / union if union > 0 else 0.0
    
    def _premium_keywords_overlap(self, name1: str, name2: str) -> float:
        # Enhanced premium keywords based on API analysis
        premium_keywords = [
            'luxury', 'private', 'boutique', 'grand', 'deluxe', 'royal', 
            'retreat', 'premium', 'palace', 'collection', 'signature', 
            'exclusive', 'estate', 'reserve', 'imperial',
            # Geographic premium indicators
            'beach', 'oceanfront', 'seafront', 'waterfront', 'marina', 'bay'
        ]
        
        name1_lower = name1.lower()
        name2_lower = name2.lower()
        
        name1_keywords = sum(1 for kw in premium_keywords if kw in name1_lower)
        name2_keywords = sum(1 for kw in premium_keywords if kw in name2_lower)
        
        if name1_keywords == 0 and name2_keywords == 0:
            return 0.0
        
        common_keywords = sum(1 for kw in premium_keywords if kw in name1_lower and kw in name2_lower)
        total_keywords = max(name1_keywords, name2_keywords)
        
        return common_keywords / total_keywords if total_keywords > 0 else 0.0
    
    def _high_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['brand_exact'] and features['country_exact'] and features['city_similarity'] > 0.8:
            return {
                'match': True,
                'confidence': 0.95,
                'reason': 'Brand Perfect Match + Location Confirmed'
            }
        
        if features['fuzz_token_sort'] > 0.92 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.90,
                'reason': f'Name Almost Identical + Same Country ({features["fuzz_token_sort"]:.2f})'
            }
        
        if features['fuzz_token_set'] > 0.90 and features['country_exact'] and features['city_similarity'] > 0.7:
            return {
                'match': True,
                'confidence': 0.88,
                'reason': f'Same Words Different Order + Location ({features["fuzz_token_set"]:.2f})'
            }
        
        return None
    
    def _medium_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['brand_similarity'] > 0.8 and features['fuzz_token_sort'] > 0.75 and features['country_exact']:
            confidence = 0.70 + (features['fuzz_token_sort'] - 0.75) * 0.4
            return {
                'match': True,
                'confidence': min(confidence, 0.85),
                'reason': f'Brand Match + Strong Name Similarity ({features["fuzz_token_sort"]:.2f})'
            }
        
        if features['fuzz_partial'] > 0.85 and features['country_exact'] and (features['brand_similarity'] > 0.6 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Name Contains Match + Geographic + Indicators ({features["fuzz_partial"]:.2f})'
            }
        
        if features['fuzz_token_set'] > 0.80 and features['country_exact'] and features['city_similarity'] > 0.6:
            confidence = 0.65 + (features['fuzz_token_set'] - 0.80) * 0.5
            return {
                'match': True,
                'confidence': min(confidence, 0.82),
                'reason': f'Word Shuffle Match + Location Verified ({features["fuzz_token_set"]:.2f})'
            }
        
        return None
    
    def _lower_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['soundex_match'] and features['fuzz_partial'] > 0.75 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.60,
                'reason': f'Sounds Like + Partial Match + Geography ({features["fuzz_partial"]:.2f})'
            }
        
        if (features['word_intersection'] > 0.6 and features['premium_keywords'] > 0.4 and 
            features['country_exact'] and features['city_similarity'] > 0.5):
            return {
                'match': True,
                'confidence': 0.55,
                'reason': f'Common Words + Premium Indicators + Location ({features["word_intersection"]:.2f})'
            }
        
        return None
    
    def _make_name_only_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        """
        Name-only matching decision for fallback cases
        More permissive rules when no geography available
        """
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return None
        
        # Calculate basic features for name-only matching
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        # Name-only rules (more permissive thresholds)
        
        # Rule 1: Perfect brand match + decent name similarity
        if features['brand_exact'] and features['fuzz_token_sort'] > 0.70:
            return {
                'match': True,
                'confidence': 0.80,
                'reason': 'Brand Perfect Match + Name Similarity (Pure Name Matching)'
            }
        
        # Rule 2: Very high name similarity
        if features['fuzz_token_sort'] > 0.88:
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Names Almost Identical (Pure Name Matching) ({features["fuzz_token_sort"]:.2f})'
            }
        
        # Rule 3: High token set similarity
        if features['fuzz_token_set'] > 0.85:
            return {
                'match': True,
                'confidence': 0.70,
                'reason': f'Same Words Different Order (Pure Name Matching) ({features["fuzz_token_set"]:.2f})'
            }
        
        # Rule 4: Brand similarity + good name match
        if features['brand_similarity'] > 0.75 and features['fuzz_token_sort'] > 0.65:
            confidence = 0.60 + (features['fuzz_token_sort'] - 0.65) * 0.3
            return {
                'match': True,
                'confidence': min(confidence, 0.75),
                'reason': f'Brand Similar + Name Match (Pure Name Matching)'
            }
        
        # Rule 5: High partial ratio + premium indicators
        if features['fuzz_partial'] > 0.80 and (features['brand_similarity'] > 0.5 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.65,
                'reason': f'Name Contains Match + Premium Signals (Pure Name Matching)'
            }
        
        return None
    def _make_name_only_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        """
        Name-only matching decision for fallback cases
        More permissive rules when no geography available
        """
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return None
        
        # Calculate basic features for name-only matching
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        # Name-only rules (more permissive thresholds)
        
        # Rule 1: Perfect brand match + decent name similarity
        if features['brand_exact'] and features['fuzz_token_sort'] > 0.70:
            return {
                'match': True,
                'confidence': 0.80,
                'reason': 'Perfect brand + decent name (name-only)'
            }
        
        # Rule 2: Very high name similarity
        if features['fuzz_token_sort'] > 0.88:
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Very high token sort ({features["fuzz_token_sort"]:.2f}) (name-only)'
            }
        
        # Rule 3: High token set similarity
        if features['fuzz_token_set'] > 0.85:
            return {
                'match': True,
                'confidence': 0.70,
                'reason': f'High token set ({features["fuzz_token_set"]:.2f}) (name-only)'
            }
        
        # Rule 4: Brand similarity + good name match
        if features['brand_similarity'] > 0.75 and features['fuzz_token_sort'] > 0.65:
            confidence = 0.60 + (features['fuzz_token_sort'] - 0.65) * 0.3
            return {
                'match': True,
                'confidence': min(confidence, 0.75),
                'reason': f'Brand similarity + name match (name-only)'
            }
        
        # Rule 5: High partial ratio + premium indicators
        if features['fuzz_partial'] > 0.80 and (features['brand_similarity'] > 0.5 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.65,
                'reason': f'High partial + indicators (name-only)'
            }
        
        return None
    
    def _make_matching_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        features = self._calculate_features(ref_hotel, api_hotel)
        
        result = self._high_confidence_rules(features)
        if result:
            return result
        
        result = self._medium_confidence_rules(features)
        if result:
            return result
        
        result = self._lower_confidence_rules(features)
        if result:
            return result
        
        return None
    
    def run_matching(self) -> List[Dict]:
        print("\n" + "="*60)
        print("🎯 RUNNING HOTEL MATCHING")
        print("="*60)
        
        matches = []
        api_by_country = self.api_hotels.groupby('country_iso')
        total_hotels = len(self.reference_hotels)
        
        # Algorithm performance tracking with human-friendly names
        algorithm_stats = {
            'Brand Perfect Match + Location Confirmed': 0,
            'Name Almost Identical + Same Country': 0,
            'Same Words Different Order + Location': 0,
            'Brand Match + Strong Name Similarity': 0,
            'Name Contains Match + Geographic + Indicators': 0,
            'Word Shuffle Match + Location Verified': 0,
            'Sounds Like + Partial Match + Geography': 0,
            'Common Words + Premium Indicators + Location': 0,
            'Brand Perfect Match + Name Similarity (Pure Name Matching)': 0,
            'Names Almost Identical (Pure Name Matching)': 0,
            'Same Words Different Order (Pure Name Matching)': 0,
            'Brand Similar + Name Match (Pure Name Matching)': 0,
            'Name Contains Match + Premium Signals (Pure Name Matching)': 0
        }
        
        print(f"📊 Processing {total_hotels} reference hotels")
        print(f"🔧 ISO pre-filtering active - grouping API by country")
        print(f"🌍 API countries available: {len(api_by_country.groups)}")
        
        skipped_no_country = 0
        skipped_no_api_country = 0
        total_comparisons = 0
        
        for idx, (_, ref_hotel) in enumerate(self.reference_hotels.iterrows(), 1):
            ref_iso = ref_hotel['country_iso']
            ref_name = ref_hotel['clean_hotel']
            
            print(f"\n[{idx:2d}/{total_hotels}] Processing: {ref_name[:50]}...")
            print(f"    🌍 Country: {ref_iso}")
            
            best_match = None
            best_confidence = 0.0
            candidates_checked = 0
            
            # Strategy 1: ISO-based matching (preferred)
            if ref_iso and ref_iso in api_by_country.groups:
                candidates = api_by_country.get_group(ref_iso)
                print(f"    📍 ISO candidates: {len(candidates):,}")
                
                for _, api_hotel in candidates.iterrows():
                    candidates_checked += 1
                    total_comparisons += 1
                    
                    result = self._make_matching_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel['id'],
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'ISO-based'
                        }
                    
                    if candidates_checked % 1000 == 0:
                        print(f"    ... checked {candidates_checked:,}/{len(candidates):,} candidates")
            
            # Strategy 2: Name-only fallback (when no ISO or no ISO matches)
            if not best_match or best_confidence < 0.75:
                if not ref_iso:
                    print(f"    ⚠️  No ISO mapping - trying name-only fallback")
                elif ref_iso not in api_by_country.groups:
                    print(f"    ⚠️  No API hotels for {ref_iso} - trying name-only fallback")
                else:
                    print(f"    🔄 Low confidence ({best_confidence:.3f}) - trying name-only fallback")
                
                fallback_candidates = 0
                fallback_checked = 0
                
                # Use top 5000 hotels by similarity for performance
                name_similarities = []
                for _, api_hotel in self.api_hotels.iterrows():
                    if api_hotel['normalized_name']:
                        sim = fuzz.ratio(ref_hotel['normalized_name'], api_hotel['normalized_name']) / 100.0
                        if sim > 0.4:  # Basic threshold
                            name_similarities.append((sim, api_hotel))
                
                # Sort by similarity and take top candidates
                name_similarities.sort(key=lambda x: x[0], reverse=True)
                top_candidates = name_similarities[:5000]  # Limit for performance
                fallback_candidates = len(top_candidates)
                
                print(f"    🔍 Name-only candidates: {fallback_candidates}")
                
                for sim_score, api_hotel in top_candidates:
                    fallback_checked += 1
                    total_comparisons += 1
                    
                    # Use name-only decision logic
                    result = self._make_name_only_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel['id'],
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'Name-only fallback'
                        }
                
                if fallback_candidates == 0:
                    if not ref_iso:
                        skipped_no_country += 1
                    else:
                        skipped_no_api_country += 1
            
            # Record result
            if best_match and best_confidence >= 0.55:
                matches.append(best_match)
                
                # Track algorithm performance
                reason = best_match['match_reason']
                algorithm_found = False
                for algo_name in algorithm_stats.keys():
                    if algo_name in reason:
                        algorithm_stats[algo_name] += 1
                        algorithm_found = True
                        break
                
                if not algorithm_found:
                    # Check for partial matches in reason
                    if 'Pure Name Matching' in reason:
                        if 'Brand Perfect Match' in reason:
                            algorithm_stats['Brand Perfect Match + Name Similarity (Pure Name Matching)'] += 1
                        elif 'Names Almost Identical' in reason:
                            algorithm_stats['Names Almost Identical (Pure Name Matching)'] += 1
                        elif 'Same Words Different Order' in reason:
                            algorithm_stats['Same Words Different Order (Pure Name Matching)'] += 1
                        elif 'Brand Similar' in reason:
                            algorithm_stats['Brand Similar + Name Match (Pure Name Matching)'] += 1
                        elif 'Name Contains Match' in reason:
                            algorithm_stats['Name Contains Match + Premium Signals (Pure Name Matching)'] += 1
                
                confidence_level = "🟢 HIGH" if best_confidence >= 0.85 else "🟡 MEDIUM" if best_confidence >= 0.70 else "🔴 LOW"
                print(f"    ✅ MATCH FOUND: {best_match['api_name'][:40]}...")
                print(f"    📊 Confidence: {best_confidence:.3f} ({confidence_level})")
                print(f"    🎯 Strategy: {best_match['match_strategy']}")
                print(f"    📝 Reason: {best_match['match_reason']}")
            else:
                print(f"    ❌ No match found (best confidence: {best_confidence:.3f})")
        
        print(f"\n" + "="*60)
        print("🎯 MATCHING COMPLETED")
        print("="*60)
        print(f"✅ Total matches found: {len(matches)}")
        print(f"📊 Coverage: {len(matches)}/{total_hotels} ({len(matches)/total_hotels*100:.1f}%)")
        print(f"⚡ Performance stats:")
        print(f"   📊 Total comparisons: {total_comparisons:,}")
        print(f"   🚫 Skipped (no ISO): {skipped_no_country}")
        print(f"   🚫 Skipped (no API country): {skipped_no_api_country}")
        
        # Algorithm effectiveness breakdown
        print(f"\n🧠 ALGORITHM EFFECTIVENESS:")
        for algo_name, count in algorithm_stats.items():
            if count > 0:
                percentage = (count / len(matches)) * 100 if matches else 0
                print(f"   📈 {algo_name}: {count} matches ({percentage:.1f}%)")
        
        # Strategy breakdown
        if matches:
            iso_matches = sum(1 for m in matches if m['match_strategy'] == 'ISO-based')
            name_matches = sum(1 for m in matches if m['match_strategy'] == 'Name-only fallback')
            
            print(f"\n📊 STRATEGY BREAKDOWN:")
            print(f"   🌍 ISO-based matching: {iso_matches} ({iso_matches/len(matches)*100:.1f}%)")
            print(f"   🔍 Name-only fallback: {name_matches} ({name_matches/len(matches)*100:.1f}%)")
        
        if matches:
            confidences = [m['confidence'] for m in matches]
            high_conf = sum(1 for c in confidences if c >= 0.85)
            med_conf = sum(1 for c in confidences if 0.70 <= c < 0.85)
            low_conf = sum(1 for c in confidences if c < 0.70)
            
            print(f"\n📈 CONFIDENCE DISTRIBUTION:")
            print(f"   🟢 High (≥0.85): {high_conf}")
            print(f"   🟡 Medium (0.70-0.84): {med_conf}")
            print(f"   🔴 Low (<0.70): {low_conf}")
        
        return matches
    
    def create_full_reference_with_results(self, matches: List[Dict]) -> pd.DataFrame:
        results_df = self.reference_hotels[['Lokalizacja', 'Hotel', 'reference_id', 'country_raw', 'city', 'country_iso']].copy()
        
        # Rename columns for clarity
        results_df = results_df.rename(columns={
            'country_raw': 'reference_country',
            'city': 'reference_city'
        })
        
        match_dict = {match['reference_id']: match for match in matches}
        
        results_df['api_id'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_id', ''))
        results_df['api_name'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_name', ''))
        results_df['api_chain'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_chain', ''))
        results_df['api_city'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_city', ''))
        results_df['api_address'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_address', ''))
        results_df['api_latitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_latitude', ''))
        results_df['api_longitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_longitude', ''))
        results_df['confidence'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('confidence', ''))
        results_df['match_reason'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_reason', ''))
        results_df['match_strategy'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_strategy', ''))
        results_df['matched'] = results_df['api_id'] != ''
        
        return results_df
    
    def run_complete_matching(self, reference_csv: str, api_csv: str) -> Dict:
        print("🚀" + "="*58 + "🚀")
        print("🚀 HOTEL MAPPING ENGINE - ISO OPTIMIZED VERSION 🚀")
        print("🚀" + "="*58 + "🚀")
        print("Algorithm: ISO Pre-filtering + Rule-based Decision Tree")
        print("Features: Brand extraction + Geographic + String similarity")
        
        self.load_reference_hotels(reference_csv)
        if self.reference_hotels is None:
            return {'error': 'Failed to load reference hotels'}
            
        self.load_api_hotels(api_csv)
        if self.api_hotels is None:
            return {'error': 'Failed to load API hotels'}
        
        matches = self.run_matching()
        
        results = {
            'total_reference_hotels': len(self.reference_hotels),
            'total_api_hotels': len(self.api_hotels),
            'total_matches': len(matches),
            'coverage_percentage': len(matches) / len(self.reference_hotels) * 100,
            'matches': matches
        }
        
        return results
    
    def save_results(self, results: Dict, output_prefix: str = "hotel_mapping_iso"):
        print("\n" + "="*60)
        print("💾 SAVING RESULTS")
        print("="*60)
        
        matches = results['matches']
        
        if matches:
            matches_df = pd.DataFrame(matches)
            matches_file = f"{output_prefix}_matches.csv"
            matches_df.to_csv(matches_file, index=False)
            print(f"✅ Saved matches: {matches_file}")
        
        full_results = self.create_full_reference_with_results(matches)
        full_file = f"{output_prefix}_full_reference.csv"
        full_results.to_csv(full_file, index=False)
        print(f"✅ Saved full reference: {full_file}")
        
        summary = pd.DataFrame({
            'metric': ['Total Reference Hotels', 'Total API Hotels', 'Total Matches', 'Coverage Percentage'],
            'value': [results['total_reference_hotels'], results['total_api_hotels'], 
                     results['total_matches'], f"{results['coverage_percentage']:.1f}%"]
        })
        summary_file = f"{output_prefix}_summary.csv"
        summary.to_csv(summary_file, index=False)
        print(f"✅ Saved summary: {summary_file}")
        
        print(f"\n🎯 FINAL RESULTS:")
        print(f"   📚 Reference hotels: {results['total_reference_hotels']}")
        print(f"   📡 API hotels: {results['total_api_hotels']:,}")
        print(f"   ✅ Matches found: {results['total_matches']}")
        print(f"   📊 Coverage: {results['coverage_percentage']:.1f}%")


if __name__ == "__main__":
    matcher = ISOHotelMatcher()
    
    results = matcher.run_complete_matching(
        reference_csv="lista_referencyjna.csv",
        api_csv="01_api_rate_hawk.csv"
    )
    
    matcher.save_results(results)
    
    print("\n" + "="*60)
    print("🏁 HOTEL MAPPING COMPLETED!")
    print("="*60)
# Out:
# 🚀==========================================================🚀
# 🚀 HOTEL MAPPING ENGINE - ISO OPTIMIZED VERSION 🚀
# 🚀==========================================================🚀
# Algorithm: ISO Pre-filtering + Rule-based Decision Tree
# Features: Brand extraction + Geographic + String similarity
#
# ============================================================
# 📂 LOADING REFERENCE HOTELS
# ============================================================
# ✅ Loaded file: lista_referencyjna.csv
# 📊 Found 99 reference hotels
#
# 🧹 Processing reference data...
# 🌍 Mapping countries to ISO codes...
# ⚠️  Unmapped countries: ['The Ritz-Carlton Yacht Collection']
# 📈 Countries distribution:
#    GR (Greece): 13 hotels
#    MV (Maldives): 12 hotels
#    AE (United Arab Emirates): 11 hotels
#    ES (Spain): 8 hotels
#    TH (Thailand): 7 hotels
# 🏨 Luxury brands detected: 23
# ✅ Processed 99 reference hotels
#
# ============================================================
# 📡 LOADING API HOTELS
# ============================================================
# ✅ Loaded file: 01_api_rate_hawk.csv
# 📊 Found 95,463 API hotels
#
# 🧹 Processing API data...
# 🌍 API countries distribution:
#    AE (United Arab Emirates): 12,942 hotels
#    GR (Greece): 8,592 hotels
#    TH (Thailand): 8,063 hotels
#    US (United States): 7,858 hotels
#    ES (Spain): 6,906 hotels
# 📍 Hotels with coordinates: 95,463/95,463 (100.0%)
# 🏨 Top 3 hotel chains:
#    No chain: 91,821 hotels
#    ZenRooms: 162 hotels
#    Choice Hotels: 144 hotels
# ✅ Processed 95,463 API hotels
#
# ============================================================
# 🎯 RUNNING HOTEL MATCHING
# ============================================================
# 📊 Processing 99 reference hotels
# 🔧 ISO pre-filtering active - grouping API by country
# 🌍 API countries available: 27
#
# [ 1/99] Processing: Regnum Carya Golf & Spa Resort, Turcja...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2966
#     ❌ No match found (best confidence: 0.000)
#
# [ 2/99] Processing: SH Valencia Palace, Walencja...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Valencia...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [ 3/99] Processing: Atlantis The Royal...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis The Royal Hotel...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [ 4/99] Processing: Ikos Porto Petro, Majorka...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [ 5/99] Processing: One & Only Royal Mirage...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only Royal Mirage Hotel...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [ 6/99] Processing: Atlantis The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis, The Palm...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [ 7/99] Processing: One & Only Portovovi, Czarnogóra...
#     🌍 Country: ME
#     📍 ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3334
#     ❌ No match found (best confidence: 0.000)
#
# [ 8/99] Processing: Bahia Del Duque...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3796
#     ❌ No match found (best confidence: 0.000)
#
# [ 9/99] Processing: Lefay Resort & SPA Dolomiti...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3265
#     ✅ MATCH FOUND: Dolomiti...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [10/99] Processing: Ikos Andalusia...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [11/99] Processing: Four Seasons Langkawi...
#     🌍 Country: MY
#     📍 ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Langkawi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [12/99] Processing: Movenpick Resort Kuredhivaru Maldives...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2504
#     ✅ MATCH FOUND: Kuredhivaru Resort & Spa Maldives...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Perfect brand + decent name (name-only)
#
# [13/99] Processing: Sani Club Hotel, Chalkidiki...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2693
#     ✅ MATCH FOUND: Sani Villa...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [14/99] Processing: Marbella Club...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Royal Suites Marbella...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [15/99] Processing: The Ritz-Carlton Yacht Collection...
#     🌍 Country: None
#     ⚠️  No ISO mapping - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: The Beach House Collection...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [16/99] Processing: Waldorf Astoria Seychelles...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Waldorf Astoria Seychelles Platte Island...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Very high token sort (0.88) (name-only)
#
# [17/99] Processing: Finolhu, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1774
#     ❌ No match found (best confidence: 0.000)
#
# [18/99] Processing: Gloria Serenity Resort...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.679) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Serenity Villa...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [19/99] Processing: Dukley Hotel & Resort, Czarnogóra...
#     🌍 Country: ME
#     📍 ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1709
#     ✅ MATCH FOUND: Dukley Hotel & Resort...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [20/99] Processing: Grecotel Corfu Imperial...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Corfu Palace...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [21/99] Processing: JW Marriott Mauritius Resort...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2778
#     ✅ MATCH FOUND: JW Marriott Miami...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Perfect brand + decent name (name-only)
#
# [22/99] Processing: Four Seasons Resort Seychelles at Desroches Island...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Four Seasons Resort Seychelles at Desroc...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [23/99] Processing: The St. Regis La Bahia Blanca Resort, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Bahia Blanca...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [24/99] Processing: One & Only Aesthesis, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [25/99] Processing: Forte Village, Sardynia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: The Village Resort...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [26/99] Processing: Four Seasons Sharm El Sheikh, Egipt...
#     🌍 Country: EG
#     📍 ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Sharm EL Sheikh...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [27/99] Processing: One & Only Reethi Rah...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: One&Only Reethi Rah Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [28/99] Processing: Vakkaru...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 813
#     ✅ MATCH FOUND: Vakkaru Maldives Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [29/99] Processing: Six Senses Zil Pasyon...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Six Senses Zil Pasyon Seychelles...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)
#
# [30/99] Processing: Fairmont St Andrews, Szkocja...
#     🌍 Country: GB
#     📍 ISO candidates: 943
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4502
#     ❌ No match found (best confidence: 0.000)
#
# [31/99] Processing: The Lodge Hotel, Porto...
#     🌍 Country: PT
#     📍 ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: Porto Marina...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [32/99] Processing: Banyan Tree Krabi...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Banyan Tree Krabi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [33/99] Processing: Mandarin Oriental Jumeira Dubai...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Hotel mandarin oriental jumeira, dubai...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [34/99] Processing: Angsana Corfu Resort...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Angsana Corfu Resort & Spa...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [35/99] Processing: JOALI Being...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Joali Being...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [36/99] Processing: Patina Maldives, Fari Islands...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Patina Maldives, Fari Islands...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [37/99] Processing: Four Seasons Marakesh, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: The Seasons Resort...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [38/99] Processing: Dusit Thani, Pattaya...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dusit Thani Pattaya...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [39/99] Processing: Chedi Andermatt, Szwajcaria...
#     🌍 Country: CH
#     📍 ISO candidates: 392
#     ✅ MATCH FOUND: The Chedi Andermatt...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [40/99] Processing: Shangri-La Sydney...
#     🌍 Country: AU
#     📍 ISO candidates: 3,669
#     ... checked 1,000/3,669 candidates
#     ... checked 2,000/3,669 candidates
#     ... checked 3,000/3,669 candidates
#     ✅ MATCH FOUND: Shangri-La Sydney...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [41/99] Processing: The Stanley, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: The Stanley...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [42/99] Processing: Daios Cove, Kreta...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Villa Kreta...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [43/99] Processing: Romanos, Costa Navarino...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [44/99] Processing: Four Seasons Jimbaran Bay, Bali...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Bali at Jimbaran Bay...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [45/99] Processing: Hilton Aruba Caribbean Resort & Casino, Aruba...
#     🌍 Country: AW
#     📍 ISO candidates: 1,255
#     ... checked 1,000/1,255 candidates
#     ✅ MATCH FOUND: Hilton Aruba Caribbean Resort and Casino...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [46/99] Processing: Mandarin Oriental, Costa Navarino...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Costa Navarino...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [47/99] Processing: Quark Expeditions...
#     🌍 Country: GL
#     ⚠️  No API hotels for GL - trying name-only fallback
#     🔍 Name-only candidates: 2214
#     ❌ No match found (best confidence: 0.000)
#
# [48/99] Processing: JOALI Maldives...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: JOALI Maldives Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [49/99] Processing: Belmond Reid's Palace, Portugalia...
#     🌍 Country: PT
#     📍 ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: GA Palace Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)
#
# [50/99] Processing: Velaa Private Island...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Velaa Private Island...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [51/99] Processing: The Abi d'Oru Hotel & Spa, Sardynia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [52/99] Processing: Burj Al Arab...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Luxury apartment Burj al Arab View...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [53/99] Processing: One & Only The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only The Palm, Dubai Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [54/99] Processing: Rosewood Phuket...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phuket Island View Resort...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [55/99] Processing: Wyndham Grand Athens, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: O&B Athens Boutique Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [56/99] Processing: Ikos Oceania, Chalkidiki...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2804
#     ✅ MATCH FOUND: Villa Oceania...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [57/99] Processing: Saii Phi Phi Island Village Resort, Tajlandia...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phi Phi The Beach Resort Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Word Shuffle Match + Location Verified (1.00)
#
# [58/99] Processing: Raffles Prasiln...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Raffles Dubai Hotel...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Perfect brand + decent name (name-only)
#
# [59/99] Processing: Waldorf Astoria Maldives Ithaafushi...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Maldives Ithaafushi Hote...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [60/99] Processing: Regent Phu Quoc Hotel, Wietnam...
#     🌍 Country: VN
#     📍 ISO candidates: 1,058
#     ... checked 1,000/1,058 candidates
#     ✅ MATCH FOUND: The Beach Club Resort Phu Quoc...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [61/99] Processing: The Ritz-Carlton, Jumeirah...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: The Ritz-Carlton, Dubai Hotel...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [62/99] Processing: METT Marbella Hotel, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Marbella House...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [63/99] Processing: Niyama Private Island...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Niyama Private Islands Maldives...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)
#
# [64/99] Processing: Hotel Du Palais Biarritz - The Unbound Collection ...
#     🌍 Country: FR
#     📍 ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     ✅ MATCH FOUND: Hôtel du Palais...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [65/99] Processing: Four Seasons Resort Orlando at Walt Disney World R...
#     🌍 Country: US
#     📍 ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: Orlando Motel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [66/99] Processing: Mandarin Oriental, Singapur...
#     🌍 Country: SG
#     📍 ISO candidates: 1,085
#     ... checked 1,000/1,085 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Singapore...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (0.94)
#
# [67/99] Processing: The Datai, Malezja...
#     🌍 Country: MY
#     📍 ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [68/99] Processing: The Betsy Hotel, Miami...
#     🌍 Country: US
#     📍 ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: W Miami...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [69/99] Processing: Ikos Dassia, Korfu...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2309
#     ❌ No match found (best confidence: 0.000)
#
# [70/99] Processing: Puente Romano, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Villa Romano...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [71/99] Processing: Domes Zeen, a Luxury Collection Resort, Kreta...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: The Beach House Collection...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [72/99] Processing: Emerald Resort, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4164
#     ✅ MATCH FOUND: Emerald Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [73/99] Processing: Badrutt's Palace, Szwajcaria...
#     🌍 Country: CH
#     📍 ISO candidates: 392
#     ✅ MATCH FOUND: Badrutt's Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [74/99] Processing: Four Seasons Resort at Jumeirah Beach...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Four Seasons Dubai at Jumeirah Beach Res...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [75/99] Processing: DoubleTree by Hilton Resort & Spa Marjan Island, U...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Rixos Al Mairid Ras Al Khaimah...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [76/99] Processing: Alpin & Vital Hotel La Perla, Ortisei, Włochy...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [77/99] Processing: The Retreat at Blue Lagoon Iceland...
#     🌍 Country: IS
#     📍 ISO candidates: 15
#     ✅ MATCH FOUND: The Retreat at Blue Lagoon Iceland...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [78/99] Processing: Jaal Riad Resort, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [79/99] Processing: The Raffles Doha...
#     🌍 Country: QA
#     📍 ISO candidates: 498
#     ✅ MATCH FOUND: Raffles Doha...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [80/99] Processing: Jumeirah at Saadiyat Island Resort, UAE...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     🔄 Low confidence (0.697) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Jumeirah Saadiyat Island Abu Dhabi...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (0.89) (name-only)
#
# [81/99] Processing: The Chedi El Gouna, Egipt...
#     🌍 Country: EG
#     📍 ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4424
#     ✅ MATCH FOUND: El Gouna Apartment...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [82/99] Processing: El Fuerte Marbella, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Marbella House...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [83/99] Processing: Fancourt Hotel...
#     🌍 Country: ZA
#     📍 ISO candidates: 601
#     ✅ MATCH FOUND: Fancourt...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [84/99] Processing: Waldorf Astoria The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Al Habtoor Palace Hotel...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [85/99] Processing: The Laguna, A Luxury Collection Resort & Spa...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: The Laguna, a Luxury Collection Resort &...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)
#
# [86/99] Processing: Six Senses Yao Noi...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Six Senses Yao Noi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [87/99] Processing: Le Fitz Roy, Val Thorens...
#     🌍 Country: FR
#     📍 ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Le Val Thorens...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [88/99] Processing: Sugar Beach Mauritius...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: Sugar Beach Mauritius...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)
#
# [89/99] Processing: Lefay Resort Lago Di Garda, Włochy...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2354
#     ❌ No match found (best confidence: 0.000)
#
# [90/99] Processing: Elivi Skiathos...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3982
#     ❌ No match found (best confidence: 0.000)
#
# [91/99] Processing: One & Only Le Saint Geran...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: One&Only Le Saint Géran...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (0.95)
#
# [92/99] Processing: The St Regis Bali Resort Nusa Dua...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Bali Nusa Dua Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: High token set (1.00) (name-only)
#
# [93/99] Processing: Explora II...
#     🌍 Country: CL
#     ⚠️  No API hotels for CL - trying name-only fallback
#     🔍 Name-only candidates: 2560
#     ❌ No match found (best confidence: 0.000)
#
# [94/99] Processing: Lily Beach Resort & Spa, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Lily Beach Resort & Spa...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)
#
# [95/99] Processing: Tortuga Bay Puntacana Resort & Club, Dominikana...
#     🌍 Country: DO
#     📍 ISO candidates: 5,826
#     ... checked 1,000/5,826 candidates
#     ... checked 2,000/5,826 candidates
#     ... checked 3,000/5,826 candidates
#     ... checked 4,000/5,826 candidates
#     ... checked 5,000/5,826 candidates
#     ✅ MATCH FOUND: Tortuga Bay Hotel at Puntacana Resort & ...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)
#
# [96/99] Processing: Ritz Carlton Phulay Bay...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phulay Bay, a Ritz-Carlton Reserve...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# [97/99] Processing: Intercontinental Phuket Resort, Tajlandia...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dinso Resort & Villas Phuket, Vignette C...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed
#
# [98/99] Processing: Verdura Golf & Spa Resort, Sycylia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2060
#     ❌ No match found (best confidence: 0.000)
#
# [99/99] Processing: Maxx Royal Belek Golf Resort, Belek...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     ✅ MATCH FOUND: Belek Golf Apartments...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)
#
# ============================================================
# 🎯 MATCHING COMPLETED
# ============================================================
# ✅ Total matches found: 80
# 📊 Coverage: 80/99 (80.8%)
# ⚡ Performance stats:
#    📊 Total comparisons: 675,037
#    🚫 Skipped (no ISO): 0
#    🚫 Skipped (no API country): 0
#
# 🧠 ALGORITHM EFFECTIVENESS:
#    📈 Brand Perfect Match + Location Confirmed: 13 matches (16.2%)
#    📈 Name Almost Identical + Same Country: 23 matches (28.7%)
#    📈 Same Words Different Order + Location: 16 matches (20.0%)
#    📈 Name Contains Match + Geographic + Indicators: 6 matches (7.5%)
#    📈 Word Shuffle Match + Location Verified: 1 matches (1.2%)
#
# 📊 STRATEGY BREAKDOWN:
#    🌍 ISO-based matching: 59 (73.8%)
#    🔍 Name-only fallback: 21 (26.2%)
#
# 📈 CONFIDENCE DISTRIBUTION:
#    🟢 High (≥0.85): 52
#    🟡 Medium (0.70-0.84): 28
#    🔴 Low (<0.70): 0
#
# ============================================================
# 💾 SAVING RESULTS
# ============================================================
# ✅ Saved matches: hotel_mapping_iso_matches.csv
# ✅ Saved full reference: hotel_mapping_iso_full_reference.csv
# ✅ Saved summary: hotel_mapping_iso_summary.csv
#
# 🎯 FINAL RESULTS:
#    📚 Reference hotels: 99
#    📡 API hotels: 95,463
#    ✅ Matches found: 80
#    📊 Coverage: 80.8%
#
# ============================================================
# 🏁 HOTEL MAPPING COMPLETED!
# ============================================================

# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
import re
import phonetics
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

class EnhancedHotelMatcher:
    def __init__(self):
        self.reference_hotels = None
        self.api_hotels = None
        self.iso_mappings = self._create_iso_mappings()
        self.country_to_iso = self._create_reverse_iso_lookup()
        self.luxury_brands = self._create_luxury_brands()
        self.api_id_brands = self._create_api_id_brands()
        
    def _create_iso_mappings(self) -> Dict[str, Dict]:
        return {
            'AE': {
                'iso_code': 'AE',
                'official_name': 'United Arab Emirates',
                'variants': ['UAE', 'U.A.E', 'United Arab Emirates', 'Emiraty Arabskie', 'Zjednoczone Emiraty Arabskie']
            },
            'TH': {
                'iso_code': 'TH',
                'official_name': 'Thailand', 
                'variants': ['Thailand', 'Tajlandia', 'Siam', 'Kingdom of Thailand']
            },
            'SC': {
                'iso_code': 'SC',
                'official_name': 'Seychelles',
                'variants': ['Seychelles', 'Seszele', 'Republic of Seychelles', 'Sesel']
            },
            'TR': {
                'iso_code': 'TR',
                'official_name': 'Turkey',
                'variants': ['Turkey', 'Turcja', 'Türkiye', 'Republic of Turkey']
            },
            'ES': {
                'iso_code': 'ES', 
                'official_name': 'Spain',
                'variants': ['Spain', 'Hiszpania', 'España', 'Kingdom of Spain']
            },
            'ME': {
                'iso_code': 'ME',
                'official_name': 'Montenegro',
                'variants': ['Montenegro', 'Czarnogóra', 'Crna Gora']
            },
            'IT': {
                'iso_code': 'IT',
                'official_name': 'Italy',
                'variants': ['Italy', 'Włochy', 'Italia', 'Italian Republic']
            },
            'MY': {
                'iso_code': 'MY',
                'official_name': 'Malaysia',
                'variants': ['Malaysia', 'Malezja']
            },
            'MV': {
                'iso_code': 'MV',
                'official_name': 'Maldives',
                'variants': ['Maldives', 'Malediwy', 'Republic of Maldives']
            },
            'GR': {
                'iso_code': 'GR',
                'official_name': 'Greece',
                'variants': ['Greece', 'Grecja', 'Hellas', 'Hellenic Republic']
            },
            'MA': {
                'iso_code': 'MA',
                'official_name': 'Morocco',
                'variants': ['Morocco', 'Maroko', 'Kingdom of Morocco']
            },
            'EG': {
                'iso_code': 'EG',
                'official_name': 'Egypt',
                'variants': ['Egypt', 'Egipt', 'Arab Republic of Egypt']
            },
            'MU': {
                'iso_code': 'MU',
                'official_name': 'Mauritius',
                'variants': ['Mauritius', 'Republic of Mauritius']
            },
            'GB': {
                'iso_code': 'GB',
                'official_name': 'United Kingdom',
                'variants': ['United Kingdom', 'Wielka Brytania', 'UK', 'Great Britain']
            },
            'PT': {
                'iso_code': 'PT',
                'official_name': 'Portugal',
                'variants': ['Portugal', 'Portugalia', 'Portuguese Republic']
            },
            'CH': {
                'iso_code': 'CH',
                'official_name': 'Switzerland',
                'variants': ['Switzerland', 'Szwajcaria', 'Swiss Confederation']
            },
            'AU': {
                'iso_code': 'AU',
                'official_name': 'Australia',
                'variants': ['Australia', 'Commonwealth of Australia']
            },
            'ID': {
                'iso_code': 'ID',
                'official_name': 'Indonesia',
                'variants': ['Indonesia', 'Indonezja', 'Republic of Indonesia']
            },
            'AW': {
                'iso_code': 'AW',
                'official_name': 'Aruba',
                'variants': ['Aruba']
            },
            'GL': {
                'iso_code': 'GL',
                'official_name': 'Greenland',
                'variants': ['Greenland', 'Grenlandia']
            },
            'VN': {
                'iso_code': 'VN',
                'official_name': 'Vietnam',
                'variants': ['Vietnam', 'Wietnam', 'Socialist Republic of Vietnam']
            },
            'FR': {
                'iso_code': 'FR',
                'official_name': 'France',
                'variants': ['France', 'Francja', 'French Republic']
            },
            'US': {
                'iso_code': 'US',
                'official_name': 'United States',
                'variants': ['United States', 'USA', 'US', 'America']
            },
            'SG': {
                'iso_code': 'SG',
                'official_name': 'Singapore',
                'variants': ['Singapore', 'Singapur', 'Republic of Singapore']
            },
            'IS': {
                'iso_code': 'IS',
                'official_name': 'Iceland',
                'variants': ['Iceland', 'Islandia', 'Republic of Iceland']
            },
            'QA': {
                'iso_code': 'QA',
                'official_name': 'Qatar',
                'variants': ['Qatar', 'State of Qatar']
            },
            'ZA': {
                'iso_code': 'ZA',
                'official_name': 'South Africa',
                'variants': ['South Africa', 'RPA', 'Republic of South Africa']
            },
            'DO': {
                'iso_code': 'DO',
                'official_name': 'Dominican Republic',
                'variants': ['Dominican Republic', 'Dominikana']
            },
            'CL': {
                'iso_code': 'CL',
                'official_name': 'Chile',
                'variants': ['Chile', 'Republic of Chile', 'Explora']
            }
        }
    
    def _create_reverse_iso_lookup(self) -> Dict[str, str]:
        lookup = {}
        for iso_code, data in self.iso_mappings.items():
            for variant in data['variants']:
                lookup[variant.lower().strip()] = iso_code
        return lookup
    
    def _create_luxury_brands(self) -> List[str]:
        return [
            'four seasons', 'atlantis', 'banyan tree', 'mandarin oriental',
            'one only', 'angsana', 'shangri-la', 'ritz carlton', 'ritz-carlton',
            'st regis', 'waldorf astoria', 'hilton', 'marriott', 'hyatt',
            'intercontinental', 'sheraton', 'westin', 'doubletree', 'regent',
            'fairmont', 'raffles', 'rosewood', 'belmond', 'six senses',
            'chedi', 'dusit thani', 'movenpick', 'mövenpick'
        ]
    
    def _create_api_id_brands(self) -> Dict[str, str]:
        """Brand patterns found in API IDs"""
        return {
            'four_seasons': 'Four Seasons',
            'oneonly': 'One & Only',
            'one_only': 'One & Only',
            'mandarin_oriental': 'Mandarin Oriental',
            'waldorf_astoria': 'Waldorf Astoria',
            'ritz_carlton': 'Ritz Carlton',
            'six_senses': 'Six Senses',
            'banyan_tree': 'Banyan Tree',
            'shangri': 'Shangri-La',
            'atlantis': 'Atlantis',
            'raffles': 'Raffles',
            'joali': 'JOALI',
            'angsana': 'Angsana',
            'hilton': 'Hilton',
            'marriott': 'Marriott',
            'hyatt': 'Hyatt'
        }
    
    def _map_country_to_iso(self, country_str: str) -> Optional[str]:
        if not country_str:
            return None
        country_clean = country_str.lower().strip()
        return self.country_to_iso.get(country_clean)
    
    def _extract_brand(self, hotel_name: str) -> Optional[str]:
        if not hotel_name:
            return None
        name_lower = hotel_name.lower()
        for brand in self.luxury_brands:
            if brand in name_lower:
                return brand
        return None
    
    def _extract_brand_from_api_id(self, api_id: str) -> Optional[str]:
        """Extract brand from API ID - more reliable than name parsing"""
        if not api_id:
            return None
        api_lower = api_id.lower()
        for pattern, brand in self.api_id_brands.items():
            if pattern in api_lower:
                return brand
        return None
    
    def _normalize_hotel_name(self, name: str) -> str:
        if pd.isna(name) or not name:
            return ""
        
        name = str(name).lower().strip()
        name = re.sub(r'[^\w\s]', ' ', name)
        
        # Enhanced stop words based on API analysis
        stop_words = [
            'hotel', 'resort', 'spa', 'suites', 'inn', 'lodge', 'motel',
            'apartment', 'apartments', 'villa', 'house', 'studio', 'bedroom',
            'luxury', 'grand', 'royal', 'palace', 'club', 'boutique', 'deluxe',
            'beach', 'view', 'pool', 'marina', 'bay', 'island',
            'in', 'by', 'with', 'and', 'the', 'at', 'of', 'for',
            '1', '2', '3', '4', '5', 'one', 'two', 'three', 'four', 'five'
        ]
        
        # Convert numbers to words for better matching
        number_map = {'1': 'one', '2': 'two', '3': 'three', '4': 'four', '5': 'five'}
        for digit, word in number_map.items():
            name = name.replace(f' {digit} ', f' {word} ')
        
        words = [word for word in name.split() if word not in stop_words and len(word) > 1]
        
        seen = set()
        unique_words = []
        for word in words:
            if word not in seen:
                unique_words.append(word)
                seen.add(word)
        
        return ' '.join(unique_words)
    
    def _normalize_city_name(self, city: str) -> str:
        if not city:
            return ""
        city_mappings = {
            'dubaj': 'dubai',
            'krabi': 'krabi',
            'desroches': 'desroches island'
        }
        city_clean = city.lower().strip()
        return city_mappings.get(city_clean, city_clean)
    
    def load_reference_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📂 LOADING REFERENCE HOTELS")
        print("="*60)
        
        df = pd.read_csv(csv_path)
        print(f"✅ Loaded file: {csv_path}")
        print(f"📊 Found {len(df)} reference hotels")
        
        print("\n🧹 Processing reference data...")
        df['clean_location'] = df['Lokalizacja'].str.strip()
        df['clean_hotel'] = df['Hotel'].str.strip()
        
        df[['country_raw', 'city_raw']] = df['clean_location'].str.split(',', n=1, expand=True)
        df['country_raw'] = df['country_raw'].fillna('').str.strip()
        df['city_raw'] = df['city_raw'].fillna('').str.strip()
        
        print("🌍 Mapping countries to ISO codes...")
        df['country_iso'] = df['country_raw'].apply(self._map_country_to_iso)
        
        unmapped_countries = df[df['country_iso'].isna()]['country_raw'].unique()
        if len(unmapped_countries) > 0:
            print(f"⚠️  Unmapped countries: {list(unmapped_countries)}")
        
        df['city'] = df['city_raw'].apply(self._normalize_city_name)
        df['normalized_name'] = df['clean_hotel'].apply(self._normalize_hotel_name)
        df['brand'] = df['clean_hotel'].apply(self._extract_brand)
        df['reference_id'] = df.index.astype(str).str.zfill(3)
        
        country_stats = df['country_iso'].value_counts()
        print(f"📈 Countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count} hotels")
        
        brands_found = df['brand'].dropna().nunique()
        print(f"🏨 Luxury brands detected: {brands_found}")
        
        self.reference_hotels = df
        print(f"✅ Processed {len(df)} reference hotels")
        return df
    
    def load_api_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📡 LOADING API HOTELS")
        print("="*60)
        
        df = pd.read_csv(csv_path)
        print(f"✅ Loaded file: {csv_path}")
        print(f"📊 Found {len(df):,} API hotels")
        
        print("\n🧹 Processing API data...")
        df['clean_name'] = df['name'].fillna('').str.strip()
        df['clean_city'] = df['city'].fillna('').str.strip()
        df['clean_address'] = df['address'].fillna('').str.strip()
        df['clean_chain'] = df['hotel_chain'].fillna('').str.strip()
        
        df['country_iso'] = df['country'].fillna('').str.upper().str.strip()
        df['normalized_name'] = df['clean_name'].apply(self._normalize_hotel_name)
        df['city_normalized'] = df['clean_city'].apply(self._normalize_city_name)
        
        df['lat'] = pd.to_numeric(df['latitude'], errors='coerce')
        df['lng'] = pd.to_numeric(df['longitude'], errors='coerce')
        
        country_stats = df['country_iso'].value_counts()
        print(f"🌍 API countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count:,} hotels")
        
        coords_valid = df[['lat', 'lng']].notna().all(axis=1).sum()
        print(f"📍 Hotels with coordinates: {coords_valid:,}/{len(df):,} ({coords_valid/len(df)*100:.1f}%)")
        
        chain_stats = df[df['clean_chain'] != '']['clean_chain'].value_counts()
        print(f"🏨 Top 3 hotel chains:")
        for chain, count in chain_stats.head(3).items():
            print(f"   {chain}: {count:,} hotels")
        
        self.api_hotels = df
        print(f"✅ Processed {len(df):,} API hotels")
        return df
    
    def _calculate_features(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return self._empty_features()
        
        features = {
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            'country_exact': ref_hotel['country_iso'] == api_hotel['country_iso'],
            'city_similarity': self._city_similarity(ref_hotel['city'], api_hotel['city_normalized']),
            'brand_exact': self._brand_exact_match(ref_hotel, api_hotel),
            'brand_similarity': self._brand_similarity(ref_hotel, api_hotel),
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        # API ID enhancement
        api_brand = self._extract_brand_from_api_id(api_hotel.get('id', ''))
        ref_brand = ref_hotel.get('brand')
        features['api_id_brand_match'] = api_brand and ref_brand and self._brands_match(ref_brand, api_brand)
        
        return features
    
    def _empty_features(self) -> Dict:
        return {
            'fuzz_ratio': 0.0, 'fuzz_partial': 0.0, 'fuzz_token_sort': 0.0,
            'fuzz_token_set': 0.0, 'country_exact': False, 'city_similarity': 0.0,
            'brand_exact': False, 'brand_similarity': 0.0, 'soundex_match': False,
            'word_intersection': 0.0, 'premium_keywords': 0.0, 'api_id_brand_match': False
        }
    
    def _city_similarity(self, city1: str, city2: str) -> float:
        if not city1 or not city2:
            return 0.0
        return fuzz.ratio(city1.lower(), city2.lower()) / 100.0
    
    def _brand_exact_match(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> bool:
        ref_brand = ref_hotel.get('brand')
        api_chain = api_hotel.get('clean_chain', '').lower()
        
        if not ref_brand or not api_chain:
            return False
        
        return ref_brand.lower() in api_chain or api_chain in ref_brand.lower()
    
    def _brand_similarity(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> float:
        ref_brand = ref_hotel.get('brand', '')
        api_chain = api_hotel.get('clean_chain', '')
        
        if not ref_brand or not api_chain:
            return 0.0
        
        return fuzz.ratio(ref_brand, api_chain) / 100.0
    
    def _brands_match(self, ref_brand: str, api_brand: str) -> bool:
        """Conservative brand matching for API ID"""
        if not ref_brand or not api_brand:
            return False
        similarity = fuzz.ratio(ref_brand.lower(), api_brand.lower()) / 100.0
        return similarity > 0.85
    
    def _soundex_match(self, name1: str, name2: str) -> bool:
        if not name1 or not name2:
            return False
        try:
            soundex1 = phonetics.soundex(name1.replace(' ', ''))
            soundex2 = phonetics.soundex(name2.replace(' ', ''))
            return soundex1 == soundex2
        except:
            return False
    
    def _word_intersection_ratio(self, name1: str, name2: str) -> float:
        if not name1 or not name2:
            return 0.0
        
        words1 = set(name1.lower().split())
        words2 = set(name2.lower().split())
        
        if not words1 or not words2:
            return 0.0
        
        intersection = len(words1 & words2)
        union = len(words1 | words2)
        
        return intersection / union if union > 0 else 0.0
    
    def _premium_keywords_overlap(self, name1: str, name2: str) -> float:
        premium_keywords = [
            'luxury', 'private', 'boutique', 'grand', 'deluxe', 'royal', 
            'retreat', 'premium', 'palace', 'collection', 'signature', 
            'exclusive', 'estate', 'reserve', 'imperial',
            'beach', 'oceanfront', 'seafront', 'waterfront', 'marina', 'bay'
        ]
        
        name1_lower = name1.lower()
        name2_lower = name2.lower()
        
        name1_keywords = sum(1 for kw in premium_keywords if kw in name1_lower)
        name2_keywords = sum(1 for kw in premium_keywords if kw in name2_lower)
        
        if name1_keywords == 0 and name2_keywords == 0:
            return 0.0
        
        common_keywords = sum(1 for kw in premium_keywords if kw in name1_lower and kw in name2_lower)
        total_keywords = max(name1_keywords, name2_keywords)
        
        return common_keywords / total_keywords if total_keywords > 0 else 0.0
    
    def _high_confidence_rules(self, features: Dict) -> Optional[Dict]:
        # API ID Brand Match gets highest priority
        if features['api_id_brand_match'] and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.97,
                'reason': 'API ID Brand Perfect Match + Same Country'
            }
        
        if features['brand_exact'] and features['country_exact'] and features['city_similarity'] > 0.8:
            return {
                'match': True,
                'confidence': 0.95,
                'reason': 'Brand Perfect Match + Location Confirmed'
            }
        
        if features['fuzz_token_sort'] > 0.92 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.90,
                'reason': f'Name Almost Identical + Same Country ({features["fuzz_token_sort"]:.2f})'
            }
        
        if features['fuzz_token_set'] > 0.90 and features['country_exact'] and features['city_similarity'] > 0.7:
            return {
                'match': True,
                'confidence': 0.88,
                'reason': f'Same Words Different Order + Location ({features["fuzz_token_set"]:.2f})'
            }
        
        return None
    
    def _medium_confidence_rules(self, features: Dict) -> Optional[Dict]:
        # API ID Brand Match with lower name similarity
        if features['api_id_brand_match'] and features['country_exact'] and features['fuzz_token_sort'] > 0.60:
            confidence = 0.80 + features['fuzz_token_sort'] * 0.1
            return {
                'match': True,
                'confidence': min(confidence, 0.95),
                'reason': f'API ID Brand Match + Name Similarity ({features["fuzz_token_sort"]:.2f})'
            }
        
        if features['brand_similarity'] > 0.8 and features['fuzz_token_sort'] > 0.75 and features['country_exact']:
            confidence = 0.70 + (features['fuzz_token_sort'] - 0.75) * 0.4
            return {
                'match': True,
                'confidence': min(confidence, 0.85),
                'reason': f'Brand Match + Strong Name Similarity ({features["fuzz_token_sort"]:.2f})'
            }
        
        if features['fuzz_partial'] > 0.85 and features['country_exact'] and (features['brand_similarity'] > 0.6 or features['premium_keywords'] > 0.3):
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Name Contains Match + Geographic + Indicators ({features["fuzz_partial"]:.2f})'
            }
        
        if features['fuzz_token_set'] > 0.80 and features['country_exact'] and features['city_similarity'] > 0.6:
            confidence = 0.65 + (features['fuzz_token_set'] - 0.80) * 0.5
            return {
                'match': True,
                'confidence': min(confidence, 0.82),
                'reason': f'Word Shuffle Match + Location Verified ({features["fuzz_token_set"]:.2f})'
            }
        
        return None
    
    def _lower_confidence_rules(self, features: Dict) -> Optional[Dict]:
        if features['soundex_match'] and features['fuzz_partial'] > 0.75 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.60,
                'reason': f'Sounds Like + Partial Match + Geography ({features["fuzz_partial"]:.2f})'
            }
        
        if (features['word_intersection'] > 0.6 and features['premium_keywords'] > 0.4 and 
            features['country_exact'] and features['city_similarity'] > 0.5):
            return {
                'match': True,
                'confidence': 0.55,
                'reason': f'Common Words + Premium Indicators + Location ({features["word_intersection"]:.2f})'
            }
        
        return None
    
    def _make_matching_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        features = self._calculate_features(ref_hotel, api_hotel)
        
        result = self._high_confidence_rules(features)
        if result:
            return result
        
        result = self._medium_confidence_rules(features)
        if result:
            return result
        
        result = self._lower_confidence_rules(features)
        if result:
            return result
        
        return None
    
    def _make_name_only_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return None
        
        # Check for API ID brand match first
        api_brand = self._extract_brand_from_api_id(api_hotel.get('id', ''))
        ref_brand = ref_hotel.get('brand')
        api_id_brand_match = api_brand and ref_brand and self._brands_match(ref_brand, api_brand)
        
        if api_id_brand_match:
            name_sim = fuzz.token_sort_ratio(ref_name, api_name) / 100.0
            confidence = 0.75 + name_sim * 0.15
            return {
                'match': True,
                'confidence': min(confidence, 0.90),
                'reason': f'API ID Brand Match + Name Similarity (Pure Name Matching) ({name_sim:.2f})'
            }
        
        # Regular name-only matching
        fuzz_token_sort = fuzz.token_sort_ratio(ref_name, api_name) / 100.0
        fuzz_token_set = fuzz.token_set_ratio(ref_name, api_name) / 100.0
        
        if fuzz_token_sort > 0.88:
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Names Almost Identical (Pure Name Matching) ({fuzz_token_sort:.2f})'
            }
        
        if fuzz_token_set > 0.85:
            return {
                'match': True,
                'confidence': 0.70,
                'reason': f'Same Words Different Order (Pure Name Matching) ({fuzz_token_set:.2f})'
            }
        
        return None
    
    def run_matching(self) -> List[Dict]:
        print("\n" + "="*60)
        print("🎯 RUNNING ENHANCED HOTEL MATCHING")
        print("="*60)
        
        matches = []
        api_by_country = self.api_hotels.groupby('country_iso')
        total_hotels = len(self.reference_hotels)
        
        algorithm_stats = {
            'API ID Brand Perfect Match + Same Country': 0,
            'Brand Perfect Match + Location Confirmed': 0,
            'Name Almost Identical + Same Country': 0,
            'Same Words Different Order + Location': 0,
            'API ID Brand Match + Name Similarity': 0,
            'Brand Match + Strong Name Similarity': 0,
            'Name Contains Match + Geographic + Indicators': 0,
            'Word Shuffle Match + Location Verified': 0,
            'Sounds Like + Partial Match + Geography': 0,
            'Common Words + Premium Indicators + Location': 0,
            'API ID Brand Match + Name Similarity (Pure Name Matching)': 0,
            'Names Almost Identical (Pure Name Matching)': 0,
            'Same Words Different Order (Pure Name Matching)': 0
        }
        
        print(f"📊 Processing {total_hotels} reference hotels")
        print(f"🔧 ISO pre-filtering + API ID intelligence active")
        print(f"🌍 API countries available: {len(api_by_country.groups)}")
        
        total_comparisons = 0
        skipped_no_country = 0
        skipped_no_api_country = 0
        api_id_rescues = 0
        
        for idx, (_, ref_hotel) in enumerate(self.reference_hotels.iterrows(), 1):
            ref_iso = ref_hotel['country_iso']
            ref_name = ref_hotel['clean_hotel']
            
            print(f"\n[{idx:2d}/{total_hotels}] Processing: {ref_name[:50]}...")
            print(f"    🌍 Country: {ref_iso}")
            
            best_match = None
            best_confidence = 0.0
            
            # Strategy 1: ISO-based matching
            if ref_iso and ref_iso in api_by_country.groups:
                candidates = api_by_country.get_group(ref_iso)
                print(f"    📍 ISO candidates: {len(candidates):,}")
                
                candidates_checked = 0
                for _, api_hotel in candidates.iterrows():
                    candidates_checked += 1
                    total_comparisons += 1
                    
                    result = self._make_matching_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel['id'],
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'ISO-based'
                        }
                    
                    if candidates_checked % 1000 == 0:
                        print(f"    ... checked {candidates_checked:,}/{len(candidates):,} candidates")
            
            # Strategy 2: Name-only fallback
            if not best_match or best_confidence < 0.75:
                if not ref_iso:
                    print(f"    ⚠️  No ISO mapping - trying name-only fallback")
                elif ref_iso not in api_by_country.groups:
                    print(f"    ⚠️  No API hotels for {ref_iso} - trying name-only fallback")
                else:
                    print(f"    🔄 Low confidence ({best_confidence:.3f}) - trying name-only fallback")
                
                # Use top 5000 hotels by similarity
                name_similarities = []
                for _, api_hotel in self.api_hotels.iterrows():
                    if api_hotel['normalized_name']:
                        sim = fuzz.ratio(ref_hotel['normalized_name'], api_hotel['normalized_name']) / 100.0
                        if sim > 0.4:
                            name_similarities.append((sim, api_hotel))
                
                name_similarities.sort(key=lambda x: x[0], reverse=True)
                top_candidates = name_similarities[:5000]
                
                print(f"    🔍 Name-only candidates: {len(top_candidates)}")
                
                for sim_score, api_hotel in top_candidates:
                    total_comparisons += 1
                    
                    result = self._make_name_only_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel['id'],
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'Name-only fallback'
                        }
                
                if len(top_candidates) == 0:
                    if not ref_iso:
                        skipped_no_country += 1
                    else:
                        skipped_no_api_country += 1
            
            # Strategy 3: API ID Rescue (only for strong brands)
            if not best_match:
                ref_brand = self._extract_brand(ref_hotel['clean_hotel'])
                if ref_brand and ref_iso and ref_iso in api_by_country.groups:
                    print(f"    🚑 Trying API ID rescue for brand: {ref_brand}")
                    rescue_candidates = api_by_country.get_group(ref_iso)
                    
                    for _, api_hotel in rescue_candidates.iterrows():
                        api_brand = self._extract_brand_from_api_id(api_hotel.get('id', ''))
                        
                        if api_brand and self._brands_match(ref_brand, api_brand):
                            # Calculate rescue confidence
                            name_sim = fuzz.token_sort_ratio(ref_hotel['normalized_name'], 
                                                            api_hotel['normalized_name']) / 100.0
                            rescue_confidence = 0.70 + name_sim * 0.15
                            
                            if rescue_confidence >= 0.60:
                                best_match = {
                                    'reference_id': ref_hotel['reference_id'],
                                    'reference_name': ref_hotel['clean_hotel'],
                                    'api_id': api_hotel['id'],
                                    'api_name': api_hotel['clean_name'],
                                    'api_chain': api_hotel['clean_chain'],
                                    'api_city': api_hotel['clean_city'],
                                    'api_address': api_hotel['clean_address'],
                                    'api_latitude': api_hotel.get('lat'),
                                    'api_longitude': api_hotel.get('lng'),
                                    'confidence': rescue_confidence,
                                    'match_reason': f'API ID Brand Rescue: {api_brand} match',
                                    'match_strategy': 'API ID Rescue'
                                }
                                api_id_rescues += 1
                                print(f"    🚑 RESCUE SUCCESS: {api_hotel['clean_name'][:40]}...")
                                break
            
            # Record result
            if best_match and best_confidence >= 0.55:
                matches.append(best_match)
                
                # Track algorithm performance
                reason = best_match['match_reason']
                for algo_name in algorithm_stats.keys():
                    if algo_name in reason:
                        algorithm_stats[algo_name] += 1
                        break
                
                confidence_level = "🟢 HIGH" if best_confidence >= 0.85 else "🟡 MEDIUM" if best_confidence >= 0.70 else "🔴 LOW"
                print(f"    ✅ MATCH FOUND: {best_match['api_name'][:40]}...")
                print(f"    📊 Confidence: {best_confidence:.3f} ({confidence_level})")
                print(f"    🎯 Strategy: {best_match['match_strategy']}")
                print(f"    📝 Reason: {best_match['match_reason'][:60]}...")
            else:
                print(f"    ❌ No match found (best confidence: {best_confidence:.3f})")
        
        print(f"\n" + "="*60)
        print("🎯 ENHANCED MATCHING COMPLETED")
        print("="*60)
        print(f"✅ Total matches found: {len(matches)}")
        print(f"📊 Coverage: {len(matches)}/{total_hotels} ({len(matches)/total_hotels*100:.1f}%)")
        print(f"⚡ Performance stats:")
        print(f"   📊 Total comparisons: {total_comparisons:,}")
        print(f"   🚫 Skipped (no ISO): {skipped_no_country}")
        print(f"   🚫 Skipped (no API country): {skipped_no_api_country}")
        print(f"   🚑 API ID rescues: {api_id_rescues}")
        
        print(f"\n🧠 ALGORITHM EFFECTIVENESS:")
        for algo_name, count in algorithm_stats.items():
            if count > 0:
                percentage = (count / len(matches)) * 100 if matches else 0
                print(f"   📈 {algo_name}: {count} matches ({percentage:.1f}%)")
        
        # Strategy breakdown
        if matches:
            iso_matches = sum(1 for m in matches if m['match_strategy'] == 'ISO-based')
            name_matches = sum(1 for m in matches if m['match_strategy'] == 'Name-only fallback')
            rescue_matches = sum(1 for m in matches if m['match_strategy'] == 'API ID Rescue')
            
            print(f"\n📊 STRATEGY BREAKDOWN:")
            print(f"   🌍 ISO-based matching: {iso_matches} ({iso_matches/len(matches)*100:.1f}%)")
            print(f"   🔍 Name-only fallback: {name_matches} ({name_matches/len(matches)*100:.1f}%)")
            if rescue_matches > 0:
                print(f"   🚑 API ID Rescue: {rescue_matches} ({rescue_matches/len(matches)*100:.1f}%)")
        
        if matches:
            confidences = [m['confidence'] for m in matches]
            high_conf = sum(1 for c in confidences if c >= 0.85)
            med_conf = sum(1 for c in confidences if 0.70 <= c < 0.85)
            low_conf = sum(1 for c in confidences if c < 0.70)
            
            print(f"\n📈 CONFIDENCE DISTRIBUTION:")
            print(f"   🟢 High (≥0.85): {high_conf}")
            print(f"   🟡 Medium (0.70-0.84): {med_conf}")
            print(f"   🔴 Low (<0.70): {low_conf}")
        
        return matches
    
    def create_full_reference_with_results(self, matches: List[Dict]) -> pd.DataFrame:
        results_df = self.reference_hotels[['Lokalizacja', 'Hotel', 'reference_id', 'country_raw', 'city', 'country_iso']].copy()
        
        results_df = results_df.rename(columns={
            'country_raw': 'reference_country',
            'city': 'reference_city'
        })
        
        match_dict = {match['reference_id']: match for match in matches}
        
        results_df['api_id'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_id', ''))
        results_df['api_name'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_name', ''))
        results_df['api_chain'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_chain', ''))
        results_df['api_city'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_city', ''))
        results_df['api_address'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_address', ''))
        results_df['api_latitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_latitude', ''))
        results_df['api_longitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_longitude', ''))
        results_df['confidence'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('confidence', ''))
        results_df['match_reason'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_reason', ''))
        results_df['match_strategy'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_strategy', ''))
        results_df['matched'] = results_df['api_id'] != ''
        
        return results_df
    
    def run_complete_matching(self, reference_csv: str, api_csv: str) -> Dict:
        print("🚀" + "="*58 + "🚀")
        print("🚀 ENHANCED HOTEL MAPPING ENGINE - API ID INTELLIGENCE 🚀")
        print("🚀" + "="*58 + "🚀")
        print("Algorithm: ISO Pre-filtering + Rule-based Decision Tree + API ID Intelligence")
        print("Features: Brand extraction + Geographic + String similarity + API ID rescue")
        
        self.load_reference_hotels(reference_csv)
        if self.reference_hotels is None:
            return {'error': 'Failed to load reference hotels'}
            
        self.load_api_hotels(api_csv)
        if self.api_hotels is None:
            return {'error': 'Failed to load API hotels'}
        
        matches = self.run_matching()
        
        results = {
            'total_reference_hotels': len(self.reference_hotels),
            'total_api_hotels': len(self.api_hotels),
            'total_matches': len(matches),
            'coverage_percentage': len(matches) / len(self.reference_hotels) * 100,
            'matches': matches
        }
        
        return results
    
    def save_results(self, results: Dict, output_prefix: str = "enhanced_hotel_mapping"):
        print("\n" + "="*60)
        print("💾 SAVING ENHANCED RESULTS")
        print("="*60)
        
        matches = results['matches']
        
        if matches:
            matches_df = pd.DataFrame(matches)
            matches_file = f"{output_prefix}_matches.csv"
            matches_df.to_csv(matches_file, index=False, encoding='utf-8-sig')
            print(f"✅ Saved matches: {matches_file}")
        
        full_results = self.create_full_reference_with_results(matches)
        full_file = f"{output_prefix}_full_reference.csv"
        full_results.to_csv(full_file, index=False, encoding='utf-8-sig')
        print(f"✅ Saved full reference: {full_file}")
        
        summary = pd.DataFrame({
            'metric': ['Total Reference Hotels', 'Total API Hotels', 'Total Matches', 'Coverage Percentage'],
            'value': [results['total_reference_hotels'], results['total_api_hotels'], 
                     results['total_matches'], f"{results['coverage_percentage']:.1f}%"]
        })
        summary_file = f"{output_prefix}_summary.csv"
        summary.to_csv(summary_file, index=False, encoding='utf-8-sig')
        print(f"✅ Saved summary: {summary_file}")
        
        print(f"\n🎯 ENHANCED FINAL RESULTS:")
        print(f"   📚 Reference hotels: {results['total_reference_hotels']}")
        print(f"   📡 API hotels: {results['total_api_hotels']:,}")
        print(f"   ✅ Matches found: {results['total_matches']}")
        print(f"   📊 Coverage: {results['coverage_percentage']:.1f}%")


if __name__ == "__main__":
    matcher = EnhancedHotelMatcher()
    
    results = matcher.run_complete_matching(
        reference_csv="00_api_lista_referencyjna.csv",
        api_csv="01_api_rate_hawk.csv"
    )
    
    matcher.save_results(results)
    
    print("\n" + "="*60)
    print("🏁 ENHANCED HOTEL MAPPING COMPLETED!")
    print("="*60)
# Out:
# 🚀==========================================================🚀
# 🚀 ENHANCED HOTEL MAPPING ENGINE - API ID INTELLIGENCE 🚀
# 🚀==========================================================🚀
# Algorithm: ISO Pre-filtering + Rule-based Decision Tree + API ID Intelligence
# Features: Brand extraction + Geographic + String similarity + API ID rescue
#
# ============================================================
# 📂 LOADING REFERENCE HOTELS
# ============================================================
# ✅ Loaded file: 00_api_lista_referencyjna.csv
# 📊 Found 97 reference hotels
#
# 🧹 Processing reference data...
# 🌍 Mapping countries to ISO codes...
# 📈 Countries distribution:
#    GR (Greece): 13 hotels
#    MV (Maldives): 12 hotels
#    AE (United Arab Emirates): 11 hotels
#    ES (Spain): 8 hotels
#    TH (Thailand): 7 hotels
# 🏨 Luxury brands detected: 23
# ✅ Processed 97 reference hotels
#
# ============================================================
# 📡 LOADING API HOTELS
# ============================================================
# ✅ Loaded file: 01_api_rate_hawk.csv
# 📊 Found 95,463 API hotels
#
# 🧹 Processing API data...
# 🌍 API countries distribution:
#    AE (United Arab Emirates): 12,942 hotels
#    GR (Greece): 8,592 hotels
#    TH (Thailand): 8,063 hotels
#    US (United States): 7,858 hotels
#    ES (Spain): 6,906 hotels
# 📍 Hotels with coordinates: 95,463/95,463 (100.0%)
# 🏨 Top 3 hotel chains:
#    No chain: 91,821 hotels
#    ZenRooms: 162 hotels
#    Choice Hotels: 144 hotels
# ✅ Processed 95,463 API hotels
#
# ============================================================
# 🎯 RUNNING ENHANCED HOTEL MATCHING
# ============================================================
# 📊 Processing 97 reference hotels
# 🔧 ISO pre-filtering + API ID intelligence active
# 🌍 API countries available: 27
#
# [ 1/97] Processing: Hilton Aruba Caribbean Resort & Casino, Aruba...
#     🌍 Country: AW
#     📍 ISO candidates: 1,255
#     ... checked 1,000/1,255 candidates
#     ✅ MATCH FOUND: Embassy Suites By Hilton Aruba Beach Res...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [ 2/97] Processing: Shangri-La Sydney...
#     🌍 Country: AU
#     📍 ISO candidates: 3,669
#     ... checked 1,000/3,669 candidates
#     ... checked 2,000/3,669 candidates
#     ... checked 3,000/3,669 candidates
#     ✅ MATCH FOUND: Shangri-La Sydney...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [ 3/97] Processing: One & Only Portovovi, Czarnogóra...
#     🌍 Country: ME
#     📍 ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3352
#     ❌ No match found (best confidence: 0.000)
#
# [ 4/97] Processing: Dukley Hotel & Resort, Czarnogóra...
#     🌍 Country: ME
#     📍 ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1716
#     ✅ MATCH FOUND: Dukley Hotel & Resort...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [ 5/97] Processing: Tortuga Bay Puntacana Resort & Club, Dominikana...
#     🌍 Country: DO
#     📍 ISO candidates: 5,826
#     ... checked 1,000/5,826 candidates
#     ... checked 2,000/5,826 candidates
#     ... checked 3,000/5,826 candidates
#     ... checked 4,000/5,826 candidates
#     ... checked 5,000/5,826 candidates
#     ✅ MATCH FOUND: Tortuga Bay Hotel at Puntacana Resort & ...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)...
#
# [ 6/97] Processing: The Chedi El Gouna, Egipt...
#     🌍 Country: EG
#     📍 ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4416
#     ✅ MATCH FOUND: El Gouna Apartment...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [ 7/97] Processing: Four Seasons Sharm El Sheikh, Egipt...
#     🌍 Country: EG
#     📍 ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Sharm EL Sheikh...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [ 8/97] Processing: Hotel Du Palais Biarritz - The Unbound Collection ...
#     🌍 Country: FR
#     📍 ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     ✅ MATCH FOUND: Hôtel du Palais...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed...
#
# [ 9/97] Processing: Le Fitz Roy, Val Thorens...
#     🌍 Country: FR
#     📍 ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Le Val Thorens...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [10/97] Processing: One & Only Aesthesis, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [11/97] Processing: The Stanley, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: The Stanley...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [12/97] Processing: Wyndham Grand Athens, Ateny...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: O&B Athens Boutique Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [13/97] Processing: Sani Club Hotel, Chalkidiki...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2695
#     ✅ MATCH FOUND: Sani Villa...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [14/97] Processing: Ikos Oceania, Chalkidiki...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2820
#     ✅ MATCH FOUND: Villa Oceania...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [15/97] Processing: Romanos, Costa Navarino...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [16/97] Processing: Mandarin Oriental, Costa Navarino...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Costa Navarino...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [17/97] Processing: Grecotel Corfu Imperial...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Corfu Palace...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [18/97] Processing: Angsana Corfu Resort...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Angsana Corfu Resort & Spa...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [19/97] Processing: Ikos Dassia, Korfu...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2304
#     ❌ No match found (best confidence: 0.000)
#
# [20/97] Processing: Daios Cove, Kreta...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Villa Kreta...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [21/97] Processing: Domes Zeen, a Luxury Collection Resort, Kreta...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: The Beach House Collection...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [22/97] Processing: Elivi Skiathos...
#     🌍 Country: GR
#     📍 ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3982
#     ❌ No match found (best confidence: 0.000)
#
# [23/97] Processing: Quark Expeditions...
#     🌍 Country: GL
#     ⚠️  No API hotels for GL - trying name-only fallback
#     🔍 Name-only candidates: 2210
#     ❌ No match found (best confidence: 0.000)
#
# [24/97] Processing: Ikos Andalusia...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [25/97] Processing: Ikos Porto Petro, Majorka...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [26/97] Processing: Marbella Club...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Royal Suites Marbella...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [27/97] Processing: METT Marbella Hotel, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Marbella House...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [28/97] Processing: Puente Romano, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Villa Romano...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [29/97] Processing: El Fuerte Marbella, Hiszpania...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Marbella House...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [30/97] Processing: Bahia Del Duque...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3797
#     ❌ No match found (best confidence: 0.000)
#
# [31/97] Processing: SH Valencia Palace, Walencja...
#     🌍 Country: ES
#     📍 ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Valencia...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [32/97] Processing: Four Seasons Jimbaran Bay, Bali...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Bali at Jimbaran Bay...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [33/97] Processing: The Laguna, A Luxury Collection Resort & Spa...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: The Laguna, a Luxury Collection Resort &...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)...
#
# [34/97] Processing: The St Regis Bali Resort Nusa Dua...
#     🌍 Country: ID
#     📍 ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Bali Nusa Dua Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [35/97] Processing: The Retreat at Blue Lagoon Iceland...
#     🌍 Country: IS
#     📍 ISO candidates: 15
#     ✅ MATCH FOUND: The Retreat at Blue Lagoon Iceland...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [36/97] Processing: Movenpick Resort Kuredhivaru Maldives...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2503
#     ✅ MATCH FOUND: Kuredhivaru Resort & Spa Maldives...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [37/97] Processing: Finolhu, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 1782
#     ❌ No match found (best confidence: 0.000)
#
# [38/97] Processing: Vakkaru...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 814
#     ✅ MATCH FOUND: Vakkaru Maldives Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [39/97] Processing: JOALI Being...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Joali Being...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [40/97] Processing: Patina Maldives, Fari Islands...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Patina Maldives, Fari Islands...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [41/97] Processing: JOALI Maldives...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: JOALI Maldives Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [42/97] Processing: Velaa Private Island...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Velaa Private Island...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [43/97] Processing: Waldorf Astoria Maldives Ithaafushi...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Maldives Ithaafushi Hote...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [44/97] Processing: Emerald Resort, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4178
#     ✅ MATCH FOUND: Emerald Hotel...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [45/97] Processing: One & Only Reethi Rah...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: One&Only Reethi Rah Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [46/97] Processing: Niyama Private Island...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Niyama Private Islands Maldives...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)...
#
# [47/97] Processing: Lily Beach Resort & Spa, Malediwy...
#     🌍 Country: MV
#     📍 ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Lily Beach Resort & Spa...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)...
#
# [48/97] Processing: Four Seasons Langkawi...
#     🌍 Country: MY
#     📍 ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Langkawi...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [49/97] Processing: The Datai, Malezja...
#     🌍 Country: MY
#     📍 ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [50/97] Processing: Four Seasons Marakesh, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Four Seasons Resort Mauritius at Anahita...
#     📊 Confidence: 0.844 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: API ID Brand Match + Name Similarity (Pure Name Matching) (0...
#
# [51/97] Processing: Jaal Riad Resort, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [52/97] Processing: The St. Regis La Bahia Blanca Resort, Maroko...
#     🌍 Country: MA
#     📍 ISO candidates: 545
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Bahia Blanca...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [53/97] Processing: JW Marriott Mauritius Resort...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2795
#     ✅ MATCH FOUND: JW Marriott Miami...
#     📊 Confidence: 0.868 (🟢 HIGH)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: API ID Brand Match + Name Similarity (Pure Name Matching) (0...
#
# [54/97] Processing: Sugar Beach Mauritius...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: Sugar Beach Mauritius...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [55/97] Processing: One & Only Le Saint Geran...
#     🌍 Country: MU
#     📍 ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: One&Only Le Saint Géran...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (0.95)...
#
# [56/97] Processing: Belmond Reid's Palace, Portugalia...
#     🌍 Country: PT
#     📍 ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: GA Palace Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Contains Match + Geographic + Indicators (1.00)...
#
# [57/97] Processing: The Lodge Hotel, Porto...
#     🌍 Country: PT
#     📍 ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: Porto Marina...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [58/97] Processing: The Raffles Doha...
#     🌍 Country: QA
#     📍 ISO candidates: 498
#     ✅ MATCH FOUND: Raffles Doha...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [59/97] Processing: Fancourt Hotel...
#     🌍 Country: ZA
#     📍 ISO candidates: 601
#     ✅ MATCH FOUND: Fancourt...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [60/97] Processing: Waldorf Astoria Seychelles...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Waldorf Astoria Seychelles Platte Island...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [61/97] Processing: Four Seasons Resort Seychelles at Desroches Island...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Four Seasons Resort Seychelles...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [62/97] Processing: Six Senses Zil Pasyon...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Six Senses Zil Pasyon Seychelles...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [63/97] Processing: Raffles Prasiln...
#     🌍 Country: SC
#     📍 ISO candidates: 747
#     ✅ MATCH FOUND: Raffles Seychelles...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [64/97] Processing: Mandarin Oriental, Singapur...
#     🌍 Country: SG
#     📍 ISO candidates: 1,085
#     ... checked 1,000/1,085 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Singapore...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [65/97] Processing: Chedi Andermatt, Szwajcaria...
#     🌍 Country: CH
#     📍 ISO candidates: 392
#     ✅ MATCH FOUND: The Chedi Andermatt...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [66/97] Processing: Badrutt's Palace, Szwajcaria...
#     🌍 Country: CH
#     📍 ISO candidates: 392
#     ✅ MATCH FOUND: Badrutt's Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [67/97] Processing: Banyan Tree Krabi...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Banyan Tree Resorts...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [68/97] Processing: Ritz Carlton Phulay Bay...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phulay Bay, a Ritz-Carlton Reserve...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [69/97] Processing: Dusit Thani, Pattaya...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dusit Thani Pattaya...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [70/97] Processing: Saii Phi Phi Island Village Resort, Tajlandia...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phi Phi The Beach Resort Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: ISO-based
#     📝 Reason: Word Shuffle Match + Location Verified (1.00)...
#
# [71/97] Processing: Rosewood Phuket...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phuket Island View Resort...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [72/97] Processing: Intercontinental Phuket Resort, Tajlandia...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dinso Resort & Villas Phuket, Vignette C...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Brand Perfect Match + Location Confirmed...
#
# [73/97] Processing: Six Senses Yao Noi...
#     🌍 Country: TH
#     📍 ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Six Senses Yao Noi...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [74/97] Processing: Gloria Serenity Resort...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.679) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Serenity Villa...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [75/97] Processing: Regnum Carya Golf & Spa Resort, Turcja...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2988
#     ❌ No match found (best confidence: 0.000)
#
# [76/97] Processing: Maxx Royal Belek Golf Resort, Belek...
#     🌍 Country: TR
#     📍 ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     ✅ MATCH FOUND: Belek Golf Apartments...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [77/97] Processing: Jumeirah at Saadiyat Island Resort, UAE...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     🔄 Low confidence (0.697) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: Jumeirah Saadiyat Island Abu Dhabi...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (0.89)...
#
# [78/97] Processing: Atlantis The Royal...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis, The Palm...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [79/97] Processing: One & Only Royal Mirage...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only Royal Mirage Hotel...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [80/97] Processing: Atlantis The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis, The Palm...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [81/97] Processing: Mandarin Oriental Jumeira Dubai...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Hotel mandarin oriental jumeira, dubai...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [82/97] Processing: Burj Al Arab...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Luxury apartment Burj al Arab View...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Name Almost Identical + Same Country (1.00)...
#
# [83/97] Processing: One & Only The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One&Only The Palm, Dubai Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [84/97] Processing: The Ritz-Carlton, Jumeirah...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: The Ritz-Carlton, Dubai Hotel...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [85/97] Processing: Four Seasons Resort at Jumeirah Beach...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Four Seasons Dubai at Jumeirah Beach Res...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [86/97] Processing: Waldorf Astoria The Palm...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Ras Al Khaimah...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [87/97] Processing: DoubleTree by Hilton Resort & Spa Marjan Island, U...
#     🌍 Country: AE
#     📍 ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: DoubleTree by Hilton Dubai - Jumeirah Be...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [88/97] Processing: The Betsy Hotel, Miami...
#     🌍 Country: US
#     📍 ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: W Miami...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [89/97] Processing: Four Seasons Resort Orlando at Walt Disney World R...
#     🌍 Country: US
#     📍 ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: Four Seasons Miami Hotel...
#     📊 Confidence: 0.970 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: API ID Brand Perfect Match + Same Country...
#
# [90/97] Processing: Fairmont St Andrews, Szkocja...
#     🌍 Country: GB
#     📍 ISO candidates: 943
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 4513
#     🚑 Trying API ID rescue for brand: fairmont
#     ❌ No match found (best confidence: 0.000)
#
# [91/97] Processing: Regent Phu Quoc Hotel, Wietnam...
#     🌍 Country: VN
#     📍 ISO candidates: 1,058
#     ... checked 1,000/1,058 candidates
#     ✅ MATCH FOUND: The Beach Club Resort Phu Quoc...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: ISO-based
#     📝 Reason: Same Words Different Order + Location (1.00)...
#
# [92/97] Processing: Lefay Resort & SPA Dolomiti...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 3283
#     ✅ MATCH FOUND: Dolomiti...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [93/97] Processing: Alpin & Vital Hotel La Perla, Ortisei, Włochy...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [94/97] Processing: Lefay Resort Lago Di Garda, Włochy...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2350
#     ❌ No match found (best confidence: 0.000)
#
# [95/97] Processing: Forte Village, Sardynia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ✅ MATCH FOUND: The Village Resort...
#     📊 Confidence: 0.700 (🟡 MEDIUM)
#     🎯 Strategy: Name-only fallback
#     📝 Reason: Same Words Different Order (Pure Name Matching) (1.00)...
#
# [96/97] Processing: The Abi d'Oru Hotel & Spa, Sardynia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 5000
#     ❌ No match found (best confidence: 0.000)
#
# [97/97] Processing: Verdura Golf & Spa Resort, Sycylia...
#     🌍 Country: IT
#     📍 ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying name-only fallback
#     🔍 Name-only candidates: 2061
#     ❌ No match found (best confidence: 0.000)
#
# ============================================================
# 🎯 ENHANCED MATCHING COMPLETED
# ============================================================
# ✅ Total matches found: 79
# 📊 Coverage: 79/97 (81.4%)
# ⚡ Performance stats:
#    📊 Total comparisons: 657,591
#    🚫 Skipped (no ISO): 0
#    🚫 Skipped (no API country): 0
#    🚑 API ID rescues: 0
#
# 🧠 ALGORITHM EFFECTIVENESS:
#    📈 API ID Brand Perfect Match + Same Country: 24 matches (30.4%)
#    📈 Brand Perfect Match + Location Confirmed: 2 matches (2.5%)
#    📈 Name Almost Identical + Same Country: 14 matches (17.7%)
#    📈 Same Words Different Order + Location: 15 matches (19.0%)
#    📈 API ID Brand Match + Name Similarity: 2 matches (2.5%)
#    📈 Name Contains Match + Geographic + Indicators: 5 matches (6.3%)
#    📈 Word Shuffle Match + Location Verified: 1 matches (1.3%)
#    📈 Same Words Different Order (Pure Name Matching): 16 matches (20.3%)
#
# 📊 STRATEGY BREAKDOWN:
#    🌍 ISO-based matching: 61 (77.2%)
#    🔍 Name-only fallback: 18 (22.8%)
#
# 📈 CONFIDENCE DISTRIBUTION:
#    🟢 High (≥0.85): 56
#    🟡 Medium (0.70-0.84): 23
#    🔴 Low (<0.70): 0
#
# ============================================================
# 💾 SAVING ENHANCED RESULTS
# ============================================================
# ✅ Saved matches: enhanced_hotel_mapping_matches.csv
# ✅ Saved full reference: enhanced_hotel_mapping_full_reference.csv
# ✅ Saved summary: enhanced_hotel_mapping_summary.csv
#
# 🎯 ENHANCED FINAL RESULTS:
#    📚 Reference hotels: 97
#    📡 API hotels: 95,463
#    ✅ Matches found: 79
#    📊 Coverage: 81.4%
#
# ============================================================
# 🏁 ENHANCED HOTEL MAPPING COMPLETED!
# ============================================================

# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
import re
import phonetics
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

class ProductionHotelMatcher:
    def __init__(self, api_source: str = 'universal'):
        self.reference_hotels = None
        self.api_hotels = None
        self.api_source = api_source
        
        # Universal components - work with ANY API
        self.iso_mappings = self._create_iso_mappings()
        self.country_to_iso = self._create_reverse_iso_lookup()
        self.universal_brands = self._create_universal_brands()
        self.stop_words = self._create_enhanced_stop_words()
        self.premium_keywords = self._create_premium_keywords()
        
        # API-specific enhancements (optional)
        self.api_enhancements = self._load_api_enhancements(api_source)
        
    def _create_iso_mappings(self) -> Dict[str, Dict]:
        """Universal ISO country mappings - works with all APIs"""
        return {
            'AE': {
                'iso_code': 'AE',
                'official_name': 'United Arab Emirates',
                'variants': ['UAE', 'U.A.E', 'United Arab Emirates', 'Emiraty Arabskie', 'Zjednoczone Emiraty Arabskie']
            },
            'TH': {
                'iso_code': 'TH',
                'official_name': 'Thailand', 
                'variants': ['Thailand', 'Tajlandia', 'Siam', 'Kingdom of Thailand']
            },
            'SC': {
                'iso_code': 'SC',
                'official_name': 'Seychelles',
                'variants': ['Seychelles', 'Seszele', 'Republic of Seychelles', 'Sesel']
            },
            'TR': {
                'iso_code': 'TR',
                'official_name': 'Turkey',
                'variants': ['Turkey', 'Turcja', 'Türkiye', 'Republic of Turkey']
            },
            'ES': {
                'iso_code': 'ES', 
                'official_name': 'Spain',
                'variants': ['Spain', 'Hiszpania', 'España', 'Kingdom of Spain']
            },
            'ME': {
                'iso_code': 'ME',
                'official_name': 'Montenegro',
                'variants': ['Montenegro', 'Czarnogóra', 'Crna Gora']
            },
            'IT': {
                'iso_code': 'IT',
                'official_name': 'Italy',
                'variants': ['Italy', 'Włochy', 'Italia', 'Italian Republic']
            },
            'MY': {
                'iso_code': 'MY',
                'official_name': 'Malaysia',
                'variants': ['Malaysia', 'Malezja']
            },
            'MV': {
                'iso_code': 'MV',
                'official_name': 'Maldives',
                'variants': ['Maldives', 'Malediwy', 'Republic of Maldives']
            },
            'GR': {
                'iso_code': 'GR',
                'official_name': 'Greece',
                'variants': ['Greece', 'Grecja', 'Hellas', 'Hellenic Republic']
            },
            'MA': {
                'iso_code': 'MA',
                'official_name': 'Morocco',
                'variants': ['Morocco', 'Maroko', 'Kingdom of Morocco']
            },
            'EG': {
                'iso_code': 'EG',
                'official_name': 'Egypt',
                'variants': ['Egypt', 'Egipt', 'Arab Republic of Egypt']
            },
            'MU': {
                'iso_code': 'MU',
                'official_name': 'Mauritius',
                'variants': ['Mauritius', 'Republic of Mauritius']
            },
            'GB': {
                'iso_code': 'GB',
                'official_name': 'United Kingdom',
                'variants': ['United Kingdom', 'Wielka Brytania', 'UK', 'Great Britain']
            },
            'PT': {
                'iso_code': 'PT',
                'official_name': 'Portugal',
                'variants': ['Portugal', 'Portugalia', 'Portuguese Republic']
            },
            'CH': {
                'iso_code': 'CH',
                'official_name': 'Switzerland',
                'variants': ['Switzerland', 'Szwajcaria', 'Swiss Confederation']
            },
            'AU': {
                'iso_code': 'AU',
                'official_name': 'Australia',
                'variants': ['Australia', 'Commonwealth of Australia']
            },
            'ID': {
                'iso_code': 'ID',
                'official_name': 'Indonesia',
                'variants': ['Indonesia', 'Indonezja', 'Republic of Indonesia']
            },
            'AW': {
                'iso_code': 'AW',
                'official_name': 'Aruba',
                'variants': ['Aruba']
            },
            'GL': {
                'iso_code': 'GL',
                'official_name': 'Greenland',
                'variants': ['Greenland', 'Grenlandia']
            },
            'VN': {
                'iso_code': 'VN',
                'official_name': 'Vietnam',
                'variants': ['Vietnam', 'Wietnam', 'Socialist Republic of Vietnam']
            },
            'FR': {
                'iso_code': 'FR',
                'official_name': 'France',
                'variants': ['France', 'Francja', 'French Republic']
            },
            'US': {
                'iso_code': 'US',
                'official_name': 'United States',
                'variants': ['United States', 'USA', 'US', 'America']
            },
            'SG': {
                'iso_code': 'SG',
                'official_name': 'Singapore',
                'variants': ['Singapore', 'Singapur', 'Republic of Singapore']
            },
            'IS': {
                'iso_code': 'IS',
                'official_name': 'Iceland',
                'variants': ['Iceland', 'Islandia', 'Republic of Iceland']
            },
            'QA': {
                'iso_code': 'QA',
                'official_name': 'Qatar',
                'variants': ['Qatar', 'State of Qatar']
            },
            'ZA': {
                'iso_code': 'ZA',
                'official_name': 'South Africa',
                'variants': ['South Africa', 'RPA', 'Republic of South Africa']
            },
            'DO': {
                'iso_code': 'DO',
                'official_name': 'Dominican Republic',
                'variants': ['Dominican Republic', 'Dominikana']
            },
            'CL': {
                'iso_code': 'CL',
                'official_name': 'Chile',
                'variants': ['Chile', 'Republic of Chile', 'Explora']
            }
        }
    
    def _create_reverse_iso_lookup(self) -> Dict[str, str]:
        lookup = {}
        for iso_code, data in self.iso_mappings.items():
            for variant in data['variants']:
                lookup[variant.lower().strip()] = iso_code
        return lookup
    
    def _create_universal_brands(self) -> List[str]:
        """Universal luxury brands - work with all APIs"""
        return [
            'four seasons', 'atlantis', 'banyan tree', 'mandarin oriental',
            'one only', 'one & only', 'angsana', 'shangri-la', 'ritz carlton', 
            'ritz-carlton', 'st regis', 'waldorf astoria', 'hilton', 'marriott', 
            'hyatt', 'intercontinental', 'sheraton', 'westin', 'doubletree', 
            'regent', 'fairmont', 'raffles', 'rosewood', 'belmond', 'six senses',
            'chedi', 'dusit thani', 'movenpick', 'mövenpick', 'joali', 'conrad',
            'park hyatt', 'grand hyatt', 'andaz', 'aloft', 'w hotels', 'le meridien',
            'luxury collection', 'autograph collection', 'jw marriott'
        ]
    
    def _create_enhanced_stop_words(self) -> List[str]:
        """Enhanced stop words based on API analysis"""
        return [
            # Basic hotel types
            'hotel', 'resort', 'spa', 'suites', 'inn', 'lodge', 'motel',
            # Accommodation types
            'apartment', 'apartments', 'villa', 'house', 'studio', 'bedroom',
            # Descriptors
            'luxury', 'grand', 'royal', 'palace', 'club', 'boutique', 'deluxe',
            # Location words
            'beach', 'view', 'pool', 'marina', 'bay', 'island',
            # Common words
            'in', 'by', 'with', 'and', 'the', 'at', 'of', 'for',
            # Numbers
            '1', '2', '3', '4', '5', 'one', 'two', 'three', 'four', 'five'
        ]
    
    def _create_premium_keywords(self) -> List[str]:
        """Premium indicators that work across all APIs"""
        return [
            'luxury', 'private', 'boutique', 'grand', 'deluxe', 'royal', 
            'retreat', 'premium', 'palace', 'collection', 'signature', 
            'exclusive', 'estate', 'reserve', 'imperial',
            'beach', 'oceanfront', 'seafront', 'waterfront', 'marina', 'bay'
        ]
    
    def _extract_id_components_smart(self, api_id: str, ref_hotel: pd.Series) -> Dict:
        """
        Smart dynamic analysis of API ID against reference hotel data
        No hardcoded patterns needed - compares ID parts with reference data
        """
        if not api_id or len(str(api_id)) < 3:
            return {'confidence_boost': 0.0, 'matches': []}
        
        # Split ID into meaningful components
        id_parts = re.split(r'[_\-\s\.]+', str(api_id).lower())
        id_parts = [part.strip() for part in id_parts if len(part) > 2 and not part.isdigit()]
        
        if not id_parts:
            return {'confidence_boost': 0.0, 'matches': []}
        
        # Reference data for comparison
        ref_brand = ref_hotel.get('brand', '').lower() if ref_hotel.get('brand') else ''
        ref_city = ref_hotel.get('city', '').lower() if ref_hotel.get('city') else ''
        ref_country = ref_hotel.get('country_raw', '').lower() if ref_hotel.get('country_raw') else ''
        ref_name_words = ref_hotel.get('normalized_name', '').split() if ref_hotel.get('normalized_name') else []
        
        matches = []
        confidence_boost = 0.0
        
        # City variant mappings for international names
        city_variants = {
            'warsaw': ['warszawa', 'warsaw'],
            'prague': ['praga', 'praha', 'prague'], 
            'vienna': ['wiedeń', 'wien', 'vienna'],
            'munich': ['monachium', 'münchen', 'munich'],
            'florence': ['florencja', 'firenze', 'florence'],
            'rome': ['rzym', 'roma', 'rome'],
            'paris': ['paryż', 'paris'],
            'london': ['londyn', 'london'],
            'istanbul': ['stambul', 'istanbul'],
            'athens': ['ateny', 'athens'],
            'budapest': ['budapeszt', 'budapest'],
            'madrid': ['madryt', 'madrid'],
            'lisbon': ['lizbona', 'lisboa', 'lisbon'],
            'zurich': ['zurych', 'zurich'],
            'geneva': ['genewa', 'genève', 'geneva'],
            'dubai': ['dubaj', 'dubai'],
            'moscow': ['moskwa', 'moscow'],
            'beijing': ['pekin', 'beijing']
        }
        
        # Check each ID component against reference data
        for part in id_parts:
            if len(part) < 3:
                continue
                
            # Brand matching
            if ref_brand and len(ref_brand) > 2:
                brand_similarity = fuzz.ratio(part, ref_brand) / 100.0
                if brand_similarity > 0.85:
                    confidence_boost += 0.06
                    matches.append(f"Brand: '{part}' matches '{ref_brand}'")
                    continue
            
            # City matching (direct)
            if ref_city and len(ref_city) > 2:
                city_similarity = fuzz.ratio(part, ref_city) / 100.0
                if city_similarity > 0.80:
                    confidence_boost += 0.04
                    matches.append(f"City: '{part}' matches '{ref_city}'")
                    continue
            
            # City variant matching
            if ref_city:
                for canonical, variants in city_variants.items():
                    if part in variants and ref_city in variants:
                        confidence_boost += 0.04
                        matches.append(f"City variant: '{part}' ~ '{ref_city}'")
                        break
            
            # Hotel name word matching
            for ref_word in ref_name_words:
                if len(ref_word) > 3:
                    word_similarity = fuzz.ratio(part, ref_word) / 100.0
                    if word_similarity > 0.85:
                        confidence_boost += 0.02
                        matches.append(f"Name part: '{part}' matches '{ref_word}'")
                        break
            
            # Country matching (less common but useful)
            if ref_country and len(ref_country) > 3:
                country_similarity = fuzz.ratio(part, ref_country) / 100.0
                if country_similarity > 0.85:
                    confidence_boost += 0.03
                    matches.append(f"Country: '{part}' matches '{ref_country}'")
        
        # Cap the boost to prevent over-enhancement
        confidence_boost = min(confidence_boost, 0.15)
        
        return {
            'confidence_boost': confidence_boost,
            'matches': matches,
            'id_parts': id_parts
        }
    
    def _try_smart_api_enhancements(self, base_result: Dict, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        """
        Smart enhancement using dynamic ID analysis - no hardcoded patterns
        """
        if not base_result:
            return base_result
        
        api_id = api_hotel.get('id', '')
        if not api_id:
            return base_result
        
        # Perform smart analysis
        analysis = self._extract_id_components_smart(api_id, ref_hotel)
        
        if analysis['confidence_boost'] > 0.01:  # Only enhance if meaningful boost
            enhanced_result = base_result.copy()
            original_confidence = enhanced_result['confidence']
            
            enhanced_result['confidence'] = min(
                original_confidence + analysis['confidence_boost'], 
                0.98
            )
            
            # Add enhancement details to reason
            if analysis['matches']:
                enhancement_details = '; '.join(analysis['matches'][:2])  # Show top 2 matches
                enhanced_result['reason'] += f" + Smart ID Analysis: {enhancement_details}"
            
            return enhanced_result
        
        return base_result
    
    def _map_country_to_iso(self, country_str: str) -> Optional[str]:
        if not country_str:
            return None
        country_clean = country_str.lower().strip()
        return self.country_to_iso.get(country_clean)
    
    def _extract_brand_from_name(self, hotel_name: str) -> Optional[str]:
        """Universal brand extraction from hotel names"""
        if not hotel_name:
            return None
        name_lower = hotel_name.lower()
        for brand in self.universal_brands:
            if brand in name_lower:
                return brand
        return None
    
    def _normalize_hotel_name(self, name: str) -> str:
        """Universal name normalization"""
        if pd.isna(name) or not name:
            return ""
        
        name = str(name).lower().strip()
        name = re.sub(r'[^\w\s]', ' ', name)
        
        # Convert numbers to words
        number_map = {'1': 'one', '2': 'two', '3': 'three', '4': 'four', '5': 'five'}
        for digit, word in number_map.items():
            name = name.replace(f' {digit} ', f' {word} ')
        
        words = [word for word in name.split() if word not in self.stop_words and len(word) > 1]
        
        # Remove duplicates while preserving order
        seen = set()
        unique_words = []
        for word in words:
            if word not in seen:
                unique_words.append(word)
                seen.add(word)
        
        return ' '.join(unique_words)
    
    def _load_api_enhancements(self, api_source: str) -> Dict:
        """Load API-specific enhancements if available"""
        # Simplified - focus on chain field detection
        enhancements = {
            'rate_hawk': {
                'has_chain_field': True,
                'smart_id_analysis': True,
                'confidence_boost': 0.03
            },
            'booking_com': {
                'has_chain_field': True,
                'smart_id_analysis': False,
                'confidence_boost': 0.03
            },
            'expedia': {
                'has_chain_field': True,
                'smart_id_analysis': False,
                'confidence_boost': 0.02
            },
            'universal': {
                'has_chain_field': True,
                'smart_id_analysis': True,
                'confidence_boost': 0.0
            }
        }
        return enhancements.get(api_source, enhancements['universal'])
    
    def _normalize_city_name(self, city: str) -> str:
        if not city:
            return ""
        city_mappings = {
            'dubaj': 'dubai',
            'krabi': 'krabi',
            'desroches': 'desroches island'
        }
        city_clean = city.lower().strip()
        return city_mappings.get(city_clean, city_clean)
    
    def load_reference_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📂 LOADING REFERENCE HOTELS")
        print("="*60)
        
        df = pd.read_csv(csv_path)
        print(f"✅ Loaded file: {csv_path}")
        print(f"📊 Found {len(df)} reference hotels")
        
        print("\n🧹 Processing reference data...")
        df['clean_location'] = df['Lokalizacja'].str.strip()
        df['clean_hotel'] = df['Hotel'].str.strip()
        
        df[['country_raw', 'city_raw']] = df['clean_location'].str.split(',', n=1, expand=True)
        df['country_raw'] = df['country_raw'].fillna('').str.strip()
        df['city_raw'] = df['city_raw'].fillna('').str.strip()
        
        print("🌍 Mapping countries to ISO codes...")
        df['country_iso'] = df['country_raw'].apply(self._map_country_to_iso)
        
        unmapped_countries = df[df['country_iso'].isna()]['country_raw'].unique()
        if len(unmapped_countries) > 0:
            print(f"⚠️  Unmapped countries: {list(unmapped_countries)}")
        
        df['city'] = df['city_raw'].apply(self._normalize_city_name)
        df['normalized_name'] = df['clean_hotel'].apply(self._normalize_hotel_name)
        df['brand'] = df['clean_hotel'].apply(self._extract_brand_from_name)
        df['reference_id'] = df.index.astype(str).str.zfill(3)
        
        country_stats = df['country_iso'].value_counts()
        print(f"📈 Countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count} hotels")
        
        brands_found = df['brand'].dropna().nunique()
        print(f"🏨 Universal brands detected: {brands_found}")
        
        self.reference_hotels = df
        print(f"✅ Processed {len(df)} reference hotels")
        return df
    
    def load_api_hotels(self, csv_path: str) -> pd.DataFrame:
        print("\n" + "="*60)
        print("📡 LOADING API HOTELS")
        print("="*60)
        
        df = pd.read_csv(csv_path)
        print(f"✅ Loaded file: {csv_path}")
        print(f"📊 Found {len(df):,} API hotels")
        
        print("\n🧹 Processing API data...")
        df['clean_name'] = df['name'].fillna('').str.strip()
        df['clean_city'] = df['city'].fillna('').str.strip()
        df['clean_address'] = df['address'].fillna('').str.strip()
        
        # Handle different possible chain field names
        chain_fields = ['hotel_chain', 'chain', 'brand', 'group']
        df['clean_chain'] = ''
        for field in chain_fields:
            if field in df.columns:
                df['clean_chain'] = df[field].fillna('').str.strip()
                break
        
        df['country_iso'] = df['country'].fillna('').str.upper().str.strip()
        df['normalized_name'] = df['clean_name'].apply(self._normalize_hotel_name)
        df['city_normalized'] = df['clean_city'].apply(self._normalize_city_name)
        df['brand_from_name'] = df['clean_name'].apply(self._extract_brand_from_name)
        
        df['lat'] = pd.to_numeric(df['latitude'], errors='coerce')
        df['lng'] = pd.to_numeric(df['longitude'], errors='coerce')
        
        country_stats = df['country_iso'].value_counts()
        print(f"🌍 API countries distribution:")
        for country, count in country_stats.head(5).items():
            country_name = self.iso_mappings.get(country, {}).get('official_name', country)
            print(f"   {country} ({country_name}): {count:,} hotels")
        
        coords_valid = df[['lat', 'lng']].notna().all(axis=1).sum()
        print(f"📍 Hotels with coordinates: {coords_valid:,}/{len(df):,} ({coords_valid/len(df)*100:.1f}%)")
        
        print(f"🔧 Smart ID analysis: {self.api_enhancements.get('smart_id_analysis', False)}")
        print(f"🎯 Enhancement features: {list(self.api_enhancements.keys())}")
        
        self.api_hotels = df
        print(f"✅ Processed {len(df):,} API hotels")
        return df
    
    def _calculate_universal_features(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        """Calculate features that work with any API"""
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return self._empty_features()
        
        features = {
            # String similarity (universal)
            'fuzz_ratio': fuzz.ratio(ref_name, api_name) / 100.0,
            'fuzz_partial': fuzz.partial_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_sort': fuzz.token_sort_ratio(ref_name, api_name) / 100.0,
            'fuzz_token_set': fuzz.token_set_ratio(ref_name, api_name) / 100.0,
            
            # Geographic (universal)
            'country_exact': ref_hotel['country_iso'] == api_hotel['country_iso'],
            'city_similarity': self._city_similarity(ref_hotel['city'], api_hotel['city_normalized']),
            
            # Brand detection (universal)
            'brand_from_name': self._brand_match_from_names(ref_hotel, api_hotel),
            'brand_chain_match': self._brand_chain_match(ref_hotel, api_hotel),
            
            # Additional universal features
            'soundex_match': self._soundex_match(ref_name, api_name),
            'word_intersection': self._word_intersection_ratio(ref_name, api_name),
            'premium_keywords': self._premium_keywords_overlap(ref_hotel['clean_hotel'], api_hotel['clean_name'])
        }
        
        return features
    
    def _empty_features(self) -> Dict:
        return {
            'fuzz_ratio': 0.0, 'fuzz_partial': 0.0, 'fuzz_token_sort': 0.0,
            'fuzz_token_set': 0.0, 'country_exact': False, 'city_similarity': 0.0,
            'brand_from_name': False, 'brand_chain_match': False, 'soundex_match': False,
            'word_intersection': 0.0, 'premium_keywords': 0.0
        }
    
    def _city_similarity(self, city1: str, city2: str) -> float:
        if not city1 or not city2:
            return 0.0
        return fuzz.ratio(city1.lower(), city2.lower()) / 100.0
    
    def _brand_match_from_names(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> bool:
        """Brand matching from hotel names (universal)"""
        ref_brand = ref_hotel.get('brand')
        api_brand = api_hotel.get('brand_from_name')
        
        if not ref_brand or not api_brand:
            return False
        
        return fuzz.ratio(ref_brand, api_brand) / 100.0 > 0.85
    
    def _brand_chain_match(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> bool:
        """Brand matching using chain field (if available)"""
        ref_brand = ref_hotel.get('brand')
        api_chain = api_hotel.get('clean_chain', '').lower()
        
        if not ref_brand or not api_chain:
            return False
        
        return ref_brand.lower() in api_chain or fuzz.ratio(ref_brand, api_chain) / 100.0 > 0.80
    
    def _soundex_match(self, name1: str, name2: str) -> bool:
        if not name1 or not name2:
            return False
        try:
            soundex1 = phonetics.soundex(name1.replace(' ', ''))
            soundex2 = phonetics.soundex(name2.replace(' ', ''))
            return soundex1 == soundex2
        except:
            return False
    
    def _word_intersection_ratio(self, name1: str, name2: str) -> float:
        if not name1 or not name2:
            return 0.0
        
        words1 = set(name1.lower().split())
        words2 = set(name2.lower().split())
        
        if not words1 or not words2:
            return 0.0
        
        intersection = len(words1 & words2)
        union = len(words1 | words2)
        
        return intersection / union if union > 0 else 0.0
    
    def _premium_keywords_overlap(self, name1: str, name2: str) -> float:
        name1_lower = name1.lower()
        name2_lower = name2.lower()
        
        name1_keywords = sum(1 for kw in self.premium_keywords if kw in name1_lower)
        name2_keywords = sum(1 for kw in self.premium_keywords if kw in name2_lower)
        
        if name1_keywords == 0 and name2_keywords == 0:
            return 0.0
        
        common_keywords = sum(1 for kw in self.premium_keywords if kw in name1_lower and kw in name2_lower)
        total_keywords = max(name1_keywords, name2_keywords)
        
        return common_keywords / total_keywords if total_keywords > 0 else 0.0
    
    def _universal_high_confidence_rules(self, features: Dict) -> Optional[Dict]:
        """High confidence rules using only universal features"""
        
        # Brand match + country + high name similarity
        if features['brand_chain_match'] and features['country_exact'] and features['fuzz_token_sort'] > 0.85:
            return {
                'match': True,
                'confidence': 0.95,
                'reason': 'Universal Brand + Location + High Name Similarity'
            }
        
        if features['brand_from_name'] and features['country_exact'] and features['city_similarity'] > 0.8:
            return {
                'match': True,
                'confidence': 0.93,
                'reason': 'Universal Brand Match + Perfect Location'
            }
        
        # Very high name similarity + country
        if features['fuzz_token_sort'] > 0.92 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.90,
                'reason': f'Universal Name Almost Identical + Same Country ({features["fuzz_token_sort"]:.2f})'
            }
        
        # Token set high + location
        if features['fuzz_token_set'] > 0.90 and features['country_exact'] and features['city_similarity'] > 0.7:
            return {
                'match': True,
                'confidence': 0.88,
                'reason': f'Universal Same Words Different Order + Location ({features["fuzz_token_set"]:.2f})'
            }
        
        return None
    
    def _universal_medium_confidence_rules(self, features: Dict) -> Optional[Dict]:
        """Medium confidence rules using universal features"""
        
        # Brand similarity + good name match
        if (features['brand_from_name'] or features['brand_chain_match']) and features['fuzz_token_sort'] > 0.75 and features['country_exact']:
            confidence = 0.75 + (features['fuzz_token_sort'] - 0.75) * 0.4
            return {
                'match': True,
                'confidence': min(confidence, 0.87),
                'reason': f'Universal Brand + Strong Name Similarity ({features["fuzz_token_sort"]:.2f})'
            }
        
        # High partial ratio + context
        if features['fuzz_partial'] > 0.85 and features['country_exact'] and features['premium_keywords'] > 0.3:
            return {
                'match': True,
                'confidence': 0.77,
                'reason': f'Universal Name Contains + Geographic + Premium ({features["fuzz_partial"]:.2f})'
            }
        
        # Token set + location
        if features['fuzz_token_set'] > 0.80 and features['country_exact'] and features['city_similarity'] > 0.6:
            confidence = 0.65 + (features['fuzz_token_set'] - 0.80) * 0.5
            return {
                'match': True,
                'confidence': min(confidence, 0.83),
                'reason': f'Universal Word Shuffle + Location ({features["fuzz_token_set"]:.2f})'
            }
        
        return None
    
    def _universal_lower_confidence_rules(self, features: Dict) -> Optional[Dict]:
        """Lower confidence rules using universal features"""
        
        # Phonetic + partial match
        if features['soundex_match'] and features['fuzz_partial'] > 0.75 and features['country_exact']:
            return {
                'match': True,
                'confidence': 0.62,
                'reason': f'Universal Phonetic + Partial Match ({features["fuzz_partial"]:.2f})'
            }
        
        # Word intersection + premium + location
        if (features['word_intersection'] > 0.6 and features['premium_keywords'] > 0.4 and 
            features['country_exact'] and features['city_similarity'] > 0.5):
            return {
                'match': True,
                'confidence': 0.58,
                'reason': f'Universal Word Intersection + Premium + Location ({features["word_intersection"]:.2f})'
            }
        
        return None
    
    def _universal_matching_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        """Core universal matching - works with any API"""
        features = self._calculate_universal_features(ref_hotel, api_hotel)
        
        # Try high confidence rules first
        result = self._universal_high_confidence_rules(features)
        if result:
            return result
        
        # Try medium confidence rules
        result = self._universal_medium_confidence_rules(features)
        if result:
            return result
        
        # Try lower confidence rules
        result = self._universal_lower_confidence_rules(features)
        if result:
            return result
        
        return None
    
    def _try_api_enhancements(self, base_result: Dict, ref_hotel: pd.Series, api_hotel: pd.Series) -> Dict:
        """Try to enhance result with API-specific features"""
        if not base_result or not self.api_enhancements.get('has_structured_ids'):
            return base_result
        
        enhanced_result = base_result.copy()
        
        # Try API ID enhancement (Rate Hawk only)
        if self.api_source == 'rate_hawk' and 'id' in api_hotel:
            api_id = str(api_hotel.get('id', '')).lower()
            ref_brand = ref_hotel.get('brand', '')
            
            # Check for brand pattern in API ID
            for pattern, brand in self.api_enhancements.get('id_brand_patterns', {}).items():
                if pattern in api_id and ref_brand and fuzz.ratio(ref_brand, brand.lower()) / 100.0 > 0.85:
                    enhanced_result['confidence'] = min(enhanced_result['confidence'] + 0.05, 0.98)
                    enhanced_result['reason'] += ' + API ID Brand Enhancement'
                    break
        
        return enhanced_result
    
    def _universal_name_only_decision(self, ref_hotel: pd.Series, api_hotel: pd.Series) -> Optional[Dict]:
        """Universal name-only matching for fallback"""
        ref_name = ref_hotel['normalized_name']
        api_name = api_hotel['normalized_name']
        
        if not ref_name or not api_name:
            return None
        
        # Check brand match first
        ref_brand = ref_hotel.get('brand')
        api_brand = api_hotel.get('brand_from_name')
        brand_match = ref_brand and api_brand and fuzz.ratio(ref_brand, api_brand) / 100.0 > 0.85
        
        if brand_match:
            name_sim = fuzz.token_sort_ratio(ref_name, api_name) / 100.0
            confidence = 0.70 + name_sim * 0.15
            return {
                'match': True,
                'confidence': min(confidence, 0.88),
                'reason': f'Universal Brand + Name Similarity (Fallback) ({name_sim:.2f})'
            }
        
        # Regular name-only matching
        fuzz_token_sort = fuzz.token_sort_ratio(ref_name, api_name) / 100.0
        fuzz_token_set = fuzz.token_set_ratio(ref_name, api_name) / 100.0
        
        if fuzz_token_sort > 0.88:
            return {
                'match': True,
                'confidence': 0.75,
                'reason': f'Universal Names Almost Identical (Fallback) ({fuzz_token_sort:.2f})'
            }
        
        if fuzz_token_set > 0.85:
            return {
                'match': True,
                'confidence': 0.72,
                'reason': f'Universal Same Words Different Order (Fallback) ({fuzz_token_set:.2f})'
            }
        
        return None
    
    def run_matching(self) -> List[Dict]:
        print("\n" + "="*60)
        print("🎯 RUNNING PRODUCTION HOTEL MATCHING")
        print("="*60)
        
        matches = []
        api_by_country = self.api_hotels.groupby('country_iso')
        total_hotels = len(self.reference_hotels)
        
        # Algorithm performance tracking
        algorithm_stats = {
            'Universal Brand + Location + High Name Similarity': 0,
            'Universal Brand Match + Perfect Location': 0,
            'Universal Name Almost Identical + Same Country': 0,
            'Universal Same Words Different Order + Location': 0,
            'Universal Brand + Strong Name Similarity': 0,
            'Universal Name Contains + Geographic + Premium': 0,
            'Universal Word Shuffle + Location': 0,
            'Universal Phonetic + Partial Match': 0,
            'Universal Word Intersection + Premium + Location': 0,
            'Universal Brand + Name Similarity (Fallback)': 0,
            'Universal Names Almost Identical (Fallback)': 0,
            'Universal Same Words Different Order (Fallback)': 0,
            'API Enhanced Matches': 0
        }
        
        print(f"📊 Processing {total_hotels} reference hotels")
        print(f"🔧 Universal core + {self.api_source} enhancements")
        print(f"🌍 API countries available: {len(api_by_country.groups)}")
        
        total_comparisons = 0
        skipped_no_country = 0
        skipped_no_api_country = 0
        enhanced_matches = 0
        
        for idx, (_, ref_hotel) in enumerate(self.reference_hotels.iterrows(), 1):
            ref_iso = ref_hotel['country_iso']
            ref_name = ref_hotel['clean_hotel']
            
            print(f"\n[{idx:2d}/{total_hotels}] Processing: {ref_name[:50]}...")
            print(f"    🌍 Country: {ref_iso}")
            
            best_match = None
            best_confidence = 0.0
            
            # Strategy 1: Universal ISO-based matching (80% baseline)
            if ref_iso and ref_iso in api_by_country.groups:
                candidates = api_by_country.get_group(ref_iso)
                print(f"    📍 Universal ISO candidates: {len(candidates):,}")
                
                candidates_checked = 0
                for _, api_hotel in candidates.iterrows():
                    candidates_checked += 1
                    total_comparisons += 1
                    
                    # Universal core matching
                    result = self._universal_matching_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel.get('id', ''),
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'Universal ISO-based'
                        }
                        
                        # Try smart API enhancements
                        enhanced_result = self._try_smart_api_enhancements(result, ref_hotel, api_hotel)
                        if enhanced_result['confidence'] > result['confidence']:
                            best_match['confidence'] = enhanced_result['confidence']
                            best_match['match_reason'] = enhanced_result['reason']
                            enhanced_matches += 1
                    
                    if candidates_checked % 1000 == 0:
                        print(f"    ... checked {candidates_checked:,}/{len(candidates):,} candidates")
            
            # Strategy 2: Universal name-only fallback
            if not best_match or best_confidence < 0.75:
                if not ref_iso:
                    print(f"    ⚠️  No ISO mapping - trying universal name-only fallback")
                elif ref_iso not in api_by_country.groups:
                    print(f"    ⚠️  No API hotels for {ref_iso} - trying universal fallback")
                else:
                    print(f"    🔄 Low confidence ({best_confidence:.3f}) - trying universal fallback")
                
                # Use top 3000 hotels by similarity for performance
                name_similarities = []
                for _, api_hotel in self.api_hotels.iterrows():
                    if api_hotel['normalized_name']:
                        sim = fuzz.ratio(ref_hotel['normalized_name'], api_hotel['normalized_name']) / 100.0
                        if sim > 0.4:
                            name_similarities.append((sim, api_hotel))
                
                name_similarities.sort(key=lambda x: x[0], reverse=True)
                top_candidates = name_similarities[:3000]
                
                print(f"    🔍 Universal name-only candidates: {len(top_candidates)}")
                
                for sim_score, api_hotel in top_candidates:
                    total_comparisons += 1
                    
                    result = self._universal_name_only_decision(ref_hotel, api_hotel)
                    
                    if result and result['confidence'] > best_confidence:
                        best_confidence = result['confidence']
                        best_match = {
                            'reference_id': ref_hotel['reference_id'],
                            'reference_name': ref_hotel['clean_hotel'],
                            'api_id': api_hotel.get('id', ''),
                            'api_name': api_hotel['clean_name'],
                            'api_chain': api_hotel['clean_chain'],
                            'api_city': api_hotel['clean_city'],
                            'api_address': api_hotel['clean_address'],
                            'api_latitude': api_hotel.get('lat'),
                            'api_longitude': api_hotel.get('lng'),
                            'confidence': result['confidence'],
                            'match_reason': result['reason'],
                            'match_strategy': 'Universal Name-only Fallback'
                        }
                        
                        # Try smart enhancements on fallback too
                        enhanced_result = self._try_smart_api_enhancements(result, ref_hotel, api_hotel)
                        if enhanced_result['confidence'] > result['confidence']:
                            best_match['confidence'] = enhanced_result['confidence']
                            best_match['match_reason'] = enhanced_result['reason']
                            enhanced_matches += 1
                
                if len(top_candidates) == 0:
                    if not ref_iso:
                        skipped_no_country += 1
                    else:
                        skipped_no_api_country += 1
            
            # Record result
            if best_match and best_confidence >= 0.55:
                matches.append(best_match)
                
                # Track algorithm performance
                reason = best_match['match_reason']
                for algo_name in algorithm_stats.keys():
                    if algo_name.replace(' + API Enhanced', '') in reason:
                        algorithm_stats[algo_name] += 1
                        break
                
                if 'API ID' in reason or 'Enhancement' in reason:
                    algorithm_stats['API Enhanced Matches'] += 1
                
                confidence_level = "🟢 HIGH" if best_confidence >= 0.85 else "🟡 MEDIUM" if best_confidence >= 0.70 else "🔴 LOW"
                print(f"    ✅ MATCH FOUND: {best_match['api_name'][:40]}...")
                print(f"    📊 Confidence: {best_confidence:.3f} ({confidence_level})")
                print(f"    🎯 Strategy: {best_match['match_strategy']}")
                print(f"    📝 Reason: {best_match['match_reason'][:60]}...")
            else:
                print(f"    ❌ No match found (best confidence: {best_confidence:.3f})")
        
        print(f"\n" + "="*60)
        print("🎯 PRODUCTION MATCHING COMPLETED")
        print("="*60)
        print(f"✅ Total matches found: {len(matches)}")
        print(f"📊 Coverage: {len(matches)}/{total_hotels} ({len(matches)/total_hotels*100:.1f}%)")
        print(f"⚡ Performance stats:")
        print(f"   📊 Total comparisons: {total_comparisons:,}")
        print(f"   🚫 Skipped (no ISO): {skipped_no_country}")
        print(f"   🚫 Skipped (no API country): {skipped_no_api_country}")
        print(f"   🔧 Smart ID enhancements applied: {enhanced_matches}")
        
        print(f"\n🧠 ALGORITHM EFFECTIVENESS:")
        for algo_name, count in algorithm_stats.items():
            if count > 0:
                percentage = (count / len(matches)) * 100 if matches else 0
                print(f"   📈 {algo_name}: {count} matches ({percentage:.1f}%)")
        
        # Strategy breakdown
        if matches:
            iso_matches = sum(1 for m in matches if m['match_strategy'] == 'Universal ISO-based')
            name_matches = sum(1 for m in matches if m['match_strategy'] == 'Universal Name-only Fallback')
            
            print(f"\n📊 STRATEGY BREAKDOWN:")
            print(f"   🌍 Universal ISO-based: {iso_matches} ({iso_matches/len(matches)*100:.1f}%)")
            print(f"   🔍 Universal Name-only Fallback: {name_matches} ({name_matches/len(matches)*100:.1f}%)")
            
            if enhanced_matches > 0:
                print(f"   🔧 Smart ID enhancements: {enhanced_matches} ({enhanced_matches/len(matches)*100:.1f}%)")
        
        if matches:
            confidences = [m['confidence'] for m in matches]
            high_conf = sum(1 for c in confidences if c >= 0.85)
            med_conf = sum(1 for c in confidences if 0.70 <= c < 0.85)
            low_conf = sum(1 for c in confidences if c < 0.70)
            
            print(f"\n📈 CONFIDENCE DISTRIBUTION:")
            print(f"   🟢 High (≥0.85): {high_conf}")
            print(f"   🟡 Medium (0.70-0.84): {med_conf}")
            print(f"   🔴 Low (<0.70): {low_conf}")
        
        return matches
    
    def create_full_reference_with_results(self, matches: List[Dict]) -> pd.DataFrame:
        """Create comprehensive results with reference + API data"""
        results_df = self.reference_hotels[['Lokalizacja', 'Hotel', 'reference_id', 'country_raw', 'city', 'country_iso']].copy()
        
        results_df = results_df.rename(columns={
            'country_raw': 'reference_country',
            'city': 'reference_city'
        })
        
        match_dict = {match['reference_id']: match for match in matches}
        
        results_df['api_id'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_id', ''))
        results_df['api_name'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_name', ''))
        results_df['api_chain'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_chain', ''))
        results_df['api_city'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_city', ''))
        results_df['api_address'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_address', ''))
        results_df['api_latitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_latitude', ''))
        results_df['api_longitude'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('api_longitude', ''))
        results_df['confidence'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('confidence', ''))
        results_df['match_reason'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_reason', ''))
        results_df['match_strategy'] = results_df['reference_id'].map(lambda x: match_dict.get(x, {}).get('match_strategy', ''))
        results_df['matched'] = results_df['api_id'] != ''
        
        return results_df
    
    def run_complete_matching(self, reference_csv: str, api_csv: str) -> Dict:
        print("🚀" + "="*58 + "🚀")
        print("🚀 PRODUCTION HOTEL MATCHER - UNIVERSAL CORE + API ENHANCEMENT 🚀")
        print("🚀" + "="*58 + "🚀")
        print(f"Architecture: Universal Core (80% baseline) + {self.api_source.title()} Enhancements")
        print("Features: ISO pre-filtering + Universal algorithms + API-specific boosters")
        
        self.load_reference_hotels(reference_csv)
        if self.reference_hotels is None:
            return {'error': 'Failed to load reference hotels'}
            
        self.load_api_hotels(api_csv)
        if self.api_hotels is None:
            return {'error': 'Failed to load API hotels'}
        
        matches = self.run_matching()
        
        results = {
            'total_reference_hotels': len(self.reference_hotels),
            'total_api_hotels': len(self.api_hotels),
            'total_matches': len(matches),
            'coverage_percentage': len(matches) / len(self.reference_hotels) * 100,
            'matches': matches,
            'api_source': self.api_source
        }
        
        return results
    
    def save_results(self, results: Dict, output_prefix: str = "production_hotel_mapping"):
        print("\n" + "="*60)
        print("💾 SAVING PRODUCTION RESULTS")
        print("="*60)
        
        matches = results['matches']
        api_source = results.get('api_source', 'universal')
        output_prefix = f"{output_prefix}_{api_source}"
        
        if matches:
            matches_df = pd.DataFrame(matches)
            matches_file = f"{output_prefix}_matches.csv"
            matches_df.to_csv(matches_file, index=False, encoding='utf-8-sig')
            print(f"✅ Saved matches: {matches_file}")
        
        full_results = self.create_full_reference_with_results(matches)
        full_file = f"{output_prefix}_full_reference.csv"
        full_results.to_csv(full_file, index=False, encoding='utf-8-sig')
        print(f"✅ Saved full reference: {full_file}")
        
        summary = pd.DataFrame({
            'metric': ['API Source', 'Total Reference Hotels', 'Total API Hotels', 'Total Matches', 'Coverage Percentage'],
            'value': [api_source, results['total_reference_hotels'], results['total_api_hotels'], 
                     results['total_matches'], f"{results['coverage_percentage']:.1f}%"]
        })
        summary_file = f"{output_prefix}_summary.csv"
        summary.to_csv(summary_file, index=False, encoding='utf-8-sig')
        print(f"✅ Saved summary: {summary_file}")
        
        print(f"\n🎯 PRODUCTION FINAL RESULTS:")
        print(f"   🔧 API Source: {api_source}")
        print(f"   📚 Reference hotels: {results['total_reference_hotels']}")
        print(f"   📡 API hotels: {results['total_api_hotels']:,}")
        print(f"   ✅ Matches found: {results['total_matches']}")
        print(f"   📊 Coverage: {results['coverage_percentage']:.1f}%")


if __name__ == "__main__":
    # Example usage with different API sources
    
    # Rate Hawk with enhancements
    print("Testing with Rate Hawk API (with ID enhancements)...")
    matcher_rh = ProductionHotelMatcher(api_source='rate_hawk')
    results_rh = matcher_rh.run_complete_matching(
        reference_csv="lista_referencyjna.csv",
        api_csv="01_api_rate_hawk.csv"
    )
    matcher_rh.save_results(results_rh)
    
    # Universal mode (works with any API)
    print("\n" + "="*60)
    print("Testing in Universal mode (no API-specific features)...")
    matcher_universal = ProductionHotelMatcher(api_source='universal')
    results_universal = matcher_universal.run_complete_matching(
        reference_csv="lista_referencyjna.csv",
        api_csv="01_api_rate_hawk.csv"  # Same data, but treated as universal
    )
    matcher_universal.save_results(results_universal)
    
    print("\n" + "="*60)
    print("🏁 PRODUCTION HOTEL MATCHING COMPLETED!")
    print("="*60)
    print(f"Rate Hawk Enhanced: {results_rh['coverage_percentage']:.1f}%")
    print(f"Universal Mode: {results_universal['coverage_percentage']:.1f}%")
    print(f"Enhancement Gain: +{results_rh['coverage_percentage'] - results_universal['coverage_percentage']:.1f}%")
# Out:
# Testing with Rate Hawk API (with ID enhancements)...
# 🚀==========================================================🚀
# 🚀 PRODUCTION HOTEL MATCHER - UNIVERSAL CORE + API ENHANCEMENT 🚀
# 🚀==========================================================🚀
# Architecture: Universal Core (80% baseline) + Rate_Hawk Enhancements
# Features: ISO pre-filtering + Universal algorithms + API-specific boosters
#
# ============================================================
# 📂 LOADING REFERENCE HOTELS
# ============================================================
# ✅ Loaded file: lista_referencyjna.csv
# 📊 Found 99 reference hotels
#
# 🧹 Processing reference data...
# 🌍 Mapping countries to ISO codes...
# ⚠️  Unmapped countries: ['The Ritz-Carlton Yacht Collection']
# 📈 Countries distribution:
#    GR (Greece): 13 hotels
#    MV (Maldives): 12 hotels
#    AE (United Arab Emirates): 11 hotels
#    ES (Spain): 8 hotels
#    TH (Thailand): 7 hotels
# 🏨 Universal brands detected: 26
# ✅ Processed 99 reference hotels
#
# ============================================================
# 📡 LOADING API HOTELS
# ============================================================
# ✅ Loaded file: 01_api_rate_hawk.csv
# 📊 Found 95,463 API hotels
#
# 🧹 Processing API data...
# 🌍 API countries distribution:
#    AE (United Arab Emirates): 12,942 hotels
#    GR (Greece): 8,592 hotels
#    TH (Thailand): 8,063 hotels
#    US (United States): 7,858 hotels
#    ES (Spain): 6,906 hotels
# 📍 Hotels with coordinates: 95,463/95,463 (100.0%)
# 🔧 Smart ID analysis: True
# 🎯 Enhancement features: ['has_chain_field', 'smart_id_analysis', 'confidence_boost']
# ✅ Processed 95,463 API hotels
#
# ============================================================
# 🎯 RUNNING PRODUCTION HOTEL MATCHING
# ============================================================
# 📊 Processing 99 reference hotels
# 🔧 Universal core + rate_hawk enhancements
# 🌍 API countries available: 27
#
# [ 1/99] Processing: Regnum Carya Golf & Spa Resort, Turcja...
#     🌍 Country: TR
#     📍 Universal ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2988
#     ❌ No match found (best confidence: 0.000)
#
# [ 2/99] Processing: SH Valencia Palace, Walencja...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Valencia...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [ 3/99] Processing: Atlantis The Royal...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis, The Palm...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [ 4/99] Processing: Ikos Porto Petro, Majorka...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [ 5/99] Processing: One & Only Royal Mirage...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One & Only Royal Mirage - Arabian Court...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [ 6/99] Processing: Atlantis The Palm...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Atlantis, The Palm...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [ 7/99] Processing: One & Only Portovovi, Czarnogóra...
#     🌍 Country: ME
#     📍 Universal ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: One & Only Portonovi...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.67) + Smart ...
#
# [ 8/99] Processing: Bahia Del Duque...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [ 9/99] Processing: Lefay Resort & SPA Dolomiti...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Dolomiti...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [10/99] Processing: Ikos Andalusia...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [11/99] Processing: Four Seasons Langkawi...
#     🌍 Country: MY
#     📍 Universal ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Langkawi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [12/99] Processing: Movenpick Resort Kuredhivaru Maldives...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Kuredhivaru Resort & Spa Maldives...
#     📊 Confidence: 0.770 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Strong Name Similarity (0.80) + Smart ID A...
#
# [13/99] Processing: Sani Club Hotel, Chalkidiki...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2695
#     ✅ MATCH FOUND: Sani Villa...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [14/99] Processing: Marbella Club...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Royal Suites Marbella...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [15/99] Processing: The Ritz-Carlton Yacht Collection...
#     🌍 Country: None
#     ⚠️  No ISO mapping - trying universal name-only fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: The Ritz-Carlton, Millenia Singapore...
#     📊 Confidence: 0.795 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.63) + Smart ...
#
# [16/99] Processing: Waldorf Astoria Seychelles...
#     🌍 Country: SC
#     📍 Universal ISO candidates: 747
#     ✅ MATCH FOUND: Waldorf Astoria Seychelles Platte Island...
#     📊 Confidence: 0.803 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Strong Name Similarity (0.88) + Smart ID A...
#
# [17/99] Processing: Finolhu, Malediwy...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 1782
#     ❌ No match found (best confidence: 0.000)
#
# [18/99] Processing: Gloria Serenity Resort...
#     🌍 Country: TR
#     📍 Universal ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     🔄 Low confidence (0.679) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Serenity Villa...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [19/99] Processing: Dukley Hotel & Resort, Czarnogóra...
#     🌍 Country: ME
#     📍 Universal ISO candidates: 6,233
#     ... checked 1,000/6,233 candidates
#     ... checked 2,000/6,233 candidates
#     ... checked 3,000/6,233 candidates
#     ... checked 4,000/6,233 candidates
#     ... checked 5,000/6,233 candidates
#     ... checked 6,000/6,233 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 1716
#     ✅ MATCH FOUND: Dukley Hotel & Resort...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [20/99] Processing: Grecotel Corfu Imperial...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Corfu Palace...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [21/99] Processing: JW Marriott Mauritius Resort...
#     🌍 Country: MU
#     📍 Universal ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2795
#     ✅ MATCH FOUND: JW Marriott Miami...
#     📊 Confidence: 0.818 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.79) + Smart ...
#
# [22/99] Processing: Four Seasons Resort Seychelles at Desroches Island...
#     🌍 Country: SC
#     📍 Universal ISO candidates: 747
#     ✅ MATCH FOUND: Four Seasons Resort Seychelles at Desroc...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [23/99] Processing: The St. Regis La Bahia Blanca Resort, Maroko...
#     🌍 Country: MA
#     📍 Universal ISO candidates: 545
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Bahia Blanca...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [24/99] Processing: One & Only Aesthesis, Ateny...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: One & Only Royal Mirage - Arabian Court...
#     📊 Confidence: 0.767 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.44)...
#
# [25/99] Processing: Forte Village, Sardynia...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: The Village Resort...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [26/99] Processing: Four Seasons Sharm El Sheikh, Egipt...
#     🌍 Country: EG
#     📍 Universal ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Sharm EL Sheikh...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [27/99] Processing: One & Only Reethi Rah...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: One&Only Reethi Rah Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [28/99] Processing: Vakkaru...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 814
#     ✅ MATCH FOUND: Vakkaru Maldives Hotel...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [29/99] Processing: Six Senses Zil Pasyon...
#     🌍 Country: SC
#     📍 Universal ISO candidates: 747
#     ✅ MATCH FOUND: Six Senses Zil Pasyon Seychelles...
#     📊 Confidence: 0.767 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Strong Name Similarity (0.79) + Smart ID A...
#
# [30/99] Processing: Fairmont St Andrews, Szkocja...
#     🌍 Country: GB
#     📍 Universal ISO candidates: 943
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Bnbme - Fairmont South...
#     📊 Confidence: 0.789 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.60) + Smart ...
#
# [31/99] Processing: The Lodge Hotel, Porto...
#     🌍 Country: PT
#     📍 Universal ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: Porto Marina...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [32/99] Processing: Banyan Tree Krabi...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Banyan Tree Krabi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [33/99] Processing: Mandarin Oriental Jumeira Dubai...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Hotel mandarin oriental jumeira, dubai...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [34/99] Processing: Angsana Corfu Resort...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Angsana Corfu Resort & Spa...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [35/99] Processing: JOALI Being...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Joali Being...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [36/99] Processing: Patina Maldives, Fari Islands...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Patina Maldives, Fari Islands...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [37/99] Processing: Four Seasons Marakesh, Maroko...
#     🌍 Country: MA
#     📍 Universal ISO candidates: 545
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Four Seasons Resort Mauritius at Anahita...
#     📊 Confidence: 0.794 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.62) + Smart ...
#
# [38/99] Processing: Dusit Thani, Pattaya...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Dusit Thani Pattaya...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [39/99] Processing: Chedi Andermatt, Szwajcaria...
#     🌍 Country: CH
#     📍 Universal ISO candidates: 392
#     ✅ MATCH FOUND: The Chedi Andermatt...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [40/99] Processing: Shangri-La Sydney...
#     🌍 Country: AU
#     📍 Universal ISO candidates: 3,669
#     ... checked 1,000/3,669 candidates
#     ... checked 2,000/3,669 candidates
#     ... checked 3,000/3,669 candidates
#     ✅ MATCH FOUND: Shangri-La Sydney...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [41/99] Processing: The Stanley, Ateny...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: The Stanley...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [42/99] Processing: Daios Cove, Kreta...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Villa Kreta...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [43/99] Processing: Romanos, Costa Navarino...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [44/99] Processing: Four Seasons Jimbaran Bay, Bali...
#     🌍 Country: ID
#     📍 Universal ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: Four Seasons Resort Bali at Jimbaran Bay...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [45/99] Processing: Hilton Aruba Caribbean Resort & Casino, Aruba...
#     🌍 Country: AW
#     📍 Universal ISO candidates: 1,255
#     ... checked 1,000/1,255 candidates
#     ✅ MATCH FOUND: Hilton Aruba Caribbean Resort and Casino...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [46/99] Processing: Mandarin Oriental, Costa Navarino...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Costa Navarino...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [47/99] Processing: Quark Expeditions...
#     🌍 Country: GL
#     ⚠️  No API hotels for GL - trying universal fallback
#     🔍 Universal name-only candidates: 2210
#     ❌ No match found (best confidence: 0.000)
#
# [48/99] Processing: JOALI Maldives...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: JOALI Maldives Resort...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [49/99] Processing: Belmond Reid's Palace, Portugalia...
#     🌍 Country: PT
#     📍 Universal ISO candidates: 4,368
#     ... checked 1,000/4,368 candidates
#     ... checked 2,000/4,368 candidates
#     ... checked 3,000/4,368 candidates
#     ... checked 4,000/4,368 candidates
#     ✅ MATCH FOUND: GA Palace Hotel...
#     📊 Confidence: 0.770 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Contains + Geographic + Premium (1.00)...
#
# [50/99] Processing: Velaa Private Island...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Velaa Private Island...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [51/99] Processing: The Abi d'Oru Hotel & Spa, Sardynia...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [52/99] Processing: Burj Al Arab...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Luxury apartment Burj al Arab View...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [53/99] Processing: One & Only The Palm...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: One & Only Royal Mirage - Arabian Court...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location...
#
# [54/99] Processing: Rosewood Phuket...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phuket Island View Resort...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [55/99] Processing: Wyndham Grand Athens, Ateny...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     ✅ MATCH FOUND: O&B Athens Boutique Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [56/99] Processing: Ikos Oceania, Chalkidiki...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2820
#     ✅ MATCH FOUND: Villa Oceania...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [57/99] Processing: Saii Phi Phi Island Village Resort, Tajlandia...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phi Phi The Beach Resort Hotel...
#     📊 Confidence: 0.750 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Word Shuffle + Location (1.00)...
#
# [58/99] Processing: Raffles Prasiln...
#     🌍 Country: SC
#     📍 Universal ISO candidates: 747
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Raffles Bali...
#     📊 Confidence: 0.811 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.74) + Smart ...
#
# [59/99] Processing: Waldorf Astoria Maldives Ithaafushi...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Maldives Ithaafushi Hote...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [60/99] Processing: Regent Phu Quoc Hotel, Wietnam...
#     🌍 Country: VN
#     📍 Universal ISO candidates: 1,058
#     ... checked 1,000/1,058 candidates
#     ✅ MATCH FOUND: Regent Phu Quoc...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [61/99] Processing: The Ritz-Carlton, Jumeirah...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: The Ritz-Carlton, Dubai Hotel...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [62/99] Processing: METT Marbella Hotel, Hiszpania...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Marbella House...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [63/99] Processing: Niyama Private Island...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Niyama Private Islands Maldives...
#     📊 Confidence: 0.770 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Contains + Geographic + Premium (1.00) + Smar...
#
# [64/99] Processing: Hotel Du Palais Biarritz - The Unbound Collection ...
#     🌍 Country: FR
#     📍 Universal ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     ✅ MATCH FOUND: Studio Biarritz...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [65/99] Processing: Four Seasons Resort Orlando at Walt Disney World R...
#     🌍 Country: US
#     📍 Universal ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: Orlando Motel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [66/99] Processing: Mandarin Oriental, Singapur...
#     🌍 Country: SG
#     📍 Universal ISO candidates: 1,085
#     ... checked 1,000/1,085 candidates
#     ✅ MATCH FOUND: Mandarin Oriental, Singapore...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [67/99] Processing: The Datai, Malezja...
#     🌍 Country: MY
#     📍 Universal ISO candidates: 1,694
#     ... checked 1,000/1,694 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [68/99] Processing: The Betsy Hotel, Miami...
#     🌍 Country: US
#     📍 Universal ISO candidates: 7,858
#     ... checked 1,000/7,858 candidates
#     ... checked 2,000/7,858 candidates
#     ... checked 3,000/7,858 candidates
#     ... checked 4,000/7,858 candidates
#     ... checked 5,000/7,858 candidates
#     ... checked 6,000/7,858 candidates
#     ... checked 7,000/7,858 candidates
#     ✅ MATCH FOUND: W Miami...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [69/99] Processing: Ikos Dassia, Korfu...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2304
#     ❌ No match found (best confidence: 0.000)
#
# [70/99] Processing: Puente Romano, Hiszpania...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Villa Romano...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [71/99] Processing: Domes Zeen, a Luxury Collection Resort, Kreta...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: The Ocean Club, a Luxury Collection Reso...
#     📊 Confidence: 0.804 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.69) + Smart ...
#
# [72/99] Processing: Emerald Resort, Malediwy...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Emerald Hotel...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [73/99] Processing: Badrutt's Palace, Szwajcaria...
#     🌍 Country: CH
#     📍 Universal ISO candidates: 392
#     ✅ MATCH FOUND: Badrutt's Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [74/99] Processing: Four Seasons Resort at Jumeirah Beach...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Four Seasons Dubai at Jumeirah Beach Res...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [75/99] Processing: DoubleTree by Hilton Resort & Spa Marjan Island, U...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: DoubleTree by Hilton Resort & Spa Marjan...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [76/99] Processing: Alpin & Vital Hotel La Perla, Ortisei, Włochy...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [77/99] Processing: The Retreat at Blue Lagoon Iceland...
#     🌍 Country: IS
#     📍 Universal ISO candidates: 15
#     ✅ MATCH FOUND: The Retreat at Blue Lagoon Iceland...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [78/99] Processing: Jaal Riad Resort, Maroko...
#     🌍 Country: MA
#     📍 Universal ISO candidates: 545
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [79/99] Processing: The Raffles Doha...
#     🌍 Country: QA
#     📍 Universal ISO candidates: 498
#     ✅ MATCH FOUND: Raffles Doha...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [80/99] Processing: Jumeirah at Saadiyat Island Resort, UAE...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     🔄 Low confidence (0.697) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Jumeirah Saadiyat Island Abu Dhabi...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (0.89) + Sma...
#
# [81/99] Processing: The Chedi El Gouna, Egipt...
#     🌍 Country: EG
#     📍 Universal ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: The Chedi Lustica Bay...
#     📊 Confidence: 0.782 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.55) + Smart ...
#
# [82/99] Processing: El Fuerte Marbella, Hiszpania...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Marbella House...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [83/99] Processing: Fancourt Hotel...
#     🌍 Country: ZA
#     📍 Universal ISO candidates: 601
#     ✅ MATCH FOUND: Fancourt...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [84/99] Processing: Waldorf Astoria The Palm...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Dubai Palm Jumeirah...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [85/99] Processing: The Laguna, A Luxury Collection Resort & Spa...
#     🌍 Country: ID
#     📍 Universal ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: The Laguna, a Luxury Collection Resort &...
#     📊 Confidence: 0.770 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Contains + Geographic + Premium (1.00) + Smar...
#
# [86/99] Processing: Six Senses Yao Noi...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Six Senses Yao Noi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [87/99] Processing: Le Fitz Roy, Val Thorens...
#     🌍 Country: FR
#     📍 Universal ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Le Val Thorens...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00)...
#
# [88/99] Processing: Sugar Beach Mauritius...
#     🌍 Country: MU
#     📍 Universal ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: Sugar Beach Mauritius...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [89/99] Processing: Lefay Resort Lago Di Garda, Włochy...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2350
#     ❌ No match found (best confidence: 0.000)
#
# [90/99] Processing: Elivi Skiathos...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [91/99] Processing: One & Only Le Saint Geran...
#     🌍 Country: MU
#     📍 Universal ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: One&Only Le Saint Géran...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (0.95) + Smar...
#
# [92/99] Processing: The St Regis Bali Resort Nusa Dua...
#     🌍 Country: ID
#     📍 Universal ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
# ...
#     ✅ MATCH FOUND: The Ocean Club, a Luxury Collection Reso...
#     📊 Confidence: 0.804 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.69) + Smart ...
#
# [72/99] Processing: Emerald Resort, Malediwy...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Emerald Hotel...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00) + Sma...
#
# [73/99] Processing: Badrutt's Palace, Szwajcaria...
#     🌍 Country: CH
#     📍 Universal ISO candidates: 392
#     ✅ MATCH FOUND: Badrutt's Palace Hotel...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [74/99] Processing: Four Seasons Resort at Jumeirah Beach...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Four Seasons Dubai at Jumeirah Beach Res...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [75/99] Processing: DoubleTree by Hilton Resort & Spa Marjan Island, U...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: DoubleTree by Hilton Resort & Spa Marjan...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [76/99] Processing: Alpin & Vital Hotel La Perla, Ortisei, Włochy...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [77/99] Processing: The Retreat at Blue Lagoon Iceland...
#     🌍 Country: IS
#     📍 Universal ISO candidates: 15
#     ✅ MATCH FOUND: The Retreat at Blue Lagoon Iceland...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [78/99] Processing: Jaal Riad Resort, Maroko...
#     🌍 Country: MA
#     📍 Universal ISO candidates: 545
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [79/99] Processing: The Raffles Doha...
#     🌍 Country: QA
#     📍 Universal ISO candidates: 498
#     ✅ MATCH FOUND: Raffles Doha...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [80/99] Processing: Jumeirah at Saadiyat Island Resort, UAE...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     🔄 Low confidence (0.697) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Jumeirah Saadiyat Island Abu Dhabi...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (0.89) + Sma...
#
# [81/99] Processing: The Chedi El Gouna, Egipt...
#     🌍 Country: EG
#     📍 Universal ISO candidates: 1,788
#     ... checked 1,000/1,788 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: The Chedi Lustica Bay...
#     📊 Confidence: 0.782 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.55) + Smart ...
#
# [82/99] Processing: El Fuerte Marbella, Hiszpania...
#     🌍 Country: ES
#     📍 Universal ISO candidates: 6,906
#     ... checked 1,000/6,906 candidates
#     ... checked 2,000/6,906 candidates
#     ... checked 3,000/6,906 candidates
#     ... checked 4,000/6,906 candidates
#     ... checked 5,000/6,906 candidates
#     ... checked 6,000/6,906 candidates
#     ✅ MATCH FOUND: Apartment Marbella House...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [83/99] Processing: Fancourt Hotel...
#     🌍 Country: ZA
#     📍 Universal ISO candidates: 601
#     ✅ MATCH FOUND: Fancourt...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [84/99] Processing: Waldorf Astoria The Palm...
#     🌍 Country: AE
#     📍 Universal ISO candidates: 12,942
#     ... checked 1,000/12,942 candidates
#     ... checked 2,000/12,942 candidates
#     ... checked 3,000/12,942 candidates
#     ... checked 4,000/12,942 candidates
#     ... checked 5,000/12,942 candidates
#     ... checked 6,000/12,942 candidates
#     ... checked 7,000/12,942 candidates
#     ... checked 8,000/12,942 candidates
#     ... checked 9,000/12,942 candidates
#     ... checked 10,000/12,942 candidates
#     ... checked 11,000/12,942 candidates
#     ... checked 12,000/12,942 candidates
#     ✅ MATCH FOUND: Waldorf Astoria Dubai Palm Jumeirah...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [85/99] Processing: The Laguna, A Luxury Collection Resort & Spa...
#     🌍 Country: ID
#     📍 Universal ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     ✅ MATCH FOUND: The Laguna, a Luxury Collection Resort &...
#     📊 Confidence: 0.770 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Contains + Geographic + Premium (1.00) + Smar...
#
# [86/99] Processing: Six Senses Yao Noi...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Six Senses Yao Noi...
#     📊 Confidence: 0.950 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand + Location + High Name Similarity + Smart ID...
#
# [87/99] Processing: Le Fitz Roy, Val Thorens...
#     🌍 Country: FR
#     📍 Universal ISO candidates: 2,938
#     ... checked 1,000/2,938 candidates
#     ... checked 2,000/2,938 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: Le Val Thorens...
#     📊 Confidence: 0.720 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Same Words Different Order (Fallback) (1.00)...
#
# [88/99] Processing: Sugar Beach Mauritius...
#     🌍 Country: MU
#     📍 Universal ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: Sugar Beach Mauritius...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (1.00) + Smar...
#
# [89/99] Processing: Lefay Resort Lago Di Garda, Włochy...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2350
#     ❌ No match found (best confidence: 0.000)
#
# [90/99] Processing: Elivi Skiathos...
#     🌍 Country: GR
#     📍 Universal ISO candidates: 8,592
#     ... checked 1,000/8,592 candidates
#     ... checked 2,000/8,592 candidates
#     ... checked 3,000/8,592 candidates
#     ... checked 4,000/8,592 candidates
#     ... checked 5,000/8,592 candidates
#     ... checked 6,000/8,592 candidates
#     ... checked 7,000/8,592 candidates
#     ... checked 8,000/8,592 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ❌ No match found (best confidence: 0.000)
#
# [91/99] Processing: One & Only Le Saint Geran...
#     🌍 Country: MU
#     📍 Universal ISO candidates: 1,930
#     ... checked 1,000/1,930 candidates
#     ✅ MATCH FOUND: One&Only Le Saint Géran...
#     📊 Confidence: 0.900 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Almost Identical + Same Country (0.95) + Smar...
#
# [92/99] Processing: The St Regis Bali Resort Nusa Dua...
#     🌍 Country: ID
#     📍 Universal ISO candidates: 5,189
#     ... checked 1,000/5,189 candidates
#     ... checked 2,000/5,189 candidates
#     ... checked 3,000/5,189 candidates
#     ... checked 4,000/5,189 candidates
#     ... checked 5,000/5,189 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 3000
#     ✅ MATCH FOUND: The St Regis Cap Cana Resort...
#     📊 Confidence: 0.800 (🟡 MEDIUM)
#     🎯 Strategy: Universal Name-only Fallback
#     📝 Reason: Universal Brand + Name Similarity (Fallback) (0.67) + Smart ...
#
# [93/99] Processing: Explora II...
#     🌍 Country: CL
#     ⚠️  No API hotels for CL - trying universal fallback
#     🔍 Universal name-only candidates: 2561
#     ❌ No match found (best confidence: 0.000)
#
# [94/99] Processing: Lily Beach Resort & Spa, Malediwy...
#     🌍 Country: MV
#     📍 Universal ISO candidates: 1,441
#     ... checked 1,000/1,441 candidates
#     ✅ MATCH FOUND: Lily Beach Resort & Spa...
#     📊 Confidence: 0.770 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Contains + Geographic + Premium (1.00) + Smar...
#
# [95/99] Processing: Tortuga Bay Puntacana Resort & Club, Dominikana...
#     🌍 Country: DO
#     📍 Universal ISO candidates: 5,826
#     ... checked 1,000/5,826 candidates
#     ... checked 2,000/5,826 candidates
#     ... checked 3,000/5,826 candidates
#     ... checked 4,000/5,826 candidates
#     ... checked 5,000/5,826 candidates
#     ✅ MATCH FOUND: Tortuga Bay Hotel at Puntacana Resort & ...
#     📊 Confidence: 0.770 (🟡 MEDIUM)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Name Contains + Geographic + Premium (1.00) + Smar...
#
# [96/99] Processing: Ritz Carlton Phulay Bay...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phulay Bay, a Ritz-Carlton Reserve...
#     📊 Confidence: 0.930 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Brand Match + Perfect Location + Smart ID Analysis...
#
# [97/99] Processing: Intercontinental Phuket Resort, Tajlandia...
#     🌍 Country: TH
#     📍 Universal ISO candidates: 8,063
#     ... checked 1,000/8,063 candidates
#     ... checked 2,000/8,063 candidates
#     ... checked 3,000/8,063 candidates
#     ... checked 4,000/8,063 candidates
#     ... checked 5,000/8,063 candidates
#     ... checked 6,000/8,063 candidates
#     ... checked 7,000/8,063 candidates
#     ... checked 8,000/8,063 candidates
#     ✅ MATCH FOUND: Phuket Island View Resort...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# [98/99] Processing: Verdura Golf & Spa Resort, Sycylia...
#     🌍 Country: IT
#     📍 Universal ISO candidates: 5,620
#     ... checked 1,000/5,620 candidates
#     ... checked 2,000/5,620 candidates
#     ... checked 3,000/5,620 candidates
#     ... checked 4,000/5,620 candidates
#     ... checked 5,000/5,620 candidates
#     🔄 Low confidence (0.000) - trying universal fallback
#     🔍 Universal name-only candidates: 2061
#     ❌ No match found (best confidence: 0.000)
#
# [99/99] Processing: Maxx Royal Belek Golf Resort, Belek...
#     🌍 Country: TR
#     📍 Universal ISO candidates: 3,267
#     ... checked 1,000/3,267 candidates
#     ... checked 2,000/3,267 candidates
#     ... checked 3,000/3,267 candidates
#     ✅ MATCH FOUND: Belek Golf Apartments...
#     📊 Confidence: 0.880 (🟢 HIGH)
#     🎯 Strategy: Universal ISO-based
#     📝 Reason: Universal Same Words Different Order + Location (1.00) + Sma...
#
# ============================================================
# 🎯 PRODUCTION MATCHING COMPLETED
# ============================================================
# ✅ Total matches found: 83
# 📊 Coverage: 83/99 (83.8%)
# ⚡ Performance stats:
#    📊 Total comparisons: 623,128
#    🚫 Skipped (no ISO): 0
#    🚫 Skipped (no API country): 0
#    🔧 Smart ID enhancements applied: 116
#
# 🧠 ALGORITHM EFFECTIVENESS:
#    📈 Universal Brand + Location + High Name Similarity: 13 matches (15.7%)
#    📈 Universal Brand Match + Perfect Location: 11 matches (13.3%)
#    📈 Universal Name Almost Identical + Same Country: 14 matches (16.9%)
#    📈 Universal Same Words Different Order + Location: 14 matches (16.9%)
#    📈 Universal Brand + Strong Name Similarity: 3 matches (3.6%)
#    📈 Universal Name Contains + Geographic + Premium: 5 matches (6.0%)
#    📈 Universal Word Shuffle + Location: 1 matches (1.2%)
#    📈 Universal Brand + Name Similarity (Fallback): 10 matches (12.0%)
#    📈 Universal Same Words Different Order (Fallback): 12 matches (14.5%)
#
# 📊 STRATEGY BREAKDOWN:
#    🌍 Universal ISO-based: 61 (73.5%)
#    🔍 Universal Name-only Fallback: 22 (26.5%)
#    🔧 Smart ID enhancements: 116 (139.8%)
#
# 📈 CONFIDENCE DISTRIBUTION:
#    🟢 High (≥0.85): 57
#    🟡 Medium (0.70-0.84): 26
#    🔴 Low (<0.70): 0
#
# ============================================================
# 💾 SAVING PRODUCTION RESULTS
# ============================================================
# ✅ Saved matches: production_hotel_mapping_universal_matches.csv
# ✅ Saved full reference: production_hotel_mapping_universal_full_reference.csv
# ✅ Saved summary: production_hotel_mapping_universal_summary.csv
#
# 🎯 PRODUCTION FINAL RESULTS:
#    🔧 API Source: universal
#    📚 Reference hotels: 99
#    📡 API hotels: 95,463
#    ✅ Matches found: 83
#    📊 Coverage: 83.8%
#
# ============================================================
# 🏁 PRODUCTION HOTEL MATCHING COMPLETED!
# ============================================================
# Rate Hawk Enhanced: 83.8%
# Universal Mode: 83.8%
# Enhancement Gain: +0.0%
